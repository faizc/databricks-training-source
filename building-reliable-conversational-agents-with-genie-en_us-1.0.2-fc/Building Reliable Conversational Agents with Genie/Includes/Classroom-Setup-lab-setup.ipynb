-- %%
%run ./Classroom-Setup-Common-SQL-WAREHOUSE

-- %%
CREATE SCHEMA IF NOT EXISTS genie_course_hr;
USE SCHEMA genie_course_hr;

-- %%
-----------------------------------
-- Create compensation table
-----------------------------------
CREATE TABLE IF NOT EXISTS compensation (
  employee_id STRING NOT NULL,
  base_salary INT,
  market_benchmark INT,
  comp_ratio DOUBLE,
  last_raise_date DATE,
  last_raise_pct DOUBLE
);

-- Insert data only if table is empty
BEGIN
  DECLARE row_count INT;
  SET row_count = (SELECT COUNT(*) FROM compensation);
  IF row_count = 0 THEN
    INSERT INTO compensation VALUES
      ('EMP-0001', 104320, 114637, 0.91, '2024-08-06', 1.2),
      ('EMP-0002', 99169, 106633, 0.93, '2024-12-09', 5.1),
      ('EMP-0003', 109096, 122580, 0.89, '2024-01-26', 5.8),
      ('EMP-0004', 135486, 144134, 0.94, '2024-07-18', 2.8),
      ('EMP-0005', 93567, 100610, 0.93, '2024-04-19', 3.1),
      ('EMP-0006', 71542, 79491, 0.9, '2024-05-04', 1.3),
      ('EMP-0007', 103238, 109828, 0.94, '2025-05-31', 1),
      ('EMP-0008', 136452, 151613, 0.9, '2024-09-10', 3.4),
      ('EMP-0009', 95461, 104902, 0.91, '2024-10-19', 3.1),
      ('EMP-0010', 106003, 117781, 0.9, '2024-06-05', 2.9),
      ('EMP-0011', 127661, 145069, 0.88, '2025-03-06', 1.7),
      ('EMP-0012', 137312, 156036, 0.88, '2024-12-26', 2.7),
      ('EMP-0013', 106322, 118136, 0.9, '2025-03-22', 2),
      ('EMP-0014', 130596, 137469, 0.95, '2024-01-28', 4.1),
      ('EMP-0015', 95073, 100077, 0.95, '2024-12-04', 2.3),
      ('EMP-0016', 135882, 146110, 0.93, '2024-07-08', 3.6),
      ('EMP-0017', 110192, 123811, 0.89, '2024-08-20', 2.5),
      ('EMP-0018', 78254, 87926, 0.89, '2024-01-13', 2),
      ('EMP-0019', 72474, 77100, 0.94, '2025-02-14', 1.7),
      ('EMP-0020', 160453, 180284, 0.89, '2025-03-02', 1.6),
      ('EMP-0021', 152696, 169662, 0.9, '2024-03-02', 1.7),
      ('EMP-0022', 69783, 78408, 0.89, '2025-02-22', 1.7),
      ('EMP-0023', 132738, 150839, 0.88, '2024-08-27', 4.6),
      ('EMP-0024', 94599, 100637, 0.94, '2024-05-25', 3.5),
      ('EMP-0025', 161742, 177738, 0.91, '2024-11-07', 2.3),
      ('EMP-0026', 47423, 50992, 0.93, '2024-09-13', 3.7),
      ('EMP-0027', 100778, 109541, 0.92, '2025-03-28', 3.5),
      ('EMP-0028', 157877, 173491, 0.91, '2024-11-24', 2.1),
      ('EMP-0029', 66343, 75390, 0.88, '2024-03-31', 2.7),
      ('EMP-0030', 105414, 115840, 0.91, '2024-07-11', 1.6),
      ('EMP-0031', 74193, 78929, 0.94, '2025-03-24', 3.8),
      ('EMP-0032', 124775, 141790, 0.88, '2025-02-21', 5.6),
      ('EMP-0033', 111490, 121185, 0.92, '2024-10-06', 2),
      ('EMP-0034', 56937, 60571, 0.94, '2024-10-09', 3.3),
      ('EMP-0035', 65284, 69451, 0.94, '2025-04-02', 2.1),
      ('EMP-0036', 158528, 172313, 0.92, '2024-08-27', 3.6),
      ('EMP-0037', 70957, 77975, 0.91, '2024-02-07', 4.8),
      ('EMP-0038', 61160, 65763, 0.93, '2025-02-23', 4.8),
      ('EMP-0039', 65403, 70326, 0.93, '2024-12-02', 4.2),
      ('EMP-0040', 119433, 135719, 0.88, '2024-10-21', 4.7),
      ('EMP-0041', 74866, 79645, 0.94, '2024-02-17', 2.8),
      ('EMP-0042', 76517, 85974, 0.89, '2024-03-21', 2.2),
      ('EMP-0043', 71882, 78991, 0.91, '2024-01-10', 3.9),
      ('EMP-0044', 71681, 79646, 0.9, '2025-03-10', 2.6),
      ('EMP-0045', 51573, 56058, 0.92, '2024-10-29', 4.9),
      ('EMP-0046', 131725, 140133, 0.94, '2025-05-23', 4.1),
      ('EMP-0047', 65631, 72923, 0.9, '2024-05-20', 1.5),
      ('EMP-0048', 49801, 55956, 0.89, '2024-10-29', 2.5),
      ('EMP-0049', 136122, 147959, 0.92, '2024-10-06', 3.4),
      ('EMP-0050', 125505, 141017, 0.89, '2024-08-19', 4),
      ('EMP-0051', 121761, 132349, 0.92, '2025-04-10', 1.9),
      ('EMP-0052', 59074, 67130, 0.88, '2024-12-01', 3.6),
      ('EMP-0053', 97606, 110916, 0.88, '2024-02-08', 2.6),
      ('EMP-0054', 80488, 84724, 0.95, '2025-03-05', 1.6),
      ('EMP-0055', 94399, 101504, 0.93, '2024-08-10', 0.7),
      ('EMP-0056', 105694, 120107, 0.88, '2024-10-09', 3.2),
      ('EMP-0057', 103163, 117231, 0.88, '2024-12-07', 3),
      ('EMP-0058', 77592, 86213, 0.9, '2024-05-31', 3.3),
      ('EMP-0059', 68466, 73619, 0.93, '2024-01-27', 3.6),
      ('EMP-0060', 78469, 84375, 0.93, '2024-04-26', 3),
      ('EMP-0061', 92421, 105024, 0.88, '2024-11-04', 0.5),
      ('EMP-0062', 78360, 84258, 0.93, '2025-03-30', 3.4),
      ('EMP-0063', 75914, 82515, 0.92, '2024-11-28', 2),
      ('EMP-0064', 79589, 84669, 0.94, '2024-08-08', 1.1),
      ('EMP-0065', 79451, 88279, 0.9, '2024-11-16', 2.5),
      ('EMP-0066', 124441, 139821, 0.89, '2025-01-16', 3.5),
      ('EMP-0067', 92132, 98013, 0.94, '2025-03-09', 4.1),
      ('EMP-0068', 51074, 57387, 0.89, '2025-05-08', 3.1),
      ('EMP-0069', 103149, 108578, 0.95, '2024-01-27', 1.9),
      ('EMP-0070', 123824, 137582, 0.9, '2024-07-04', 3.9),
      ('EMP-0071', 51856, 56985, 0.91, '2025-04-09', 2.5),
      ('EMP-0072', 135392, 145583, 0.93, '2024-02-20', 2.6),
      ('EMP-0073', 71461, 77675, 0.92, '2024-12-19', 2.3),
      ('EMP-0074', 56160, 63818, 0.88, '2024-07-28', 2.8),
      ('EMP-0075', 57177, 64244, 0.89, '2025-01-24', 2.3),
      ('EMP-0076', 129020, 146614, 0.88, '2024-03-20', 3.8),
      ('EMP-0077', 70011, 73696, 0.95, '2024-06-24', 3.4),
      ('EMP-0078', 68420, 74370, 0.92, '2025-02-09', 4.1),
      ('EMP-0079', 50991, 55425, 0.92, '2024-07-17', 3.8),
      ('EMP-0080', 72417, 81367, 0.89, '2024-03-18', 3.8),
      ('EMP-0081', 140296, 149251, 0.94, '2024-11-26', 3.9),
      ('EMP-0082', 69709, 75771, 0.92, '2024-12-26', 2.1),
      ('EMP-0083', 129735, 141016, 0.92, '2025-01-28', 1.8),
      ('EMP-0084', 101968, 112053, 0.91, '2024-06-03', 4.1),
      ('EMP-0085', 54042, 56886, 0.95, '2024-06-11', 1.5),
      ('EMP-0086', 111251, 120925, 0.92, '2024-12-08', 3.4),
      ('EMP-0087', 131195, 142603, 0.92, '2024-05-24', 3.7),
      ('EMP-0088', 72847, 77497, 0.94, '2024-05-10', 2.1),
      ('EMP-0089', 89017, 98908, 0.9, '2024-08-07', 2.1),
      ('EMP-0090', 59764, 64262, 0.93, '2024-02-08', 1.9),
      ('EMP-0091', 66302, 71292, 0.93, '2024-06-18', 2.9),
      ('EMP-0092', 73530, 81700, 0.9, '2024-09-01', 2.3),
      ('EMP-0093', 171287, 184180, 0.93, '2025-05-29', 0.5),
      ('EMP-0094', 53510, 58163, 0.92, '2024-04-15', 2.7),
      ('EMP-0095', 69153, 73567, 0.94, '2024-04-03', 3.7),
      ('EMP-0096', 54220, 60244, 0.9, '2024-03-24', 2.8),
      ('EMP-0097', 55564, 61059, 0.91, '2024-05-22', 3.1),
      ('EMP-0098', 69382, 73034, 0.95, '2025-03-09', 3.6),
      ('EMP-0099', 77651, 88240, 0.88, '2025-05-26', 2.9),
      ('EMP-0100', 74480, 82756, 0.9, '2025-03-02', 3.6),
      ('EMP-0101', 109145, 124028, 0.88, '2025-04-26', 4),
      ('EMP-0102', 76336, 84818, 0.9, '2024-04-16', 3.2),
      ('EMP-0103', 89231, 94927, 0.94, '2025-04-20', 4.1),
      ('EMP-0104', 54543, 58024, 0.94, '2024-02-12', 2.7),
      ('EMP-0105', 57631, 64034, 0.9, '2024-02-18', 3.6),
      ('EMP-0106', 125528, 132135, 0.95, '2025-05-23', 2.7),
      ('EMP-0107', 124039, 134825, 0.92, '2024-07-03', 2.2),
      ('EMP-0108', 73759, 82875, 0.89, '2025-03-30', 2.8),
      ('EMP-0109', 101575, 109220, 0.93, '2025-02-19', 1.8),
      ('EMP-0110', 109071, 122552, 0.89, '2024-08-29', 3.2),
      ('EMP-0111', 70300, 77253, 0.91, '2024-03-19', 1.9),
      ('EMP-0112', 72250, 77688, 0.93, '2025-05-26', 0.8),
      ('EMP-0113', 128359, 142621, 0.9, '2025-05-17', 3.2),
      ('EMP-0114', 163426, 175727, 0.93, '2024-03-07', 2.2),
      ('EMP-0115', 128294, 144151, 0.89, '2024-07-24', 3.2),
      ('EMP-0116', 95270, 103554, 0.92, '2024-03-29', 3.9),
      ('EMP-0117', 132697, 139681, 0.95, '2024-03-16', 1.6),
      ('EMP-0118', 103112, 108539, 0.95, '2025-03-19', 1),
      ('EMP-0119', 74819, 83132, 0.9, '2024-10-17', 3.4),
      ('EMP-0120', 95828, 104161, 0.92, '2024-06-06', 3.7),
      ('EMP-0121', 59105, 67165, 0.88, '2024-09-28', 2),
      ('EMP-0122', 90747, 100830, 0.9, '2024-11-05', 1.2),
      ('EMP-0123', 101289, 111307, 0.91, '2025-04-20', 3.4),
      ('EMP-0124', 168730, 183402, 0.92, '2024-04-18', 2.5),
      ('EMP-0125', 58390, 62117, 0.94, '2025-03-04', 3),
      ('EMP-0126', 85011, 89485, 0.95, '2025-04-23', 2.1),
      ('EMP-0127', 100045, 108745, 0.92, '2024-02-19', 4.1),
      ('EMP-0128', 132433, 140886, 0.94, '2025-01-09', 3.1),
      ('EMP-0129', 70245, 78927, 0.89, '2025-05-31', 1.8),
      ('EMP-0130', 162585, 172963, 0.94, '2024-12-13', 2.1),
      ('EMP-0131', 73305, 83301, 0.88, '2024-12-07', 3.4),
      ('EMP-0132', 69292, 77856, 0.89, '2024-11-02', 2),
      ('EMP-0133', 71696, 79662, 0.9, '2024-04-22', 4.3),
      ('EMP-0134', 158888, 170847, 0.93, '2025-05-06', 3.7),
      ('EMP-0135', 59121, 66428, 0.89, '2025-03-27', 2.8),
      ('EMP-0136', 163519, 185817, 0.88, '2024-05-21', 1.7),
      ('EMP-0137', 158998, 176664, 0.9, '2024-09-27', 2.5),
      ('EMP-0138', 72916, 81018, 0.9, '2024-07-31', 2.6),
      ('EMP-0139', 69610, 75663, 0.92, '2025-02-08', 4),
      ('EMP-0140', 144927, 154178, 0.94, '2024-09-19', 3),
      ('EMP-0141', 52687, 57268, 0.92, '2024-09-05', 5.1),
      ('EMP-0142', 78403, 88093, 0.89, '2024-05-20', 4.3),
      ('EMP-0143', 100274, 111416, 0.9, '2024-03-01', 3.4),
      ('EMP-0144', 158422, 168534, 0.94, '2024-06-29', 3.2),
      ('EMP-0145', 129268, 140509, 0.92, '2024-04-19', 3.8),
      ('EMP-0146', 127383, 139981, 0.91, '2024-07-16', 3.3),
      ('EMP-0147', 52215, 56755, 0.92, '2024-07-16', 3.9),
      ('EMP-0148', 60858, 68380, 0.89, '2024-05-23', 0.7),
      ('EMP-0149', 76654, 85171, 0.9, '2024-01-12', 2.9),
      ('EMP-0150', 106277, 114276, 0.93, '2024-11-14', 2.5),
      ('EMP-0151', 68362, 76811, 0.89, '2025-01-17', 1.9),
      ('EMP-0152', 134245, 145918, 0.92, '2024-03-24', 1.8),
      ('EMP-0153', 54348, 61065, 0.89, '2024-06-02', 4),
      ('EMP-0154', 141247, 150263, 0.94, '2025-04-01', 3.4),
      ('EMP-0155', 51582, 55465, 0.93, '2025-02-09', 3),
      ('EMP-0156', 75388, 81943, 0.92, '2024-03-02', 3.3),
      ('EMP-0157', 74244, 81587, 0.91, '2025-01-26', 0.9),
      ('EMP-0158', 57364, 64454, 0.89, '2025-02-06', 1.4),
      ('EMP-0159', 158061, 169958, 0.93, '2025-03-10', 1.2),
      ('EMP-0160', 73144, 83118, 0.88, '2025-03-05', 1.2),
      ('EMP-0161', 49831, 54164, 0.92, '2024-02-19', 3),
      ('EMP-0162', 132004, 143483, 0.92, '2024-10-23', 3.2),
      ('EMP-0163', 144779, 160866, 0.9, '2024-05-26', 4.2),
      ('EMP-0164', 99274, 107907, 0.92, '2025-03-13', 2.7),
      ('EMP-0165', 74467, 83671, 0.89, '2025-01-20', 3.5),
      ('EMP-0166', 137579, 144820, 0.95, '2024-05-17', 2.4),
      ('EMP-0167', 56650, 64375, 0.88, '2025-01-21', 2.4),
      ('EMP-0168', 121961, 134023, 0.91, '2024-12-06', 2.3),
      ('EMP-0169', 143789, 154612, 0.93, '2024-07-28', 2.4),
      ('EMP-0170', 102982, 114424, 0.9, '2025-05-24', 1.2),
      ('EMP-0171', 76910, 81819, 0.94, '2024-05-29', 4.3),
      ('EMP-0172', 75646, 84051, 0.9, '2024-09-08', 1.5),
      ('EMP-0173', 160043, 175871, 0.91, '2024-06-21', 2.9),
      ('EMP-0174', 153824, 167200, 0.92, '2024-03-17', 4.4),
      ('EMP-0175', 53328, 59253, 0.9, '2025-04-11', 2),
      ('EMP-0176', 58306, 64073, 0.91, '2024-01-18', 2.2),
      ('EMP-0177', 129018, 137253, 0.94, '2024-06-01', 3.1),
      ('EMP-0178', 59628, 64813, 0.92, '2024-08-19', 2.4),
      ('EMP-0179', 83924, 95368, 0.88, '2024-01-10', 2.9),
      ('EMP-0180', 127351, 143091, 0.89, '2025-05-01', 2.7),
      ('EMP-0181', 86256, 90796, 0.95, '2024-05-27', 3),
      ('EMP-0182', 89472, 96206, 0.93, '2024-12-05', 1.8),
      ('EMP-0183', 58647, 62390, 0.94, '2024-12-14', 1.9),
      ('EMP-0184', 52178, 54924, 0.95, '2025-05-17', 3.2),
      ('EMP-0185', 108381, 120423, 0.9, '2024-09-09', 2.9),
      ('EMP-0186', 127315, 143051, 0.89, '2024-01-06', 4),
      ('EMP-0187', 73098, 79454, 0.92, '2025-02-21', 3.3),
      ('EMP-0188', 131746, 146384, 0.9, '2025-02-01', 3.3),
      ('EMP-0189', 67102, 75396, 0.89, '2024-11-04', 2.9),
      ('EMP-0190', 77790, 86433, 0.9, '2024-09-09', 2.8),
      ('EMP-0191', 51164, 56849, 0.9, '2025-01-24', 3.3),
      ('EMP-0192', 52190, 54937, 0.95, '2024-07-24', 2.4),
      ('EMP-0193', 160548, 176426, 0.91, '2025-02-06', 1.5),
      ('EMP-0194', 111596, 117469, 0.95, '2025-04-17', 3.6),
      ('EMP-0195', 98396, 109329, 0.9, '2024-09-15', 2.1),
      ('EMP-0196', 91126, 99050, 0.92, '2025-01-03', 2.5),
      ('EMP-0197', 88364, 95015, 0.93, '2024-02-15', 1.7),
      ('EMP-0198', 53144, 59049, 0.9, '2024-08-14', 2.1),
      ('EMP-0199', 162219, 180243, 0.9, '2024-03-28', 4.8),
      ('EMP-0200', 110559, 122843, 0.9, '2024-04-09', 1.6),
      ('EMP-0201', 133901, 142448, 0.94, '2024-04-21', 2.7),
      ('EMP-0202', 72312, 76118, 0.95, '2024-08-25', 3.4),
      ('EMP-0203', 121022, 131546, 0.92, '2025-02-02', 3.7),
      ('EMP-0204', 130130, 143000, 0.91, '2024-07-20', 2.2),
      ('EMP-0205', 101371, 110186, 0.92, '2024-12-22', 2.3),
      ('EMP-0206', 57957, 65120, 0.89, '2024-11-08', 3.7),
      ('EMP-0207', 104321, 114638, 0.91, '2025-05-13', 2),
      ('EMP-0208', 69217, 73635, 0.94, '2024-02-24', 4.6),
      ('EMP-0209', 147719, 162329, 0.91, '2025-05-18', 1.3),
      ('EMP-0210', 58226, 66166, 0.88, '2024-08-18', 2.4),
      ('EMP-0211', 99053, 111296, 0.89, '2025-01-10', 1.4),
      ('EMP-0212', 53536, 59484, 0.9, '2024-02-03', 2.1),
      ('EMP-0213', 131917, 140337, 0.94, '2024-12-25', 3.9),
      ('EMP-0214', 122987, 139758, 0.88, '2024-12-25', 1.7),
      ('EMP-0215', 73642, 77518, 0.95, '2024-04-07', 4.1),
      ('EMP-0216', 138355, 155455, 0.89, '2024-11-25', 3.8),
      ('EMP-0217', 90057, 98964, 0.91, '2024-03-18', 1.6),
      ('EMP-0218', 89778, 94503, 0.95, '2024-12-01', 1.2),
      ('EMP-0219', 123381, 137090, 0.9, '2025-03-15', 3.5),
      ('EMP-0220', 93056, 103396, 0.9, '2024-02-19', 4.3),
      ('EMP-0221', 76997, 86513, 0.89, '2024-05-15', 3.6),
      ('EMP-0222', 72140, 81977, 0.88, '2024-11-08', 2.7),
      ('EMP-0223', 49471, 55585, 0.89, '2024-08-19', 1.9),
      ('EMP-0224', 159118, 178784, 0.89, '2024-03-13', 3.1),
      ('EMP-0225', 132859, 142859, 0.93, '2024-05-16', 2.1),
      ('EMP-0226', 92213, 102459, 0.9, '2024-08-06', 2.6),
      ('EMP-0227', 127247, 142974, 0.89, '2024-05-06', 2.2),
      ('EMP-0228', 72374, 80416, 0.9, '2024-10-18', 3.3),
      ('EMP-0229', 89959, 99954, 0.9, '2024-02-25', 3.4),
      ('EMP-0230', 66315, 72082, 0.92, '2024-01-13', 5.3),
      ('EMP-0231', 74040, 83191, 0.89, '2025-04-27', 4.6),
      ('EMP-0232', 72579, 76399, 0.95, '2025-02-11', 1.6),
      ('EMP-0233', 54805, 60894, 0.9, '2024-11-13', 5),
      ('EMP-0234', 107154, 119060, 0.9, '2025-03-23', 2.8),
      ('EMP-0235', 48598, 55225, 0.88, '2024-06-28', 4.1),
      ('EMP-0236', 107133, 120374, 0.89, '2024-05-09', 3),
      ('EMP-0237', 64833, 69713, 0.93, '2024-03-19', 1.8),
      ('EMP-0238', 75145, 80801, 0.93, '2024-04-28', 3.2),
      ('EMP-0239', 107877, 121210, 0.89, '2024-02-06', 0.9),
      ('EMP-0240', 71389, 79321, 0.9, '2024-03-20', 2.5),
      ('EMP-0241', 158539, 168659, 0.94, '2024-10-16', 3.1),
      ('EMP-0242', 70734, 76058, 0.93, '2024-09-05', 1.7),
      ('EMP-0243', 132005, 150006, 0.88, '2025-02-23', 4.2),
      ('EMP-0244', 131246, 147467, 0.89, '2024-08-31', 0.8),
      ('EMP-0245', 168204, 180865, 0.93, '2025-01-16', 1.4),
      ('EMP-0246', 102856, 111800, 0.92, '2024-03-04', 0.6),
      ('EMP-0247', 166835, 185372, 0.9, '2024-10-05', 3.2),
      ('EMP-0248', 62950, 69944, 0.9, '2024-05-03', 0.5),
      ('EMP-0249', 72107, 81019, 0.89, '2024-11-07', 3.7),
      ('EMP-0250', 50432, 53086, 0.95, '2025-02-09', 1.5),
      ('EMP-0251', 129153, 143503, 0.9, '2025-04-18', 4.4),
      ('EMP-0252', 58539, 62945, 0.93, '2024-03-27', 2.3),
      ('EMP-0253', 157449, 176909, 0.89, '2024-12-05', 4.7),
      ('EMP-0254', 141083, 160322, 0.88, '2025-03-12', 3.3),
      ('EMP-0255', 134101, 144195, 0.93, '2025-05-25', 1.9),
      ('EMP-0256', 57215, 62190, 0.92, '2024-01-20', 4.7),
      ('EMP-0257', 74419, 82688, 0.9, '2024-10-03', 3.4),
      ('EMP-0258', 57642, 63343, 0.91, '2024-08-26', 3.5),
      ('EMP-0259', 129502, 137768, 0.94, '2025-02-01', 1.8),
      ('EMP-0260', 82561, 90726, 0.91, '2024-01-29', 2.7),
      ('EMP-0261', 154057, 171174, 0.9, '2025-05-17', 3.3),
      ('EMP-0262', 100536, 112962, 0.89, '2024-05-13', 2.7),
      ('EMP-0263', 103508, 110115, 0.94, '2025-01-08', 3.9),
      ('EMP-0264', 73814, 79370, 0.93, '2025-03-23', 3.7),
      ('EMP-0265', 83624, 92916, 0.9, '2024-06-28', 1.8),
      ('EMP-0266', 167507, 178199, 0.94, '2024-02-03', 3.4),
      ('EMP-0267', 57656, 64062, 0.9, '2024-03-20', 3.2),
      ('EMP-0268', 89170, 99078, 0.9, '2024-03-10', 2),
      ('EMP-0269', 139465, 153258, 0.91, '2025-01-22', 2.4),
      ('EMP-0270', 78902, 87669, 0.9, '2024-11-22', 3),
      ('EMP-0271', 133128, 147920, 0.9, '2025-05-09', 2.7),
      ('EMP-0272', 51602, 54318, 0.95, '2025-02-23', 2.5),
      ('EMP-0273', 67435, 74104, 0.91, '2025-05-17', 3.5),
      ('EMP-0274', 105185, 118185, 0.89, '2024-10-25', 4.1),
      ('EMP-0275', 98915, 111140, 0.89, '2025-01-31', 3.8),
      ('EMP-0276', 84550, 93944, 0.9, '2024-10-02', 2.5),
      ('EMP-0277', 128501, 142779, 0.9, '2024-03-03', 4),
      ('EMP-0278', 67227, 76394, 0.88, '2024-05-30', 4.2),
      ('EMP-0279', 58846, 61943, 0.95, '2025-03-21', 3.6),
      ('EMP-0280', 171836, 188831, 0.91, '2025-02-10', 1.1),
      ('EMP-0281', 125779, 136716, 0.92, '2025-03-05', 3.4),
      ('EMP-0282', 162466, 182546, 0.89, '2024-10-19', 4.4),
      ('EMP-0283', 89842, 100946, 0.89, '2025-02-16', 3.8),
      ('EMP-0284', 107175, 114016, 0.94, '2025-01-16', 4.8),
      ('EMP-0285', 131559, 138483, 0.95, '2024-08-21', 4.8),
      ('EMP-0286', 113480, 124703, 0.91, '2025-02-20', 2.9),
      ('EMP-0287', 49382, 54266, 0.91, '2024-01-30', 3.9),
      ('EMP-0288', 112069, 125920, 0.89, '2025-01-12', 3.5),
      ('EMP-0289', 92921, 97812, 0.95, '2025-04-30', 2.2),
      ('EMP-0290', 72592, 81564, 0.89, '2024-08-07', 3.9),
      ('EMP-0291', 92473, 101619, 0.91, '2024-05-15', 2.2),
      ('EMP-0292', 122776, 134919, 0.91, '2025-01-20', 3.7),
      ('EMP-0293', 124065, 140983, 0.88, '2025-01-18', 1.8),
      ('EMP-0294', 96630, 105033, 0.92, '2024-10-10', 2.9),
      ('EMP-0295', 140480, 154374, 0.91, '2024-11-23', 2.3),
      ('EMP-0296', 67752, 73643, 0.92, '2024-07-13', 2.1),
      ('EMP-0297', 108784, 122229, 0.89, '2024-04-09', 1.4),
      ('EMP-0298', 102000, 113333, 0.9, '2024-11-10', 1.2),
      ('EMP-0299', 106668, 121214, 0.88, '2024-03-13', 2.4),
      ('EMP-0300', 75571, 79548, 0.95, '2024-12-16', 1.9),
      ('EMP-0301', 104674, 116304, 0.9, '2024-02-29', 3.8),
      ('EMP-0302', 100158, 108867, 0.92, '2025-03-15', 0.9),
      ('EMP-0303', 82395, 87654, 0.94, '2024-07-14', 3.1),
      ('EMP-0304', 75051, 81577, 0.92, '2024-11-09', 3.9),
      ('EMP-0305', 110773, 117844, 0.94, '2024-05-17', 1.8),
      ('EMP-0306', 60991, 64201, 0.95, '2024-08-04', 2.9),
      ('EMP-0307', 68359, 73504, 0.93, '2024-02-19', 2.7),
      ('EMP-0308', 74128, 80574, 0.92, '2025-04-30', 2.8),
      ('EMP-0309', 95683, 105146, 0.91, '2024-04-17', 1.6),
      ('EMP-0310', 99328, 106804, 0.93, '2024-07-25', 2.4),
      ('EMP-0311', 165331, 183701, 0.9, '2024-01-03', 3.4),
      ('EMP-0312', 55115, 61927, 0.89, '2024-04-13', 4.2),
      ('EMP-0313', 52300, 55638, 0.94, '2025-01-03', 3.3),
      ('EMP-0314', 52264, 56198, 0.93, '2024-12-02', 2.3),
      ('EMP-0315', 79187, 88974, 0.89, '2025-02-13', 3.8),
      ('EMP-0316', 98754, 110960, 0.89, '2024-03-01', 4.9),
      ('EMP-0317', 128514, 144398, 0.89, '2025-01-23', 3.3),
      ('EMP-0318', 120988, 137486, 0.88, '2024-11-17', 5),
      ('EMP-0319', 75781, 82371, 0.92, '2024-04-07', 1.5),
      ('EMP-0320', 57199, 64999, 0.88, '2024-06-09', 1.9),
      ('EMP-0321', 74803, 85003, 0.88, '2024-08-16', 2.1),
      ('EMP-0322', 127971, 136139, 0.94, '2025-04-02', 1.9),
      ('EMP-0323', 63569, 67627, 0.94, '2024-11-07', 4),
      ('EMP-0324', 124542, 135372, 0.92, '2025-04-29', 2.8),
      ('EMP-0325', 51902, 56415, 0.92, '2025-01-17', 2.9),
      ('EMP-0326', 54025, 60702, 0.89, '2025-02-06', 3.4),
      ('EMP-0327', 61074, 68622, 0.89, '2025-04-06', 1.7),
      ('EMP-0328', 102353, 108886, 0.94, '2025-05-09', 4.5),
      ('EMP-0329', 52342, 56893, 0.92, '2024-11-25', 2),
      ('EMP-0330', 159830, 170032, 0.94, '2024-05-21', 1.7),
      ('EMP-0331', 135392, 142518, 0.95, '2024-08-10', 3.4),
      ('EMP-0332', 168886, 183572, 0.92, '2024-11-26', 2.6),
      ('EMP-0333', 149072, 160292, 0.93, '2024-10-19', 3.8),
      ('EMP-0334', 71354, 80173, 0.89, '2024-06-13', 4.5),
      ('EMP-0335', 74217, 81557, 0.91, '2025-04-08', 4.6),
      ('EMP-0336', 81041, 87141, 0.93, '2024-02-18', 3.9),
      ('EMP-0337', 127058, 135168, 0.94, '2025-03-29', 4.1),
      ('EMP-0338', 65351, 72612, 0.9, '2024-06-30', 3.4),
      ('EMP-0339', 54864, 60960, 0.9, '2024-06-13', 2.3),
      ('EMP-0340', 53712, 61036, 0.88, '2024-11-04', 1.7),
      ('EMP-0341', 100516, 114223, 0.88, '2025-06-01', 3.7),
      ('EMP-0342', 137027, 152252, 0.9, '2024-10-27', 3.3),
      ('EMP-0343', 60463, 67181, 0.9, '2024-09-06', 4.5),
      ('EMP-0344', 73066, 81184, 0.9, '2025-01-18', 1.8),
      ('EMP-0345', 74465, 83669, 0.89, '2024-01-08', 2.5),
      ('EMP-0346', 72538, 77998, 0.93, '2024-03-14', 3),
      ('EMP-0347', 53074, 57689, 0.92, '2024-08-21', 3.9),
      ('EMP-0348', 53190, 57815, 0.92, '2024-03-05', 3),
      ('EMP-0349', 68368, 74313, 0.92, '2024-10-15', 3.1),
      ('EMP-0350', 92880, 98809, 0.94, '2024-10-29', 3.5),
      ('EMP-0351', 54539, 59282, 0.92, '2025-02-07', 0.6),
      ('EMP-0352', 72197, 81120, 0.89, '2024-07-07', 3.3),
      ('EMP-0353', 142438, 153159, 0.93, '2024-03-15', 2.9),
      ('EMP-0354', 102409, 115066, 0.89, '2024-08-28', 4.1),
      ('EMP-0355', 79087, 85040, 0.93, '2024-06-05', 2.1),
      ('EMP-0356', 73094, 78596, 0.93, '2025-03-22', 2.8),
      ('EMP-0357', 79653, 86579, 0.92, '2024-06-28', 2.7),
      ('EMP-0358', 73362, 78884, 0.93, '2024-01-20', 3.8),
      ('EMP-0359', 69272, 75296, 0.92, '2025-04-28', 2.7),
      ('EMP-0360', 126887, 139436, 0.91, '2024-04-02', 2.1),
      ('EMP-0361', 134756, 151411, 0.89, '2024-05-29', 2.9),
      ('EMP-0362', 69275, 76972, 0.9, '2024-07-30', 1.2),
      ('EMP-0363', 54338, 61054, 0.89, '2024-10-07', 3.4),
      ('EMP-0364', 95512, 102701, 0.93, '2024-03-20', 2),
      ('EMP-0365', 129323, 137578, 0.94, '2024-01-07', 2.5),
      ('EMP-0366', 99958, 112312, 0.89, '2025-01-05', 1.5),
      ('EMP-0367', 122653, 134784, 0.91, '2024-08-03', 1.8),
      ('EMP-0368', 52401, 58878, 0.89, '2024-02-10', 3.4),
      ('EMP-0369', 157619, 171325, 0.92, '2024-10-17', 3.7),
      ('EMP-0370', 73863, 82992, 0.89, '2024-07-05', 2.1),
      ('EMP-0371', 94427, 103766, 0.91, '2024-04-21', 4.2),
      ('EMP-0372', 100842, 107279, 0.94, '2024-02-09', 3.9),
      ('EMP-0373', 154297, 164146, 0.94, '2025-03-17', 2),
      ('EMP-0374', 159115, 176794, 0.9, '2024-04-10', 2.3),
      ('EMP-0375', 132306, 148658, 0.89, '2024-01-08', 2.6),
      ('EMP-0376', 98429, 108164, 0.91, '2024-06-07', 1.8),
      ('EMP-0377', 77972, 83841, 0.93, '2025-02-27', 1.8),
      ('EMP-0378', 97262, 108069, 0.9, '2025-02-11', 2.8),
      ('EMP-0379', 48475, 51569, 0.94, '2024-02-23', 4.4),
      ('EMP-0380', 114591, 128754, 0.89, '2024-09-26', 3.1),
      ('EMP-0381', 102680, 108084, 0.95, '2024-06-28', 2.3),
      ('EMP-0382', 52234, 56776, 0.92, '2024-02-06', 2.1),
      ('EMP-0383', 80628, 87639, 0.92, '2024-01-16', 3),
      ('EMP-0384', 157495, 165784, 0.95, '2024-10-10', 3.4),
      ('EMP-0385', 87700, 98539, 0.89, '2024-03-15', 2.1),
      ('EMP-0386', 129879, 139655, 0.93, '2025-01-21', 1.4),
      ('EMP-0387', 125582, 141103, 0.89, '2024-03-10', 1.7),
      ('EMP-0388', 80926, 87963, 0.92, '2024-09-26', 3),
      ('EMP-0389', 102946, 109517, 0.94, '2024-10-02', 3.7),
      ('EMP-0390', 82552, 92755, 0.89, '2024-07-26', 4),
      ('EMP-0391', 49540, 52147, 0.95, '2025-05-19', 1.7),
      ('EMP-0392', 69426, 73857, 0.94, '2024-10-08', 0.5),
      ('EMP-0393', 131110, 142511, 0.92, '2025-03-09', 1.8),
      ('EMP-0394', 101129, 112366, 0.9, '2024-01-09', 3.7),
      ('EMP-0395', 100340, 109065, 0.92, '2024-08-30', 2.7),
      ('EMP-0396', 87521, 94109, 0.93, '2025-01-08', 3.5),
      ('EMP-0397', 95720, 106356, 0.9, '2024-08-29', 1.1),
      ('EMP-0398', 95525, 104973, 0.91, '2024-05-17', 4.9),
      ('EMP-0399', 129638, 140911, 0.92, '2024-02-18', 1.8),
      ('EMP-0400', 106084, 116576, 0.91, '2024-12-08', 2.9),
      ('EMP-0401', 79717, 86649, 0.92, '2024-06-27', 3.8),
      ('EMP-0402', 129295, 142082, 0.91, '2024-05-28', 4),
      ('EMP-0403', 92977, 104469, 0.89, '2024-08-21', 2.4),
      ('EMP-0404', 81704, 87854, 0.93, '2025-04-06', 2.5),
      ('EMP-0405', 102187, 114817, 0.89, '2025-02-10', 3.3),
      ('EMP-0406', 131460, 147708, 0.89, '2024-06-08', 5),
      ('EMP-0407', 137802, 154834, 0.89, '2024-06-23', 4.5),
      ('EMP-0408', 161757, 181749, 0.89, '2024-06-30', 2.1),
      ('EMP-0409', 72017, 78279, 0.92, '2024-04-01', 2.1),
      ('EMP-0410', 56136, 62373, 0.9, '2024-01-09', 2.6),
      ('EMP-0411', 122827, 130667, 0.94, '2025-01-17', 3.8),
      ('EMP-0412', 142773, 151886, 0.94, '2024-08-13', 2.9),
      ('EMP-0413', 136960, 152178, 0.9, '2024-10-02', 1.3),
      ('EMP-0414', 106799, 117362, 0.91, '2024-11-24', 3.3),
      ('EMP-0415', 75194, 82631, 0.91, '2024-01-09', 3.1),
      ('EMP-0416', 77841, 85540, 0.91, '2024-02-02', 2.1),
      ('EMP-0417', 60621, 68113, 0.89, '2024-09-13', 3.8),
      ('EMP-0418', 66440, 73011, 0.91, '2024-04-06', 0.5),
      ('EMP-0419', 157495, 169349, 0.93, '2024-05-05', 3),
      ('EMP-0420', 169508, 188342, 0.9, '2024-06-20', 3.4),
      ('EMP-0421', 91504, 98391, 0.93, '2024-06-07', 2.7),
      ('EMP-0422', 76565, 87006, 0.88, '2024-06-06', 2.5),
      ('EMP-0423', 148743, 158237, 0.94, '2025-03-25', 3),
      ('EMP-0424', 73967, 79534, 0.93, '2024-10-28', 1.9),
      ('EMP-0425', 73460, 78149, 0.94, '2024-06-13', 3.5),
      ('EMP-0426', 101623, 111674, 0.91, '2024-07-08', 4),
      ('EMP-0427', 123779, 131680, 0.94, '2024-07-13', 1.8),
      ('EMP-0428', 74116, 83276, 0.89, '2024-03-09', 5.3),
      ('EMP-0429', 104268, 113335, 0.92, '2025-02-01', 2.3),
      ('EMP-0430', 69886, 79416, 0.88, '2024-08-01', 1.7),
      ('EMP-0431', 65473, 69652, 0.94, '2024-02-29', 3.4),
      ('EMP-0432', 52655, 59163, 0.89, '2024-08-24', 2.4),
      ('EMP-0433', 99146, 106609, 0.93, '2025-01-01', 2.3),
      ('EMP-0434', 90765, 97597, 0.93, '2025-03-29', 5),
      ('EMP-0435', 70624, 75132, 0.94, '2024-11-27', 2),
      ('EMP-0436', 154597, 162734, 0.95, '2025-04-03', 3),
      ('EMP-0437', 99967, 111074, 0.9, '2024-08-15', 3.2),
      ('EMP-0438', 105657, 118716, 0.89, '2025-04-16', 2.7),
      ('EMP-0439', 77150, 83859, 0.92, '2024-08-10', 2.8),
      ('EMP-0440', 119361, 135638, 0.88, '2025-01-25', 3.3),
      ('EMP-0441', 75803, 81509, 0.93, '2024-01-12', 2.1),
      ('EMP-0442', 69728, 77476, 0.9, '2024-08-14', 3.9),
      ('EMP-0443', 108187, 118887, 0.91, '2025-02-07', 3.5),
      ('EMP-0444', 57419, 61741, 0.93, '2024-05-13', 3.1),
      ('EMP-0445', 69291, 76990, 0.9, '2024-09-29', 3.1),
      ('EMP-0446', 70643, 78492, 0.9, '2024-01-25', 3.1),
      ('EMP-0447', 95971, 102097, 0.94, '2024-08-27', 3.3),
      ('EMP-0448', 79598, 84679, 0.94, '2024-10-21', 4.5),
      ('EMP-0449', 55442, 62294, 0.89, '2024-09-21', 1.7),
      ('EMP-0450', 157189, 174654, 0.9, '2024-03-02', 2.6),
      ('EMP-0451', 111496, 122523, 0.91, '2024-10-04', 1.9),
      ('EMP-0452', 117419, 130466, 0.9, '2025-01-24', 1.4),
      ('EMP-0453', 99438, 108085, 0.92, '2025-04-13', 1.5),
      ('EMP-0454', 72062, 80969, 0.89, '2024-12-21', 2.6),
      ('EMP-0455', 124277, 132210, 0.94, '2024-01-31', 5.3),
      ('EMP-0456', 94406, 102615, 0.92, '2024-08-20', 1.9),
      ('EMP-0457', 78237, 84126, 0.93, '2024-07-26', 3.6),
      ('EMP-0458', 95643, 106270, 0.9, '2024-05-01', 3.8),
      ('EMP-0459', 141676, 157418, 0.9, '2024-10-07', 3.4),
      ('EMP-0460', 103511, 112512, 0.92, '2024-08-25', 3),
      ('EMP-0461', 131522, 141422, 0.93, '2024-07-07', 3.7),
      ('EMP-0462', 51895, 54626, 0.95, '2024-08-15', 2.9),
      ('EMP-0463', 110149, 122388, 0.9, '2025-04-13', 3.8),
      ('EMP-0464', 125430, 132032, 0.95, '2024-02-09', 1.9),
      ('EMP-0465', 74291, 80751, 0.92, '2024-02-20', 3.4),
      ('EMP-0466', 80001, 86023, 0.93, '2024-05-25', 1.6),
      ('EMP-0467', 132180, 148517, 0.89, '2025-02-27', 2.9),
      ('EMP-0468', 131341, 145934, 0.9, '2024-06-16', 2.9),
      ('EMP-0469', 53322, 57335, 0.93, '2024-06-12', 2.3),
      ('EMP-0470', 78380, 84280, 0.93, '2024-02-22', 2.2),
      ('EMP-0471', 56389, 64078, 0.88, '2024-09-16', 4.2),
      ('EMP-0472', 100599, 111777, 0.9, '2025-05-02', 2),
      ('EMP-0473', 132063, 143547, 0.92, '2024-07-31', 3.5),
      ('EMP-0474', 101143, 112381, 0.9, '2024-03-30', 4),
      ('EMP-0475', 102100, 110978, 0.92, '2024-06-30', 4.6),
      ('EMP-0476', 73252, 78766, 0.93, '2024-03-07', 2.9),
      ('EMP-0477', 103455, 112451, 0.92, '2024-04-21', 0.5),
      ('EMP-0478', 151949, 166977, 0.91, '2024-11-20', 2.9),
      ('EMP-0479', 108707, 118160, 0.92, '2025-05-19', 3.7),
      ('EMP-0480', 48540, 51638, 0.94, '2024-07-31', 4.1),
      ('EMP-0481', 80000, 90909, 0.88, '2024-07-25', 2.7),
      ('EMP-0482', 95250, 102419, 0.93, '2024-12-15', 2),
      ('EMP-0483', 135256, 143889, 0.94, '2024-02-06', 2.3),
      ('EMP-0484', 153943, 167329, 0.92, '2024-11-19', 2.8),
      ('EMP-0485', 54780, 58277, 0.94, '2024-12-13', 4.4),
      ('EMP-0486', 74279, 79870, 0.93, '2024-11-18', 2.8),
      ('EMP-0487', 94862, 103111, 0.92, '2024-06-28', 4.3),
      ('EMP-0488', 58788, 66054, 0.89, '2025-05-10', 2.9),
      ('EMP-0489', 121930, 128347, 0.95, '2024-07-29', 2.8),
      ('EMP-0490', 152700, 162447, 0.94, '2024-12-07', 2.7),
      ('EMP-0491', 130423, 144914, 0.9, '2024-07-16', 2.7),
      ('EMP-0492', 81002, 85265, 0.95, '2024-04-14', 3.3),
      ('EMP-0493', 105963, 117737, 0.9, '2024-12-12', 2.7),
      ('EMP-0494', 54729, 60142, 0.91, '2024-07-02', 2.4),
      ('EMP-0495', 64891, 68306, 0.95, '2025-04-21', 2.6),
      ('EMP-0496', 98784, 108554, 0.91, '2024-08-17', 4.3),
      ('EMP-0497', 111130, 118223, 0.94, '2024-11-28', 2.8),
      ('EMP-0498', 100478, 108041, 0.93, '2024-05-10', 2),
      ('EMP-0499', 129660, 142484, 0.91, '2025-02-27', 3.1),
      ('EMP-0500', 78727, 84653, 0.93, '2025-03-21', 2.2),
      ('EMP-0501', 127499, 135637, 0.94, '2024-04-27', 2.1),
      ('EMP-0502', 71949, 78205, 0.92, '2025-01-23', 2.3),
      ('EMP-0503', 138482, 148905, 0.93, '2024-06-01', 2.2),
      ('EMP-0504', 76209, 82836, 0.92, '2024-11-07', 5),
      ('EMP-0505', 92326, 98219, 0.94, '2024-10-28', 5),
      ('EMP-0506', 135480, 144128, 0.94, '2024-02-01', 3.1),
      ('EMP-0507', 82749, 92976, 0.89, '2024-06-26', 2.4),
      ('EMP-0508', 75508, 84840, 0.89, '2024-03-14', 2.7),
      ('EMP-0509', 53507, 56922, 0.94, '2025-03-11', 2.2),
      ('EMP-0510', 71151, 78188, 0.91, '2024-01-08', 1.3),
      ('EMP-0511', 153926, 174916, 0.88, '2024-02-08', 1.6),
      ('EMP-0512', 52838, 58064, 0.91, '2024-03-21', 1.6),
      ('EMP-0513', 98662, 109624, 0.9, '2024-02-24', 4),
      ('EMP-0514', 155302, 170662, 0.91, '2024-10-28', 2.9),
      ('EMP-0515', 76301, 82936, 0.92, '2024-02-22', 2.5),
      ('EMP-0516', 52697, 56061, 0.94, '2024-10-11', 3),
      ('EMP-0517', 109220, 117441, 0.93, '2025-01-13', 3.3),
      ('EMP-0518', 125151, 131738, 0.95, '2024-06-06', 3.9),
      ('EMP-0519', 120501, 130979, 0.92, '2024-12-19', 3.7),
      ('EMP-0520', 76312, 82056, 0.93, '2024-08-27', 1.9),
      ('EMP-0521', 137146, 145900, 0.94, '2025-04-04', 2.4),
      ('EMP-0522', 103921, 110554, 0.94, '2024-10-06', 2.6),
      ('EMP-0523', 78393, 84294, 0.93, '2024-07-18', 1.5),
      ('EMP-0524', 98746, 108512, 0.91, '2024-04-16', 2.6),
      ('EMP-0525', 52149, 54894, 0.95, '2024-08-10', 4.4),
      ('EMP-0526', 53545, 56963, 0.94, '2024-07-08', 4.2),
      ('EMP-0527', 93749, 100805, 0.93, '2024-11-27', 2.9),
      ('EMP-0528', 83701, 88106, 0.95, '2024-09-28', 3.2),
      ('EMP-0529', 102274, 111167, 0.92, '2025-03-17', 3.3),
      ('EMP-0530', 59692, 64185, 0.93, '2024-01-20', 3.5),
      ('EMP-0531', 73281, 77959, 0.94, '2024-01-04', 0.6),
      ('EMP-0532', 128474, 145993, 0.88, '2025-05-08', 3.9),
      ('EMP-0533', 79271, 87111, 0.91, '2024-12-14', 4),
      ('EMP-0534', 56791, 63810, 0.89, '2025-02-03', 4.1),
      ('EMP-0535', 124302, 139665, 0.89, '2024-09-01', 2.6),
      ('EMP-0536', 160163, 182003, 0.88, '2024-02-27', 2.2),
      ('EMP-0537', 109075, 122556, 0.89, '2024-08-26', 3.2),
      ('EMP-0538', 99168, 110187, 0.9, '2024-05-13', 4.4),
      ('EMP-0539', 75638, 80466, 0.94, '2024-04-18', 4),
      ('EMP-0540', 79420, 88244, 0.9, '2024-05-20', 1.9),
      ('EMP-0541', 86644, 97353, 0.89, '2025-03-01', 3.5),
      ('EMP-0542', 57788, 62813, 0.92, '2024-06-10', 4.1),
      ('EMP-0543', 130755, 143687, 0.91, '2025-05-02', 2.8),
      ('EMP-0544', 71823, 78068, 0.92, '2025-05-26', 2.7),
      ('EMP-0545', 98148, 103314, 0.95, '2024-04-07', 1.5),
      ('EMP-0546', 120971, 134412, 0.9, '2024-07-17', 3.4),
      ('EMP-0547', 102465, 110177, 0.93, '2024-10-18', 3.2),
      ('EMP-0548', 134910, 151584, 0.89, '2024-01-30', 2.5),
      ('EMP-0549', 75233, 80896, 0.93, '2024-11-29', 3.1),
      ('EMP-0550', 133195, 149657, 0.89, '2025-05-11', 4),
      ('EMP-0551', 76791, 82571, 0.93, '2025-01-02', 3.7),
      ('EMP-0552', 54657, 58146, 0.94, '2025-04-14', 1.5),
      ('EMP-0553', 135539, 144190, 0.94, '2024-08-23', 4.7),
      ('EMP-0554', 136797, 147094, 0.93, '2024-09-09', 3),
      ('EMP-0555', 137115, 155812, 0.88, '2025-04-26', 2.9),
      ('EMP-0556', 122145, 134225, 0.91, '2024-09-03', 4.4),
      ('EMP-0557', 79170, 89966, 0.88, '2024-11-08', 3.6),
      ('EMP-0558', 106286, 119422, 0.89, '2025-01-14', 1.9),
      ('EMP-0559', 92562, 99529, 0.93, '2024-07-31', 3.1),
      ('EMP-0560', 127337, 139931, 0.91, '2024-02-11', 2.6),
      ('EMP-0561', 56547, 61464, 0.92, '2025-05-04', 2.9),
      ('EMP-0562', 118898, 132109, 0.9, '2024-03-05', 2.2),
      ('EMP-0563', 105244, 111962, 0.94, '2024-10-26', 2.1),
      ('EMP-0564', 55949, 58894, 0.95, '2024-03-19', 3.6),
      ('EMP-0565', 103398, 114887, 0.9, '2024-05-15', 2),
      ('EMP-0566', 55568, 59751, 0.93, '2025-02-25', 1.7),
      ('EMP-0567', 125379, 139310, 0.9, '2024-05-15', 3.7),
      ('EMP-0568', 156598, 173998, 0.9, '2025-04-11', 4.3),
      ('EMP-0569', 157485, 176949, 0.89, '2024-04-29', 3.8),
      ('EMP-0570', 76116, 81845, 0.93, '2024-12-18', 3.7),
      ('EMP-0571', 165828, 178310, 0.93, '2025-04-14', 3.5),
      ('EMP-0572', 98298, 104572, 0.94, '2025-03-28', 2.7),
      ('EMP-0573', 56381, 61284, 0.92, '2024-08-13', 2.6),
      ('EMP-0574', 100978, 113458, 0.89, '2024-03-26', 1.9),
      ('EMP-0575', 98270, 104543, 0.94, '2025-01-04', 1.7),
      ('EMP-0576', 58174, 64638, 0.9, '2025-04-01', 3.3),
      ('EMP-0577', 73479, 79010, 0.93, '2025-02-28', 3.9),
      ('EMP-0578', 106818, 121384, 0.88, '2025-01-19', 3.9),
      ('EMP-0579', 103610, 116416, 0.89, '2025-01-25', 2.7),
      ('EMP-0580', 107506, 122166, 0.88, '2024-01-03', 3.5),
      ('EMP-0581', 78479, 89181, 0.88, '2024-10-10', 0.5),
      ('EMP-0582', 100773, 108358, 0.93, '2024-05-02', 1.9),
      ('EMP-0583', 58873, 62631, 0.94, '2024-05-18', 2.8),
      ('EMP-0584', 55858, 60715, 0.92, '2024-03-19', 1.3),
      ('EMP-0585', 99011, 105331, 0.94, '2024-10-04', 2.4),
      ('EMP-0586', 120646, 131137, 0.92, '2025-01-16', 3.2),
      ('EMP-0587', 93242, 101350, 0.92, '2024-04-26', 1.1),
      ('EMP-0588', 80524, 90476, 0.89, '2025-03-28', 4),
      ('EMP-0589', 52127, 58570, 0.89, '2024-05-25', 2.7),
      ('EMP-0590', 94713, 107628, 0.88, '2025-05-10', 3),
      ('EMP-0591', 98037, 104295, 0.94, '2024-02-14', 4.4),
      ('EMP-0592', 104001, 111829, 0.93, '2024-01-30', 4.6),
      ('EMP-0593', 80221, 87197, 0.92, '2024-03-10', 4.1),
      ('EMP-0594', 165108, 187623, 0.88, '2024-04-11', 5),
      ('EMP-0595', 69844, 78476, 0.89, '2024-12-29', 4),
      ('EMP-0596', 129179, 141955, 0.91, '2024-05-19', 2.1),
      ('EMP-0597', 55083, 60531, 0.91, '2025-04-12', 2.3),
      ('EMP-0598', 72450, 77074, 0.94, '2025-05-02', 3.9),
      ('EMP-0599', 73213, 82262, 0.89, '2025-02-08', 1.9),
      ('EMP-0600', 165208, 179574, 0.92, '2025-02-17', 4.4),
      ('EMP-0601', 108869, 120966, 0.9, '2025-02-18', 4.2),
      ('EMP-0602', 74531, 81012, 0.92, '2024-05-17', 4.6),
      ('EMP-0603', 162025, 174220, 0.93, '2024-06-05', 2.5),
      ('EMP-0604', 138808, 149256, 0.93, '2025-05-17', 1.8),
      ('EMP-0605', 159749, 175548, 0.91, '2025-01-20', 2.7),
      ('EMP-0606', 130637, 143557, 0.91, '2024-11-15', 2.8),
      ('EMP-0607', 92470, 100511, 0.92, '2025-05-02', 2.5),
      ('EMP-0608', 98518, 105933, 0.93, '2024-10-18', 2.9),
      ('EMP-0609', 76080, 86455, 0.88, '2024-12-15', 2.2),
      ('EMP-0610', 104806, 112695, 0.93, '2024-03-27', 3.3),
      ('EMP-0611', 54345, 59720, 0.91, '2025-03-08', 1),
      ('EMP-0612', 94049, 102227, 0.92, '2024-11-26', 1.4),
      ('EMP-0613', 94666, 106366, 0.89, '2024-11-02', 2.3),
      ('EMP-0614', 79051, 87834, 0.9, '2025-02-15', 3.5),
      ('EMP-0615', 68409, 72776, 0.94, '2025-05-01', 2.2),
      ('EMP-0616', 77042, 86564, 0.89, '2025-02-15', 3),
      ('EMP-0617', 138024, 155083, 0.89, '2025-04-23', 2.8),
      ('EMP-0618', 109443, 122970, 0.89, '2024-06-03', 3),
      ('EMP-0619', 88648, 94306, 0.94, '2024-06-13', 2.9),
      ('EMP-0620', 81774, 89862, 0.91, '2025-03-22', 1.1),
      ('EMP-0621', 58409, 62805, 0.93, '2024-02-13', 4.1),
      ('EMP-0622', 73699, 83749, 0.88, '2025-02-20', 4.2),
      ('EMP-0623', 70492, 76622, 0.92, '2024-05-03', 1.1),
      ('EMP-0624', 73708, 81898, 0.9, '2025-02-03', 3.6),
      ('EMP-0625', 67249, 73900, 0.91, '2024-02-27', 2),
      ('EMP-0626', 100391, 106799, 0.94, '2024-05-28', 2),
      ('EMP-0627', 59009, 63451, 0.93, '2024-09-02', 3),
      ('EMP-0628', 136569, 145286, 0.94, '2025-02-06', 5),
      ('EMP-0629', 70082, 76176, 0.92, '2025-02-20', 3.2),
      ('EMP-0630', 154827, 164710, 0.94, '2024-04-12', 3.7),
      ('EMP-0631', 90784, 99763, 0.91, '2024-01-29', 3.1),
      ('EMP-0632', 50240, 55822, 0.9, '2024-03-25', 3.6),
      ('EMP-0633', 133241, 146419, 0.91, '2024-05-16', 2.9),
      ('EMP-0634', 82609, 87882, 0.94, '2024-08-17', 3.2),
      ('EMP-0635', 160187, 177986, 0.9, '2024-06-21', 4.3),
      ('EMP-0636', 162846, 182973, 0.89, '2025-03-21', 3.3),
      ('EMP-0637', 63645, 68435, 0.93, '2025-01-26', 4.3),
      ('EMP-0638', 139585, 156837, 0.89, '2024-05-29', 5.7),
      ('EMP-0639', 77457, 87030, 0.89, '2025-04-25', 3.6),
      ('EMP-0640', 134375, 149306, 0.9, '2024-04-07', 2.7),
      ('EMP-0641', 159235, 180949, 0.88, '2025-05-31', 2.4),
      ('EMP-0642', 53068, 59627, 0.89, '2025-05-19', 4.9),
      ('EMP-0643', 70653, 78503, 0.9, '2024-05-10', 0.5),
      ('EMP-0644', 160089, 174010, 0.92, '2025-03-22', 3.7),
      ('EMP-0645', 53188, 59098, 0.9, '2024-02-06', 2.4),
      ('EMP-0646', 55370, 60846, 0.91, '2025-05-19', 4.2),
      ('EMP-0647', 80179, 85297, 0.94, '2024-10-06', 1.6),
      ('EMP-0648', 126194, 134249, 0.94, '2024-09-09', 3.2),
      ('EMP-0649', 67533, 71844, 0.94, '2024-06-06', 4.1),
      ('EMP-0650', 101336, 106669, 0.95, '2025-04-08', 2.3),
      ('EMP-0651', 139636, 148549, 0.94, '2024-03-13', 1.7),
      ('EMP-0652', 73018, 82975, 0.88, '2024-08-01', 3.9),
      ('EMP-0653', 109901, 116916, 0.94, '2024-05-14', 2.7),
      ('EMP-0654', 76741, 85268, 0.9, '2025-03-09', 3.9),
      ('EMP-0655', 103752, 112774, 0.92, '2025-04-19', 2.4),
      ('EMP-0656', 50691, 56956, 0.89, '2025-05-04', 2.1),
      ('EMP-0657', 88684, 99645, 0.89, '2024-02-16', 1.8),
      ('EMP-0658', 129329, 140575, 0.92, '2025-05-30', 4.6),
      ('EMP-0659', 131117, 144085, 0.91, '2024-10-31', 2.4),
      ('EMP-0660', 82385, 92567, 0.89, '2024-09-22', 3.3),
      ('EMP-0661', 53859, 59186, 0.91, '2025-02-18', 4.8),
      ('EMP-0662', 117282, 126110, 0.93, '2025-02-08', 3.1),
      ('EMP-0663', 127311, 135437, 0.94, '2024-08-02', 2.4),
      ('EMP-0664', 75331, 82781, 0.91, '2025-04-30', 2.6),
      ('EMP-0665', 55782, 62676, 0.89, '2025-02-05', 3.1),
      ('EMP-0666', 130264, 141591, 0.92, '2024-10-24', 4),
      ('EMP-0667', 161552, 173712, 0.93, '2024-01-20', 2.2),
      ('EMP-0668', 132734, 144276, 0.92, '2024-12-21', 2),
      ('EMP-0669', 102277, 111171, 0.92, '2024-12-13', 4.7),
      ('EMP-0670', 153831, 163650, 0.94, '2024-06-14', 2.4),
      ('EMP-0671', 72177, 81098, 0.89, '2025-03-01', 4.1),
      ('EMP-0672', 157276, 174751, 0.9, '2024-06-11', 3.9),
      ('EMP-0673', 83818, 93131, 0.9, '2024-08-17', 0.5),
      ('EMP-0674', 76361, 82109, 0.93, '2024-04-16', 2.4),
      ('EMP-0675', 145330, 156269, 0.93, '2024-04-14', 3.1),
      ('EMP-0676', 128253, 137906, 0.93, '2025-03-28', 3.1),
      ('EMP-0677', 69143, 73556, 0.94, '2025-03-25', 4.7),
      ('EMP-0678', 73376, 82445, 0.89, '2025-01-16', 2.8),
      ('EMP-0679', 69946, 74411, 0.94, '2025-02-27', 4.9),
      ('EMP-0680', 51491, 54201, 0.95, '2024-03-27', 2.5),
      ('EMP-0681', 105743, 112493, 0.94, '2024-02-29', 5.8),
      ('EMP-0682', 127399, 136988, 0.93, '2024-11-17', 3.1),
      ('EMP-0683', 129547, 145558, 0.89, '2025-03-28', 2.3),
      ('EMP-0684', 48406, 52049, 0.93, '2024-05-09', 1.8),
      ('EMP-0685', 74200, 80652, 0.92, '2024-01-24', 4.8),
      ('EMP-0686', 132074, 142015, 0.93, '2025-01-16', 2.9),
      ('EMP-0687', 80940, 91977, 0.88, '2024-12-13', 4.8),
      ('EMP-0688', 128710, 143011, 0.9, '2024-05-23', 2.7),
      ('EMP-0689', 92128, 103515, 0.89, '2025-03-11', 3.2),
      ('EMP-0690', 73178, 78686, 0.93, '2025-02-16', 2),
      ('EMP-0691', 95754, 100794, 0.95, '2025-05-16', 2.9),
      ('EMP-0692', 93121, 98022, 0.95, '2024-04-30', 2.6),
      ('EMP-0693', 153093, 162865, 0.94, '2024-04-22', 3.9),
      ('EMP-0694', 79483, 88314, 0.9, '2024-01-29', 3.1),
      ('EMP-0695', 126431, 134501, 0.94, '2025-05-15', 4.3),
      ('EMP-0696', 100110, 106500, 0.94, '2025-01-21', 1.4),
      ('EMP-0697', 101649, 111702, 0.91, '2025-04-04', 4),
      ('EMP-0698', 81496, 90551, 0.9, '2024-02-16', 5),
      ('EMP-0699', 126353, 134418, 0.94, '2024-11-12', 2.5),
      ('EMP-0700', 98717, 107301, 0.92, '2025-05-02', 2.8),
      ('EMP-0701', 129979, 142834, 0.91, '2024-11-24', 2.8),
      ('EMP-0702', 75878, 83382, 0.91, '2024-04-03', 3.3),
      ('EMP-0703', 76509, 85010, 0.9, '2025-02-21', 2.8),
      ('EMP-0704', 73430, 82506, 0.89, '2024-11-27', 2.9),
      ('EMP-0705', 145869, 160296, 0.91, '2025-05-31', 2.6),
      ('EMP-0706', 76634, 84213, 0.91, '2024-08-27', 3.2),
      ('EMP-0707', 74500, 82778, 0.9, '2025-02-20', 1.2),
      ('EMP-0708', 78221, 86912, 0.9, '2025-03-09', 4.2),
      ('EMP-0709', 157960, 169849, 0.93, '2024-06-20', 5.3),
      ('EMP-0710', 130053, 138354, 0.94, '2024-08-05', 2),
      ('EMP-0711', 95938, 105426, 0.91, '2024-05-05', 3.8),
      ('EMP-0712', 90628, 95398, 0.95, '2024-09-24', 4.6),
      ('EMP-0713', 73999, 82221, 0.9, '2024-05-16', 3),
      ('EMP-0714', 74745, 80371, 0.93, '2024-03-24', 3.3),
      ('EMP-0715', 90616, 96400, 0.94, '2025-01-01', 1.6),
      ('EMP-0716', 168322, 187024, 0.9, '2024-01-21', 3.1),
      ('EMP-0717', 89942, 99936, 0.9, '2025-05-20', 3.3),
      ('EMP-0718', 74721, 83956, 0.89, '2024-10-11', 1.9),
      ('EMP-0719', 96726, 108681, 0.89, '2024-05-11', 3),
      ('EMP-0720', 72390, 76200, 0.95, '2024-09-15', 2.1),
      ('EMP-0721', 117477, 124976, 0.94, '2025-02-20', 2.8),
      ('EMP-0722', 139952, 159036, 0.88, '2025-03-06', 2.1),
      ('EMP-0723', 128824, 135604, 0.95, '2025-03-09', 5.2),
      ('EMP-0724', 53050, 60284, 0.88, '2025-03-18', 3.5),
      ('EMP-0725', 91655, 97505, 0.94, '2024-08-30', 4.6),
      ('EMP-0726', 95996, 107861, 0.89, '2024-03-03', 3.8),
      ('EMP-0727', 53378, 60657, 0.88, '2024-02-27', 2.2),
      ('EMP-0728', 127973, 136141, 0.94, '2024-01-11', 1.9),
      ('EMP-0729', 76612, 87059, 0.88, '2024-12-02', 2.6),
      ('EMP-0730', 98329, 110482, 0.89, '2024-09-19', 2.3),
      ('EMP-0731', 58013, 65183, 0.89, '2025-03-22', 1.6),
      ('EMP-0732', 129202, 143558, 0.9, '2024-12-17', 2.3),
      ('EMP-0733', 63546, 67602, 0.94, '2025-03-08', 1.5),
      ('EMP-0734', 115179, 125195, 0.92, '2024-12-05', 3.8),
      ('EMP-0735', 69821, 74278, 0.94, '2024-02-13', 0.8),
      ('EMP-0736', 75287, 80093, 0.94, '2025-01-19', 3.2),
      ('EMP-0737', 78066, 87715, 0.89, '2025-03-26', 3.5),
      ('EMP-0738', 81237, 86422, 0.94, '2024-06-27', 2.3),
      ('EMP-0739', 137163, 145918, 0.94, '2024-05-20', 1.7),
      ('EMP-0740', 108089, 116225, 0.93, '2025-03-20', 3.3),
      ('EMP-0741', 73728, 81020, 0.91, '2025-03-15', 3.7),
      ('EMP-0742', 129280, 145258, 0.89, '2024-09-10', 4.7),
      ('EMP-0743', 77926, 85633, 0.91, '2024-03-07', 3.5),
      ('EMP-0744', 105738, 114933, 0.92, '2025-05-09', 2.7),
      ('EMP-0745', 92390, 98287, 0.94, '2025-04-07', 3.7),
      ('EMP-0746', 71196, 77387, 0.92, '2024-05-17', 3),
      ('EMP-0747', 52213, 58014, 0.9, '2025-04-06', 2),
      ('EMP-0748', 55692, 61880, 0.9, '2024-03-18', 2.7),
      ('EMP-0749', 132141, 148473, 0.89, '2025-01-03', 3.6),
      ('EMP-0750', 131062, 147261, 0.89, '2024-05-21', 4.7),
      ('EMP-0751', 74916, 78859, 0.95, '2024-01-13', 1.8),
      ('EMP-0752', 131399, 145999, 0.9, '2025-04-24', 2.8),
      ('EMP-0753', 69520, 78112, 0.89, '2025-04-05', 3.1),
      ('EMP-0754', 74013, 81333, 0.91, '2024-12-29', 2.4),
      ('EMP-0755', 105871, 112629, 0.94, '2024-06-06', 6),
      ('EMP-0756', 126948, 133629, 0.95, '2024-03-06', 2.4),
      ('EMP-0757', 99074, 111319, 0.89, '2024-06-30', 4.5),
      ('EMP-0758', 56019, 62943, 0.89, '2024-10-25', 2.8),
      ('EMP-0759', 73395, 82466, 0.89, '2024-04-23', 3.7),
      ('EMP-0760', 57517, 63205, 0.91, '2025-05-01', 3.7),
      ('EMP-0761', 137328, 154301, 0.89, '2024-05-26', 1.2),
      ('EMP-0762', 164160, 180396, 0.91, '2024-02-10', 2.9),
      ('EMP-0763', 70893, 78770, 0.9, '2025-03-18', 0.9),
      ('EMP-0764', 103839, 110467, 0.94, '2024-06-10', 2.8),
      ('EMP-0765', 59636, 64125, 0.93, '2025-05-31', 3.1),
      ('EMP-0766', 94110, 105742, 0.89, '2025-04-17', 1.8),
      ('EMP-0767', 80622, 89580, 0.9, '2025-04-20', 2.6),
      ('EMP-0768', 55120, 61933, 0.89, '2024-01-19', 2.5),
      ('EMP-0769', 73055, 78554, 0.93, '2024-06-06', 2.4),
      ('EMP-0770', 101520, 110348, 0.92, '2024-04-15', 2.3),
      ('EMP-0771', 133632, 146848, 0.91, '2024-09-01', 3.1),
      ('EMP-0772', 101140, 106463, 0.95, '2024-04-08', 3.5),
      ('EMP-0773', 87982, 95633, 0.92, '2024-07-13', 1.3),
      ('EMP-0774', 66766, 75018, 0.89, '2025-02-15', 2.9),
      ('EMP-0775', 99148, 107770, 0.92, '2024-02-14', 3.6),
      ('EMP-0776', 131922, 146580, 0.9, '2024-04-07', 0.7),
      ('EMP-0777', 88950, 93632, 0.95, '2025-05-08', 3.2),
      ('EMP-0778', 100518, 111687, 0.9, '2024-05-07', 2.4),
      ('EMP-0779', 60086, 67512, 0.89, '2025-01-19', 3.1),
      ('EMP-0780', 55889, 60749, 0.92, '2025-02-28', 2.5),
      ('EMP-0781', 71693, 81469, 0.88, '2024-09-11', 3.5),
      ('EMP-0782', 90241, 98088, 0.92, '2024-03-07', 3.3),
      ('EMP-0783', 158147, 177693, 0.89, '2024-07-28', 3),
      ('EMP-0784', 77010, 85567, 0.9, '2024-10-19', 0.7),
      ('EMP-0785', 50965, 56005, 0.91, '2025-04-27', 1.9),
      ('EMP-0786', 56424, 60026, 0.94, '2024-11-03', 2.5),
      ('EMP-0787', 73379, 79760, 0.92, '2025-05-07', 3.5),
      ('EMP-0788', 55789, 59988, 0.93, '2025-05-18', 2.1),
      ('EMP-0789', 77926, 85633, 0.91, '2024-02-09', 3.5),
      ('EMP-0790', 159837, 173736, 0.92, '2025-05-15', 2.4),
      ('EMP-0791', 71406, 77615, 0.92, '2024-01-29', 2.5),
      ('EMP-0792', 68189, 77488, 0.88, '2024-04-04', 1.6),
      ('EMP-0793', 66214, 71198, 0.93, '2025-05-27', 4.4),
      ('EMP-0794', 128029, 143853, 0.89, '2024-12-18', 3.3),
      ('EMP-0795', 52573, 59742, 0.88, '2024-03-12', 3.2),
      ('EMP-0796', 69857, 75115, 0.93, '2024-07-21', 1.8),
      ('EMP-0797', 75502, 84834, 0.89, '2024-07-15', 2.9),
      ('EMP-0798', 62176, 69861, 0.89, '2024-03-28', 2.4),
      ('EMP-0799', 103729, 116549, 0.89, '2024-03-03', 2.7),
      ('EMP-0800', 116531, 126664, 0.92, '2024-09-29', 4);
    SET row_count = (SELECT COUNT(*) FROM compensation);
    SELECT 'compensation: Inserted ' || row_count || ' rows.' AS status;
  ELSE
    SELECT 'compensation: Table already has ' || row_count || ' rows. Skipping insert.' AS status;
  END IF;
END;

-- %%
-- Create employees table
CREATE TABLE IF NOT EXISTS employees (
  employee_id STRING NOT NULL,
  first_name STRING,
  last_name STRING,
  department STRING,
  region STRING,
  hire_date DATE,
  manager_id STRING,
  job_title STRING,
  job_level INT,
  status STRING
);

-- Insert data only if table is empty
BEGIN
  DECLARE row_count INT;
  SET row_count = (SELECT COUNT(*) FROM employees);
  IF row_count = 0 THEN
    INSERT INTO employees VALUES
      ('EMP-0001', 'Cormac', 'Ly', 'Engineering', 'Southwest', '2022-01-08', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0002', 'Sakura', 'Wang', 'Engineering', 'Southwest', '2022-04-21', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0003', 'Rashid', 'Koroma', 'Engineering', 'Southwest', '2023-12-08', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0004', 'Griffin', 'Yamamoto', 'Engineering', 'Southwest', '2021-09-26', 'MGR-001', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0005', 'Kai', 'Sanchez', 'Engineering', 'Southwest', '2023-02-03', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0006', 'Bao', 'Matsuda', 'Engineering', 'Southwest', '2022-07-16', 'MGR-001', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0007', 'Thandi', 'Kulkarni', 'Engineering', 'Southwest', '2023-08-25', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0008', 'Samir', 'Fischer', 'Engineering', 'Southwest', '2021-12-08', 'MGR-001', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0009', 'Karina', 'Ueda', 'Engineering', 'Southwest', '2020-12-14', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0010', 'Javier', 'Larsson', 'Engineering', 'Southwest', '2020-04-04', 'MGR-001', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0011', 'Miguel', 'Fujita', 'Engineering', 'Southwest', '2021-09-29', 'MGR-001', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0012', 'Priya', 'Estrada', 'Engineering', 'Southwest', '2022-02-01', 'MGR-001', 'Staff Engineer', 4, 'Active'),
      ('EMP-0013', 'Vivian', 'Guerrero', 'Engineering', 'Southwest', '2022-02-24', 'MGR-001', 'Senior Engineer', 3, 'Active'),
      ('EMP-0014', 'Tatiana', 'Torres', 'Engineering', 'Southwest', '2020-02-17', 'MGR-001', 'Staff Engineer', 4, 'Active'),
      ('EMP-0015', 'Viktor', 'Ono', 'Marketing', 'Southeast', '2020-11-09', 'MGR-058', 'Senior Marketing Manager', 3, 'Resigned'),
      ('EMP-0016', 'Viktor', 'Inoue', 'Sales', 'Southwest', '2020-07-16', 'MGR-012', 'Sales Manager', 4, 'Resigned'),
      ('EMP-0017', 'Oumar', 'Grant', 'Customer Success', 'West Coast', '2018-02-16', 'MGR-052', 'Senior CS Manager', 3, 'Resigned'),
      ('EMP-0018', 'Oumar', 'Chen', 'Engineering', 'West Coast', '2018-06-02', 'MGR-036', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0019', 'Finn', 'Gutierrez', 'Sales', 'Southwest', '2022-05-11', 'MGR-012', 'Account Executive', 2, 'Resigned'),
      ('EMP-0020', 'Anya', 'Kobayashi', 'Sales', 'West Coast', '2017-12-15', 'MGR-022', 'Regional Sales Director', 5, 'Resigned'),
      ('EMP-0021', 'Camila', 'Pillai', 'Operations', 'Southeast', '2020-05-02', 'MGR-040', 'VP of Operations', 5, 'Resigned'),
      ('EMP-0022', 'Amira', 'Yoshida', 'Marketing', 'Southwest', '2018-12-13', 'MGR-009', 'Marketing Specialist', 2, 'Resigned'),
      ('EMP-0023', 'Dante', 'Nakamura', 'Sales', 'Midwest', '2024-11-19', 'MGR-042', 'Sales Manager', 4, 'Resigned'),
      ('EMP-0024', 'Eric', 'Eriksson', 'Operations', 'Southwest', '2024-04-06', 'MGR-025', 'Senior Operations Manager', 3, 'Resigned'),
      ('EMP-0025', 'Viktor', 'Navarro', 'Product', 'West Coast', '2021-12-04', 'MGR-002', 'VP of Product', 5, 'Resigned'),
      ('EMP-0026', 'Suresh', 'Ishikawa', 'Operations', 'Southeast', '2017-06-13', 'MGR-040', 'Operations Analyst', 1, 'Resigned'),
      ('EMP-0027', 'Divya', 'Grant', 'Engineering', 'Midwest', '2018-12-19', 'MGR-036', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0028', 'Yolanda', 'Ma', 'Product', 'Southeast', '2022-04-10', 'MGR-047', 'VP of Product', 5, 'Resigned'),
      ('EMP-0029', 'Felix', 'Traoré', 'Product', 'Southeast', '2021-06-29', 'MGR-054', 'Product Manager', 2, 'Resigned'),
      ('EMP-0030', 'Tatiana', 'Guo', 'Customer Success', 'Southwest', '2023-02-01', 'MGR-046', 'Senior CS Manager', 3, 'Resigned'),
      ('EMP-0031', 'Fernanda', 'Iyer', 'Customer Success', 'Southwest', '2023-02-28', 'MGR-019', 'CS Manager', 2, 'Resigned'),
      ('EMP-0032', 'Fatima', 'Ly', 'Customer Success', 'Northeast', '2020-06-26', 'MGR-048', 'CS Director', 4, 'Resigned'),
      ('EMP-0033', 'Lakshmi', 'Matsuda', 'Engineering', 'Northeast', '2025-01-14', 'MGR-029', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0034', 'Troy', 'Sanchez', 'Operations', 'West Coast', '2019-02-20', 'MGR-025', 'Operations Analyst', 1, 'Resigned'),
      ('EMP-0035', 'Jia', 'Camara', 'Marketing', 'Southwest', '2020-05-07', 'MGR-058', 'Marketing Specialist', 2, 'Resigned'),
      ('EMP-0036', 'Ayumi', 'Sakho', 'Operations', 'Southeast', '2019-02-12', 'MGR-031', 'VP of Operations', 5, 'Resigned'),
      ('EMP-0037', 'Xiomara', 'Xu', 'Product', 'Southeast', '2024-06-11', 'MGR-013', 'Product Manager', 2, 'Resigned'),
      ('EMP-0038', 'Felix', 'Mensah', 'Customer Success', 'Southeast', '2022-02-15', 'MGR-005', 'CS Associate', 1, 'Resigned'),
      ('EMP-0039', 'Ingrid', 'Lund', 'Customer Success', 'Midwest', '2024-10-08', 'MGR-046', 'CS Manager', 2, 'Resigned'),
      ('EMP-0040', 'Brigitte', 'Wu', 'Product', 'Southeast', '2017-05-28', 'MGR-054', 'Group Product Manager', 4, 'Resigned'),
      ('EMP-0041', 'Adaeze', 'Mensah', 'Customer Success', 'Southwest', '2024-10-13', 'MGR-027', 'CS Manager', 2, 'Resigned'),
      ('EMP-0042', 'Pia', 'Sow', 'Operations', 'Northeast', '2021-08-15', 'MGR-025', 'Operations Specialist', 2, 'Resigned'),
      ('EMP-0043', 'Lina', 'Salazar', 'Finance', 'Northeast', '2024-02-26', 'MGR-026', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0044', 'Elsa', 'Sakho', 'Sales', 'Southwest', '2020-11-16', 'MGR-045', 'Account Executive', 2, 'Resigned'),
      ('EMP-0045', 'Marisol', 'Eriksson', 'Operations', 'Southeast', '2021-04-12', 'MGR-034', 'Operations Analyst', 1, 'Resigned'),
      ('EMP-0046', 'Esperanza', 'Olsen', 'Engineering', 'West Coast', '2025-05-09', 'MGR-004', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0047', 'Takeshi', 'Ly', 'Customer Success', 'Midwest', '2019-02-18', 'MGR-048', 'CS Manager', 2, 'Resigned'),
      ('EMP-0048', 'Oluwaseun', 'Koroma', 'Customer Success', 'Southeast', '2021-02-03', 'MGR-051', 'CS Associate', 1, 'Resigned'),
      ('EMP-0049', 'Yara', 'Gupta', 'Customer Success', 'West Coast', '2021-02-07', 'MGR-048', 'CS Director', 4, 'Resigned'),
      ('EMP-0050', 'Ruth', 'Bangura', 'Product', 'Midwest', '2022-04-03', 'MGR-002', 'Group Product Manager', 4, 'Resigned'),
      ('EMP-0051', 'Esperanza', 'Campos', 'Marketing', 'Southwest', '2017-02-27', 'MGR-015', 'Marketing Director', 4, 'Resigned'),
      ('EMP-0052', 'Rosa', 'Wade', 'Operations', 'Midwest', '2019-08-16', 'MGR-056', 'Operations Analyst', 1, 'Resigned'),
      ('EMP-0053', 'Tariq', 'Matsuda', 'Product', 'Midwest', '2018-04-23', 'MGR-013', 'Senior Product Manager', 3, 'Resigned'),
      ('EMP-0054', 'Yuki', 'Berg', 'Finance', 'Northeast', '2021-02-28', 'MGR-055', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0055', 'Leo', 'Mensah', 'Customer Success', 'Southeast', '2020-02-20', 'MGR-005', 'Senior CS Manager', 3, 'Resigned'),
      ('EMP-0056', 'Chukwu', 'Mensah', 'Product', 'Midwest', '2024-03-26', 'MGR-047', 'Senior Product Manager', 3, 'Resigned'),
      ('EMP-0057', 'Julian', 'Sharma', 'Product', 'Northeast', '2023-09-12', 'MGR-002', 'Senior Product Manager', 3, 'Resigned'),
      ('EMP-0058', 'Obi', 'Ramírez', 'Engineering', 'West Coast', '2019-06-04', 'MGR-018', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0059', 'Oumar', 'Reyes', 'Sales', 'West Coast', '2018-12-16', 'MGR-012', 'Account Executive', 2, 'Resigned'),
      ('EMP-0060', 'Rashid', 'Grant', 'Marketing', 'Southwest', '2017-08-03', 'MGR-014', 'Marketing Specialist', 2, 'Resigned'),
      ('EMP-0061', 'Chukwu', 'Guo', 'Finance', 'Southwest', '2019-06-27', 'MGR-043', 'Finance Manager', 3, 'Resigned'),
      ('EMP-0062', 'Jasmine', 'Aguilar', 'Customer Success', 'Southeast', '2018-03-19', 'MGR-046', 'CS Manager', 2, 'Resigned'),
      ('EMP-0063', 'Malaika', 'Reyes', 'Engineering', 'Northeast', '2024-02-07', 'MGR-053', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0064', 'Natsumi', 'Roth', 'Finance', 'West Coast', '2024-11-14', 'MGR-017', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0065', 'Sunita', 'Popov', 'Customer Success', 'Southeast', '2025-03-08', 'MGR-005', 'CS Manager', 2, 'Resigned'),
      ('EMP-0066', 'Celine', 'Xu', 'Engineering', 'Southwest', '2018-01-17', 'MGR-032', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0067', 'Eric', 'Kulkarni', 'Finance', 'Midwest', '2021-08-10', 'MGR-028', 'Finance Manager', 3, 'Resigned'),
      ('EMP-0068', 'Elsa', 'Dutta', 'Marketing', 'Midwest', '2022-09-10', 'MGR-014', 'Marketing Coordinator', 1, 'Resigned'),
      ('EMP-0069', 'Tarquin', 'Murakami', 'Engineering', 'Midwest', '2021-10-24', 'MGR-038', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0070', 'Chen', 'Santos', 'Sales', 'Midwest', '2020-06-19', 'MGR-024', 'Sales Manager', 4, 'Resigned'),
      ('EMP-0071', 'Kai', 'Hernández', 'Sales', 'Southwest', '2022-12-13', 'MGR-022', 'Sales Associate', 1, 'Resigned'),
      ('EMP-0072', 'Annika', 'Ndiaye', 'Finance', 'Southwest', '2018-09-30', 'MGR-020', 'Finance Director', 4, 'Resigned'),
      ('EMP-0073', 'Andre', 'Ueda', 'Finance', 'Southeast', '2019-06-02', 'MGR-060', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0074', 'Naomi', 'Ueda', 'Finance', 'Midwest', '2021-06-07', 'MGR-043', 'Financial Analyst', 1, 'Resigned'),
      ('EMP-0075', 'Leila', 'Conteh', 'Marketing', 'Midwest', '2022-07-31', 'MGR-058', 'Marketing Coordinator', 1, 'Resigned'),
      ('EMP-0076', 'Beatriz', 'Nilsson', 'Engineering', 'Southeast', '2017-06-23', 'MGR-032', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0077', 'Maxwell', 'Bhat', 'Product', 'Southeast', '2021-07-18', 'MGR-002', 'Product Manager', 2, 'Resigned'),
      ('EMP-0078', 'Chukwu', 'López', 'Operations', 'Southwest', '2023-08-10', 'MGR-040', 'Operations Specialist', 2, 'Resigned'),
      ('EMP-0079', 'Kofi', 'Fofana', 'Customer Success', 'Northeast', '2024-02-07', 'MGR-005', 'CS Associate', 1, 'Resigned'),
      ('EMP-0080', 'Zara', 'Berg', 'Engineering', 'Northeast', '2018-12-12', 'MGR-053', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0081', 'Wyatt', 'Matsuda', 'Customer Success', 'West Coast', '2022-01-13', 'MGR-051', 'CS Director', 4, 'Resigned'),
      ('EMP-0082', 'Ravi', 'Rojas', 'Engineering', 'Southeast', '2020-05-25', 'MGR-029', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0083', 'Greta', 'Okafor', 'Engineering', 'Midwest', '2017-11-11', 'MGR-006', 'Staff Engineer', 4, 'Resigned'),
      ('EMP-0084', 'Oluwaseun', 'Sylla', 'Customer Success', 'West Coast', '2020-08-09', 'MGR-048', 'Senior CS Manager', 3, 'Resigned'),
      ('EMP-0085', 'Jia', 'Wang', 'Finance', 'Northeast', '2024-12-08', 'MGR-039', 'Financial Analyst', 1, 'Resigned'),
      ('EMP-0086', 'Linh', 'Hasegawa', 'Customer Success', 'Midwest', '2017-08-03', 'MGR-052', 'Senior CS Manager', 3, 'Resigned'),
      ('EMP-0087', 'Tunde', 'Rivera', 'Marketing', 'West Coast', '2020-09-27', 'MGR-009', 'Marketing Director', 4, 'Resigned'),
      ('EMP-0088', 'Ryan', 'Gupta', 'Finance', 'Southwest', '2021-03-23', 'MGR-055', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0089', 'Elijah', 'Sharma', 'Product', 'Southeast', '2017-03-16', 'MGR-047', 'Senior Product Manager', 3, 'Resigned'),
      ('EMP-0090', 'Petra', 'Cruz', 'Sales', 'Northeast', '2018-02-19', 'MGR-044', 'Sales Associate', 1, 'Resigned'),
      ('EMP-0091', 'Desmond', 'Gupta', 'Finance', 'Southeast', '2019-01-11', 'MGR-057', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0092', 'Marta', 'Berg', 'Operations', 'West Coast', '2025-05-25', 'MGR-056', 'Operations Specialist', 2, 'Resigned'),
      ('EMP-0093', 'Troy', 'Kamara', 'Marketing', 'West Coast', '2022-03-07', 'MGR-015', 'VP of Marketing', 5, 'Resigned'),
      ('EMP-0094', 'Yara', 'Sugiyama', 'Sales', 'Midwest', '2022-05-23', 'MGR-024', 'Sales Associate', 1, 'Resigned'),
      ('EMP-0095', 'Nadia', 'Rivera', 'Engineering', 'Northeast', '2022-10-04', 'MGR-007', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0096', 'Greta', 'Mansaray', 'Engineering', 'Southeast', '2022-08-19', 'MGR-030', 'Junior Engineer', 1, 'Resigned'),
      ('EMP-0097', 'Svetlana', 'Fofana', 'Customer Success', 'Northeast', '2020-03-21', 'MGR-052', 'CS Associate', 1, 'Resigned'),
      ('EMP-0098', 'Padma', 'Patel', 'Engineering', 'Southwest', '2018-09-05', 'MGR-038', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0099', 'Marisol', 'Liu', 'Engineering', 'Northeast', '2023-12-27', 'MGR-036', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0100', 'Luciana', 'Estrada', 'Sales', 'Northeast', '2017-01-07', 'MGR-045', 'Account Executive', 2, 'Resigned'),
      ('EMP-0101', 'Elijah', 'Mendoza', 'Engineering', 'West Coast', '2022-09-11', 'MGR-038', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0102', 'Ines', 'Inoue', 'Product', 'Southwest', '2017-10-04', 'MGR-047', 'Product Manager', 2, 'Resigned'),
      ('EMP-0103', 'Thandiwe', 'Sato', 'Engineering', 'Midwest', '2024-03-17', 'MGR-007', 'Senior Engineer', 3, 'Resigned'),
      ('EMP-0104', 'Mateo', 'Sato', 'Engineering', 'Southeast', '2019-04-06', 'MGR-004', 'Junior Engineer', 1, 'Resigned'),
      ('EMP-0105', 'Esperanza', 'Sakho', 'Operations', 'Midwest', '2024-04-03', 'MGR-031', 'Operations Analyst', 1, 'Resigned'),
      ('EMP-0106', 'Nadia', 'Murakami', 'Operations', 'Southeast', '2021-05-03', 'MGR-034', 'Operations Director', 4, 'Resigned'),
      ('EMP-0107', 'Bao', 'Kimura', 'Customer Success', 'Southwest', '2017-11-20', 'MGR-046', 'CS Director', 4, 'Resigned'),
      ('EMP-0108', 'Chioma', 'Desai', 'Product', 'Midwest', '2023-10-05', 'MGR-050', 'Product Manager', 2, 'Resigned'),
      ('EMP-0109', 'Daniel', 'Romero', 'Operations', 'Midwest', '2017-08-23', 'MGR-011', 'Senior Operations Manager', 3, 'Resigned'),
      ('EMP-0110', 'Emeka', 'Santos', 'Sales', 'West Coast', '2021-11-30', 'MGR-010', 'Senior Account Executive', 3, 'Resigned'),
      ('EMP-0111', 'Tunde', 'Ndiaye', 'Engineering', 'West Coast', '2022-01-17', 'MGR-030', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0112', 'Esperanza', 'Hansen', 'Product', 'Midwest', '2018-04-10', 'MGR-002', 'Product Manager', 2, 'Resigned'),
      ('EMP-0113', 'Gabriel', 'Castillo', 'Customer Success', 'Midwest', '2019-05-29', 'MGR-048', 'CS Director', 4, 'Resigned'),
      ('EMP-0114', 'Kenji', 'Sylla', 'Sales', 'Southeast', '2024-08-25', 'MGR-024', 'Regional Sales Director', 5, 'Resigned'),
      ('EMP-0115', 'Idris', 'Fischer', 'Product', 'Northeast', '2022-09-15', 'MGR-013', 'Group Product Manager', 4, 'Resigned'),
      ('EMP-0116', 'Wyatt', 'Müller', 'Marketing', 'West Coast', '2022-03-30', 'MGR-014', 'Senior Marketing Manager', 3, 'Resigned'),
      ('EMP-0117', 'Amir', 'Arai', 'Operations', 'Southeast', '2017-10-30', 'MGR-025', 'Operations Director', 4, 'Resigned'),
      ('EMP-0118', 'Esteban', 'Martínez', 'Customer Success', 'West Coast', '2019-01-16', 'MGR-052', 'Senior CS Manager', 3, 'Resigned'),
      ('EMP-0119', 'Nadia', 'Vega', 'Sales', 'Midwest', '2020-08-14', 'MGR-059', 'Account Executive', 2, 'Resigned'),
      ('EMP-0120', 'Ayumi', 'Olsen', 'Sales', 'Midwest', '2018-01-18', 'MGR-044', 'Senior Account Executive', 3, 'Resigned'),
      ('EMP-0121', 'Joaquin', 'Popov', 'Customer Success', 'West Coast', '2017-04-27', 'MGR-005', 'CS Associate', 1, 'Resigned'),
      ('EMP-0122', 'Leo', 'Saito', 'Product', 'Southwest', '2024-01-13', 'MGR-054', 'Senior Product Manager', 3, 'Resigned'),
      ('EMP-0123', 'Tatiana', 'Kováč', 'Operations', 'Southwest', '2018-10-10', 'MGR-056', 'Senior Operations Manager', 3, 'Resigned'),
      ('EMP-0124', 'Brendan', 'Wu', 'Product', 'Midwest', '2018-06-20', 'MGR-047', 'VP of Product', 5, 'Resigned'),
      ('EMP-0125', 'Chen', 'Sylla', 'Sales', 'Northeast', '2020-04-03', 'MGR-035', 'Sales Associate', 1, 'Resigned'),
      ('EMP-0126', 'Emeka', 'Desai', 'Finance', 'Midwest', '2018-10-15', 'MGR-039', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0127', 'Priya', 'Sharma', 'Operations', 'West Coast', '2019-09-14', 'MGR-031', 'Senior Operations Manager', 3, 'Resigned'),
      ('EMP-0128', 'Troy', 'Rao', 'Finance', 'Southwest', '2021-11-01', 'MGR-020', 'Finance Director', 4, 'Resigned'),
      ('EMP-0129', 'Kai', 'Singh', 'Finance', 'West Coast', '2023-03-17', 'MGR-026', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0130', 'Iris', 'Vogt', 'Engineering', 'Northeast', '2021-06-02', 'MGR-030', 'Principal Engineer', 5, 'Resigned'),
      ('EMP-0131', 'Björn', 'Eriksson', 'Finance', 'West Coast', '2017-06-14', 'MGR-008', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0132', 'Ravi', 'Ly', 'Finance', 'Northeast', '2023-11-17', 'MGR-028', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0133', 'Adam', 'Mayer', 'Operations', 'West Coast', '2017-03-10', 'MGR-034', 'Operations Specialist', 2, 'Resigned'),
      ('EMP-0134', 'Liam', 'Navarro', 'Operations', 'Midwest', '2023-06-28', 'MGR-031', 'VP of Operations', 5, 'Resigned'),
      ('EMP-0135', 'Desmond', 'Vargas', 'Sales', 'Northeast', '2024-11-09', 'MGR-012', 'Sales Associate', 1, 'Resigned'),
      ('EMP-0136', 'Nikolai', 'Traoré', 'Finance', 'West Coast', '2025-04-02', 'MGR-057', 'VP of Finance', 5, 'Resigned'),
      ('EMP-0137', 'Rohan', 'Hansen', 'Sales', 'Southeast', '2020-11-03', 'MGR-044', 'Regional Sales Director', 5, 'Resigned'),
      ('EMP-0138', 'Suki', 'Huang', 'Finance', 'Midwest', '2020-05-04', 'MGR-060', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0139', 'Amir', 'Mansaray', 'Finance', 'Midwest', '2023-06-07', 'MGR-055', 'Senior Financial Analyst', 2, 'Resigned'),
      ('EMP-0140', 'Zara', 'Hayashi', 'Engineering', 'Midwest', '2017-11-20', 'MGR-030', 'Principal Engineer', 5, 'Resigned'),
      ('EMP-0141', 'Sana', 'Sesay', 'Finance', 'Midwest', '2023-11-27', 'MGR-057', 'Financial Analyst', 1, 'Resigned'),
      ('EMP-0142', 'Camila', 'Bah', 'Engineering', 'Southwest', '2025-01-17', 'MGR-036', 'Software Engineer', 2, 'Resigned'),
      ('EMP-0143', 'Emeka', 'Hasegawa', 'Product', 'Southeast', '2019-03-28', 'MGR-047', 'Senior Product Manager', 3, 'Resigned'),
      ('EMP-0144', 'Maxwell', 'Bah', 'Finance', 'Southwest', '2018-12-19', 'MGR-037', 'VP of Finance', 5, 'Terminated'),
      ('EMP-0145', 'Esperanza', 'Braun', 'Sales', 'Midwest', '2017-02-07', 'MGR-023', 'Sales Manager', 4, 'Terminated'),
      ('EMP-0146', 'Julian', 'Sakho', 'Finance', 'Southeast', '2018-07-04', 'MGR-041', 'Finance Director', 4, 'Terminated'),
      ('EMP-0147', 'Ximena', 'Conteh', 'Product', 'Northeast', '2020-10-12', 'MGR-047', 'Associate Product Manager', 1, 'Terminated'),
      ('EMP-0148', 'Tatiana', 'Cissé', 'Finance', 'Midwest', '2024-07-04', 'MGR-017', 'Financial Analyst', 1, 'Terminated'),
      ('EMP-0149', 'Maria', 'Svoboda', 'Operations', 'Northeast', '2019-12-30', 'MGR-034', 'Operations Specialist', 2, 'Terminated'),
      ('EMP-0150', 'Rashid', 'Adeyemi', 'Product', 'Southwest', '2018-10-17', 'MGR-050', 'Senior Product Manager', 3, 'Terminated'),
      ('EMP-0151', 'Natsumi', 'Murakami', 'Finance', 'Northeast', '2018-07-02', 'MGR-039', 'Senior Financial Analyst', 2, 'Terminated'),
      ('EMP-0152', 'Troy', 'Guerrero', 'Customer Success', 'Northeast', '2024-08-18', 'MGR-052', 'CS Director', 4, 'Terminated'),
      ('EMP-0153', 'Chukwu', 'Osei', 'Finance', 'Southwest', '2023-02-22', 'MGR-041', 'Financial Analyst', 1, 'Terminated'),
      ('EMP-0154', 'Catalina', 'Boateng', 'Product', 'Northeast', '2022-06-26', 'MGR-002', 'Group Product Manager', 4, 'Terminated'),
      ('EMP-0155', 'Luciana', 'Németh', 'Operations', 'West Coast', '2022-03-09', 'MGR-033', 'Operations Analyst', 1, 'Terminated'),
      ('EMP-0156', 'Devi', 'Ono', 'Engineering', 'Southwest', '2024-11-08', 'MGR-006', 'Software Engineer', 2, 'Terminated'),
      ('EMP-0157', 'Troy', 'Nakamura', 'Marketing', 'Southeast', '2018-07-09', 'MGR-058', 'Marketing Specialist', 2, 'Terminated'),
      ('EMP-0158', 'Rohan', 'Lukić', 'Engineering', 'West Coast', '2020-11-25', 'MGR-006', 'Junior Engineer', 1, 'Terminated'),
      ('EMP-0159', 'Camila', 'Smith', 'Customer Success', 'Southwest', '2022-03-12', 'MGR-051', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0160', 'Suki', 'Delgado', 'Marketing', 'Northeast', '2025-02-17', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0161', 'Carlos', 'Yang', 'Sales', 'Southwest', '2017-05-18', 'MGR-042', 'Sales Associate', 1, 'Active'),
      ('EMP-0162', 'Finn', 'Bah', 'Finance', 'Northeast', '2017-08-20', 'MGR-020', 'Finance Director', 4, 'Active'),
      ('EMP-0163', 'Divya', 'Wu', 'Finance', 'West Coast', '2020-08-06', 'MGR-021', 'Finance Director', 4, 'Active'),
      ('EMP-0164', 'Sunita', 'Kováč', 'Marketing', 'Southwest', '2023-08-21', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0165', 'Esteban', 'Vargas', 'Customer Success', 'West Coast', '2021-09-02', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0166', 'Lina', 'Cruz', 'Marketing', 'Northeast', '2017-08-25', 'MGR-058', 'Marketing Director', 4, 'Active'),
      ('EMP-0167', 'Felix', 'Larsson', 'Operations', 'Midwest', '2025-02-15', 'MGR-031', 'Operations Analyst', 1, 'Active'),
      ('EMP-0168', 'Kenji', 'Ito', 'Customer Success', 'West Coast', '2023-04-09', 'MGR-019', 'CS Director', 4, 'Active'),
      ('EMP-0169', 'Lukas', 'Ito', 'Product', 'Southwest', '2022-05-16', 'MGR-013', 'Group Product Manager', 4, 'Active'),
      ('EMP-0170', 'Yusuf', 'Rivera', 'Operations', 'Southeast', '2021-01-11', 'MGR-033', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0171', 'Troy', 'Wu', 'Sales', 'Midwest', '2017-07-07', 'MGR-045', 'Account Executive', 2, 'Active'),
      ('EMP-0172', 'Yolanda', 'Ono', 'Product', 'Southeast', '2019-03-15', 'MGR-047', 'Product Manager', 2, 'Active'),
      ('EMP-0173', 'Marco', 'Conteh', 'Customer Success', 'Southeast', '2024-03-13', 'MGR-051', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0174', 'Leila', 'Sakho', 'Operations', 'Northeast', '2023-01-30', 'MGR-003', 'VP of Operations', 5, 'Active'),
      ('EMP-0175', 'Maria', 'Traoré', 'Sales', 'Northeast', '2018-09-11', 'MGR-010', 'Sales Associate', 1, 'Active'),
      ('EMP-0176', 'Padma', 'Menon', 'Product', 'Southeast', '2022-12-20', 'MGR-054', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0177', 'Elsa', 'Kim', 'Finance', 'Southeast', '2019-01-05', 'MGR-017', 'Finance Director', 4, 'Active'),
      ('EMP-0178', 'Enrique', 'Nilsson', 'Marketing', 'Southeast', '2021-07-22', 'MGR-058', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0179', 'Chioma', 'Nakamura', 'Engineering', 'Southeast', '2023-03-14', 'MGR-036', 'Software Engineer', 2, 'Active'),
      ('EMP-0180', 'Adaeze', 'Fujita', 'Finance', 'Southwest', '2017-06-24', 'MGR-021', 'Finance Director', 4, 'Active'),
      ('EMP-0181', 'Valentina', 'Sakho', 'Finance', 'Southwest', '2020-07-12', 'MGR-008', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0182', 'Esperanza', 'Osei', 'Marketing', 'Northeast', '2023-05-11', 'MGR-058', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0183', 'Chioma', 'Morita', 'Product', 'Midwest', '2021-11-26', 'MGR-013', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0184', 'Winston', 'Sun', 'Customer Success', 'Midwest', '2020-01-25', 'MGR-052', 'CS Associate', 1, 'Active'),
      ('EMP-0185', 'Rohan', 'Dahl', 'Sales', 'West Coast', '2017-12-18', 'MGR-045', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0186', 'Celine', 'Vargas', 'Product', 'Northeast', '2020-07-21', 'MGR-047', 'Group Product Manager', 4, 'Active'),
      ('EMP-0187', 'Kaia', 'Ivanov', 'Sales', 'Southwest', '2022-01-13', 'MGR-044', 'Account Executive', 2, 'Active'),
      ('EMP-0188', 'Ayumi', 'Sharma', 'Finance', 'West Coast', '2021-04-27', 'MGR-008', 'Finance Director', 4, 'Active'),
      ('EMP-0189', 'Beatriz', 'Sanchez', 'Finance', 'West Coast', '2021-04-09', 'MGR-020', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0190', 'Andrei', 'Ma', 'Marketing', 'Southeast', '2017-11-12', 'MGR-015', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0191', 'Padma', 'Eriksson', 'Operations', 'Southwest', '2017-01-28', 'MGR-040', 'Operations Analyst', 1, 'Active'),
      ('EMP-0192', 'Thandiwe', 'Dahl', 'Customer Success', 'West Coast', '2020-08-06', 'MGR-048', 'CS Associate', 1, 'Active'),
      ('EMP-0193', 'Esperanza', 'Wu', 'Marketing', 'Southeast', '2019-09-20', 'MGR-015', 'VP of Marketing', 5, 'Active'),
      ('EMP-0194', 'Yara', 'Lin', 'Finance', 'Northeast', '2023-03-04', 'MGR-008', 'Finance Manager', 3, 'Active'),
      ('EMP-0195', 'Dante', 'Hernández', 'Customer Success', 'Southeast', '2018-07-25', 'MGR-051', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0196', 'Rohan', 'Yamamoto', 'Operations', 'West Coast', '2021-06-30', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0197', 'Winston', 'Wang', 'Engineering', 'Northeast', '2020-12-25', 'MGR-007', 'Senior Engineer', 3, 'Active'),
      ('EMP-0198', 'Kai', 'Fujita', 'Customer Success', 'Southeast', '2018-02-08', 'MGR-027', 'CS Associate', 1, 'Active'),
      ('EMP-0199', 'Eric', 'Morita', 'Sales', 'Midwest', '2022-06-01', 'MGR-012', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0200', 'Björn', 'Mansaray', 'Marketing', 'Midwest', '2019-04-28', 'MGR-058', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0201', 'Xiomara', 'Hernández', 'Marketing', 'Southwest', '2018-04-17', 'MGR-009', 'Marketing Director', 4, 'Active'),
      ('EMP-0202', 'Patrick', 'Vega', 'Sales', 'West Coast', '2023-04-13', 'MGR-035', 'Account Executive', 2, 'Active'),
      ('EMP-0203', 'Aiko', 'Dahl', 'Operations', 'Southwest', '2019-03-20', 'MGR-056', 'Operations Director', 4, 'Active'),
      ('EMP-0204', 'Valentina', 'Petrov', 'Finance', 'Southwest', '2023-01-09', 'MGR-020', 'Finance Director', 4, 'Active'),
      ('EMP-0205', 'Nkechi', 'Diop', 'Product', 'Midwest', '2023-11-09', 'MGR-050', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0206', 'Omar', 'Kováč', 'Finance', 'West Coast', '2018-07-03', 'MGR-028', 'Financial Analyst', 1, 'Active'),
      ('EMP-0207', 'Björn', 'Haugen', 'Operations', 'Southeast', '2023-06-13', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0208', 'Omar', 'Campos', 'Sales', 'Southeast', '2019-02-06', 'MGR-024', 'Account Executive', 2, 'Active'),
      ('EMP-0209', 'Cedric', 'Sato', 'Sales', 'Southeast', '2022-09-02', 'MGR-049', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0210', 'Nkechi', 'Torres', 'Engineering', 'West Coast', '2019-06-23', 'MGR-029', 'Junior Engineer', 1, 'Active'),
      ('EMP-0211', 'Ximena', 'Maeda', 'Product', 'Southeast', '2018-04-09', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0212', 'Finn', 'Sakho', 'Sales', 'Southeast', '2024-05-01', 'MGR-022', 'Sales Associate', 1, 'Active'),
      ('EMP-0213', 'Isabella', 'Rojas', 'Customer Success', 'Southwest', '2019-08-29', 'MGR-019', 'CS Director', 4, 'Active'),
      ('EMP-0214', 'Hina', 'Torres', 'Finance', 'Northeast', '2019-04-28', 'MGR-060', 'Finance Director', 4, 'Active'),
      ('EMP-0215', 'Sakura', 'Ortiz', 'Product', 'Midwest', '2020-01-01', 'MGR-054', 'Product Manager', 2, 'Active'),
      ('EMP-0216', 'Sunita', 'Adeyemi', 'Marketing', 'Northeast', '2018-06-28', 'MGR-014', 'Marketing Director', 4, 'Active'),
      ('EMP-0217', 'Ryan', 'Barry', 'Sales', 'West Coast', '2024-01-16', 'MGR-035', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0218', 'Mohammed', 'Bhat', 'Finance', 'Midwest', '2021-02-20', 'MGR-039', 'Finance Manager', 3, 'Active'),
      ('EMP-0219', 'Mohammed', 'Delgado', 'Product', 'Midwest', '2022-12-30', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0220', 'Marco', 'Holm', 'Finance', 'Northeast', '2022-06-11', 'MGR-060', 'Finance Manager', 3, 'Active'),
      ('EMP-0221', 'Ximena', 'Kim', 'Engineering', 'Northeast', '2017-01-03', 'MGR-032', 'Software Engineer', 2, 'Active'),
      ('EMP-0222', 'Oumar', 'Sharma', 'Product', 'Midwest', '2021-03-04', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0223', 'Hina', 'Sharma', 'Product', 'Southwest', '2022-05-08', 'MGR-002', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0224', 'Wei', 'Gutierrez', 'Customer Success', 'Southwest', '2021-09-26', 'MGR-051', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0225', 'Diego', 'Ivanov', 'Marketing', 'Midwest', '2018-07-16', 'MGR-058', 'Marketing Director', 4, 'Active'),
      ('EMP-0226', 'Sofia', 'Diop', 'Finance', 'Southwest', '2018-11-04', 'MGR-039', 'Finance Manager', 3, 'Active'),
      ('EMP-0227', 'Sunita', 'Romero', 'Product', 'Southeast', '2017-12-22', 'MGR-002', 'Group Product Manager', 4, 'Active'),
      ('EMP-0228', 'Hina', 'Hansen', 'Customer Success', 'Northeast', '2024-03-25', 'MGR-005', 'CS Manager', 2, 'Active'),
      ('EMP-0229', 'Marisol', 'Ramírez', 'Finance', 'West Coast', '2025-05-22', 'MGR-037', 'Finance Manager', 3, 'Active'),
      ('EMP-0230', 'Lina', 'Braun', 'Operations', 'Southwest', '2024-02-27', 'MGR-011', 'Operations Specialist', 2, 'Active'),
      ('EMP-0231', 'Hana', 'Jalloh', 'Customer Success', 'West Coast', '2023-02-16', 'MGR-051', 'CS Manager', 2, 'Active'),
      ('EMP-0232', 'Carlos', 'Grant', 'Engineering', 'Southwest', '2017-06-13', 'MGR-004', 'Software Engineer', 2, 'Active'),
      ('EMP-0233', 'Suresh', 'Németh', 'Operations', 'Southeast', '2023-01-07', 'MGR-025', 'Operations Analyst', 1, 'Active'),
      ('EMP-0234', 'Celine', 'Guerrero', 'Marketing', 'Southeast', '2024-04-15', 'MGR-009', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0235', 'Dmitri', 'Sanchez', 'Engineering', 'Southeast', '2023-11-13', 'MGR-053', 'Junior Engineer', 1, 'Active'),
      ('EMP-0236', 'Wei', 'Zhang', 'Operations', 'Midwest', '2025-01-31', 'MGR-033', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0237', 'Gabriel', 'Santos', 'Marketing', 'Southeast', '2017-09-19', 'MGR-015', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0238', 'Dmitri', 'Salazar', 'Customer Success', 'West Coast', '2018-10-07', 'MGR-027', 'CS Manager', 2, 'Active'),
      ('EMP-0239', 'Mei', 'Nguyen', 'Sales', 'Southwest', '2021-04-18', 'MGR-016', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0240', 'Vivian', 'Cruz', 'Marketing', 'Northeast', '2025-01-29', 'MGR-015', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0241', 'Anya', 'Diallo', 'Sales', 'West Coast', '2021-07-01', 'MGR-012', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0242', 'Isabella', 'Hu', 'Operations', 'Southwest', '2020-04-09', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0243', 'Wyatt', 'Eriksson', 'Product', 'West Coast', '2019-10-02', 'MGR-013', 'Group Product Manager', 4, 'Active'),
      ('EMP-0244', 'Wei', 'Fofana', 'Engineering', 'Southeast', '2025-02-26', 'MGR-029', 'Staff Engineer', 4, 'Active'),
      ('EMP-0245', 'Björn', 'Huang', 'Engineering', 'Southwest', '2022-10-30', 'MGR-032', 'Principal Engineer', 5, 'Active'),
      ('EMP-0246', 'Cormac', 'Watanabe', 'Finance', 'Northeast', '2021-06-04', 'MGR-017', 'Finance Manager', 3, 'Active'),
      ('EMP-0247', 'Rashid', 'Hayashi', 'Marketing', 'Midwest', '2021-05-29', 'MGR-015', 'VP of Marketing', 5, 'Active'),
      ('EMP-0248', 'Kwame', 'Wade', 'Engineering', 'Northeast', '2022-01-16', 'MGR-036', 'Junior Engineer', 1, 'Active'),
      ('EMP-0249', 'Amira', 'Sylla', 'Marketing', 'Southeast', '2018-05-07', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0250', 'Oluwaseun', 'Touré', 'Customer Success', 'Midwest', '2024-12-22', 'MGR-019', 'CS Associate', 1, 'Active'),
      ('EMP-0251', 'Jabari', 'Takahashi', 'Engineering', 'Southeast', '2023-03-28', 'MGR-038', 'Staff Engineer', 4, 'Active'),
      ('EMP-0252', 'Nadia', 'Nguyen', 'Engineering', 'Northeast', '2021-06-29', 'MGR-030', 'Junior Engineer', 1, 'Active'),
      ('EMP-0253', 'Ingrid', 'O''Brien', 'Engineering', 'Northeast', '2021-12-22', 'MGR-007', 'Principal Engineer', 5, 'Active'),
      ('EMP-0254', 'Alejandro', 'Reddy', 'Finance', 'Southeast', '2021-06-06', 'MGR-039', 'Finance Director', 4, 'Active'),
      ('EMP-0255', 'Aiko', 'Olsen', 'Marketing', 'Southeast', '2017-05-22', 'MGR-014', 'Marketing Director', 4, 'Active'),
      ('EMP-0256', 'Jasmine', 'López', 'Marketing', 'Southeast', '2019-03-28', 'MGR-014', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0257', 'Pia', 'Aguilar', 'Finance', 'Southeast', '2023-05-06', 'MGR-041', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0258', 'Kofi', 'Santos', 'Customer Success', 'Midwest', '2022-04-17', 'MGR-048', 'CS Associate', 1, 'Active'),
      ('EMP-0259', 'Lina', 'Kimura', 'Finance', 'Southwest', '2019-06-18', 'MGR-043', 'Finance Director', 4, 'Active'),
      ('EMP-0260', 'Omar', 'Diallo', 'Sales', 'West Coast', '2025-04-12', 'MGR-059', 'Account Executive', 2, 'Active'),
      ('EMP-0261', 'Helga', 'Maeda', 'Sales', 'West Coast', '2022-07-10', 'MGR-044', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0262', 'Joaquin', 'Horváth', 'Engineering', 'West Coast', '2020-09-20', 'MGR-053', 'Senior Engineer', 3, 'Active'),
      ('EMP-0263', 'Yusuf', 'Adeyemi', 'Engineering', 'Northeast', '2018-08-04', 'MGR-006', 'Senior Engineer', 3, 'Active'),
      ('EMP-0264', 'Esperanza', 'Grant', 'Engineering', 'Midwest', '2018-07-13', 'MGR-007', 'Software Engineer', 2, 'Active'),
      ('EMP-0265', 'Xiomara', 'Takahashi', 'Product', 'West Coast', '2023-11-19', 'MGR-047', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0266', 'Natsumi', 'Martínez', 'Sales', 'Southwest', '2023-06-05', 'MGR-035', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0267', 'Griffin', 'Horváth', 'Product', 'West Coast', '2022-07-26', 'MGR-013', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0268', 'Andrei', 'López', 'Customer Success', 'Midwest', '2019-12-23', 'MGR-019', 'CS Manager', 2, 'Active'),
      ('EMP-0269', 'James', 'Rodriguez', 'Operations', 'Southeast', '2018-11-13', 'MGR-040', 'Operations Director', 4, 'Active'),
      ('EMP-0270', 'Amir', 'Estrada', 'Product', 'Northeast', '2017-10-29', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0271', 'Jia', 'Reddy', 'Operations', 'Northeast', '2023-02-19', 'MGR-011', 'Operations Director', 4, 'Active'),
      ('EMP-0272', 'Andrei', 'Ly', 'Operations', 'Northeast', '2020-09-18', 'MGR-031', 'Operations Analyst', 1, 'Active'),
      ('EMP-0273', 'Javier', 'Castillo', 'Product', 'Midwest', '2018-01-28', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0274', 'Hina', 'López', 'Marketing', 'West Coast', '2018-02-02', 'MGR-009', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0275', 'Lakshmi', 'Shimizu', 'Customer Success', 'Southeast', '2024-05-31', 'MGR-027', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0276', 'Seiji', 'Flores', 'Operations', 'Southwest', '2022-03-20', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0277', 'Yuki', 'Wang', 'Product', 'Midwest', '2021-08-23', 'MGR-054', 'Group Product Manager', 4, 'Active'),
      ('EMP-0278', 'Paloma', 'Weber', 'Sales', 'Southeast', '2021-06-06', 'MGR-059', 'Account Executive', 2, 'Active'),
      ('EMP-0279', 'Omar', 'Torres', 'Sales', 'Northeast', '2021-10-01', 'MGR-012', 'Sales Associate', 1, 'Active'),
      ('EMP-0280', 'Zara', 'Navarro', 'Marketing', 'Midwest', '2017-10-02', 'MGR-009', 'VP of Marketing', 5, 'Active'),
      ('EMP-0281', 'Karina', 'Delgado', 'Customer Success', 'Southwest', '2023-12-28', 'MGR-048', 'CS Director', 4, 'Active'),
      ('EMP-0282', 'Helga', 'Grant', 'Finance', 'Southwest', '2023-04-24', 'MGR-060', 'VP of Finance', 5, 'Active'),
      ('EMP-0283', 'Sunita', 'Castillo', 'Operations', 'Southeast', '2022-04-22', 'MGR-003', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0284', 'Kai', 'Okafor', 'Operations', 'Midwest', '2017-07-21', 'MGR-056', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0285', 'Marisol', 'Koroma', 'Marketing', 'Southeast', '2024-09-06', 'MGR-009', 'Marketing Director', 4, 'Active'),
      ('EMP-0286', 'Catalina', 'Ortiz', 'Marketing', 'Southeast', '2018-01-01', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0287', 'Ines', 'Tanaka', 'Finance', 'Northeast', '2024-12-16', 'MGR-041', 'Financial Analyst', 1, 'Active'),
      ('EMP-0288', 'Yara', 'Tanaka', 'Sales', 'Southwest', '2021-01-16', 'MGR-059', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0289', 'Nadia', 'Santos', 'Sales', 'Midwest', '2022-01-02', 'MGR-016', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0290', 'Mina', 'Svoboda', 'Product', 'Southwest', '2021-05-03', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0291', 'Nikolai', 'Kimura', 'Product', 'Southeast', '2024-08-26', 'MGR-002', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0292', 'Wei', 'Cruz', 'Marketing', 'West Coast', '2020-06-05', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0293', 'Devi', 'Keita', 'Marketing', 'West Coast', '2021-06-15', 'MGR-009', 'Marketing Director', 4, 'Active'),
      ('EMP-0294', 'Arjun', 'Kováč', 'Product', 'Southwest', '2020-10-09', 'MGR-047', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0295', 'Idris', 'Ito', 'Sales', 'West Coast', '2017-08-21', 'MGR-045', 'Sales Manager', 4, 'Active'),
      ('EMP-0296', 'Fernanda', 'Bangura', 'Marketing', 'Southeast', '2025-04-06', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0297', 'Hugo', 'Xu', 'Product', 'Midwest', '2018-11-28', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0298', 'Beatriz', 'Novak', 'Product', 'Midwest', '2019-06-30', 'MGR-047', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0299', 'Ines', 'Svoboda', 'Finance', 'Midwest', '2018-04-28', 'MGR-039', 'Finance Manager', 3, 'Active'),
      ('EMP-0300', 'Gabriel', 'Vargas', 'Finance', 'Midwest', '2018-09-10', 'MGR-020', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0301', 'Brendan', 'Novak', 'Customer Success', 'Southwest', '2024-01-29', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0302', 'Sakura', 'Estrada', 'Customer Success', 'Northeast', '2017-12-27', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0303', 'Tunde', 'Patel', 'Engineering', 'West Coast', '2021-03-09', 'MGR-004', 'Software Engineer', 2, 'Active'),
      ('EMP-0304', 'Suki', 'Cruz', 'Product', 'Midwest', '2018-02-25', 'MGR-050', 'Product Manager', 2, 'Active'),
      ('EMP-0305', 'Idris', 'Hayashi', 'Operations', 'West Coast', '2020-10-15', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0306', 'Pia', 'Ito', 'Sales', 'Southeast', '2019-07-08', 'MGR-059', 'Sales Associate', 1, 'Active'),
      ('EMP-0307', 'Sakura', 'Liu', 'Marketing', 'Southwest', '2024-03-07', 'MGR-015', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0308', 'Amara', 'O''Brien', 'Engineering', 'Southwest', '2021-04-07', 'MGR-006', 'Software Engineer', 2, 'Active'),
      ('EMP-0309', 'Wei', 'Moreno', 'Operations', 'Southwest', '2020-01-11', 'MGR-025', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0310', 'Arjun', 'Boateng', 'Customer Success', 'Southwest', '2023-10-31', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0311', 'Mina', 'Johansson', 'Finance', 'Southeast', '2024-09-19', 'MGR-039', 'VP of Finance', 5, 'Active'),
      ('EMP-0312', 'Sven', 'Weber', 'Product', 'Southeast', '2018-01-04', 'MGR-054', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0313', 'Julian', 'Bangura', 'Marketing', 'Southeast', '2018-12-17', 'MGR-009', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0314', 'Lakshmi', 'Watanabe', 'Customer Success', 'Southwest', '2018-07-21', 'MGR-051', 'CS Associate', 1, 'Active'),
      ('EMP-0315', 'Iris', 'Kimura', 'Product', 'Southwest', '2020-11-04', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0316', 'Tunde', 'Aguilar', 'Customer Success', 'Southeast', '2018-11-15', 'MGR-005', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0317', 'Diego', 'Németh', 'Finance', 'Southeast', '2024-08-10', 'MGR-039', 'Finance Director', 4, 'Active'),
      ('EMP-0318', 'Hana', 'Menon', 'Operations', 'Southwest', '2021-12-11', 'MGR-003', 'Operations Director', 4, 'Active'),
      ('EMP-0319', 'Elijah', 'Estrada', 'Product', 'West Coast', '2024-07-06', 'MGR-047', 'Product Manager', 2, 'Active'),
      ('EMP-0320', 'Ruth', 'Ogawa', 'Product', 'Southeast', '2023-04-06', 'MGR-054', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0321', 'Wyatt', 'Torres', 'Engineering', 'Southeast', '2020-09-17', 'MGR-029', 'Software Engineer', 2, 'Active'),
      ('EMP-0322', 'Rashid', 'Larsson', 'Operations', 'Southeast', '2022-01-10', 'MGR-011', 'Operations Director', 4, 'Active'),
      ('EMP-0323', 'Carlos', 'Ivanov', 'Operations', 'Southeast', '2023-02-28', 'MGR-003', 'Operations Analyst', 1, 'Active'),
      ('EMP-0324', 'Julian', 'Gutierrez', 'Marketing', 'Southwest', '2022-02-05', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0325', 'Greta', 'Boateng', 'Engineering', 'Northeast', '2020-12-25', 'MGR-029', 'Junior Engineer', 1, 'Active'),
      ('EMP-0326', 'Andrei', 'Braun', 'Sales', 'Southeast', '2023-11-08', 'MGR-022', 'Sales Associate', 1, 'Active'),
      ('EMP-0327', 'Hassan', 'Popov', 'Engineering', 'Southeast', '2024-02-07', 'MGR-053', 'Junior Engineer', 1, 'Active'),
      ('EMP-0328', 'Dagny', 'Sato', 'Operations', 'Southwest', '2017-07-18', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0329', 'Freya', 'Ono', 'Sales', 'Northeast', '2024-05-17', 'MGR-045', 'Sales Associate', 1, 'Active'),
      ('EMP-0330', 'Malaika', 'Joshi', 'Marketing', 'Southeast', '2020-04-19', 'MGR-058', 'VP of Marketing', 5, 'Active'),
      ('EMP-0331', 'Luciana', 'Kováč', 'Customer Success', 'West Coast', '2024-12-25', 'MGR-051', 'CS Director', 4, 'Active'),
      ('EMP-0332', 'Dante', 'Ogawa', 'Product', 'Northeast', '2024-04-16', 'MGR-013', 'VP of Product', 5, 'Active'),
      ('EMP-0333', 'Beatriz', 'Aguilar', 'Finance', 'West Coast', '2024-12-18', 'MGR-037', 'VP of Finance', 5, 'Active'),
      ('EMP-0334', 'Aisha', 'Pillai', 'Engineering', 'Southwest', '2017-08-06', 'MGR-004', 'Software Engineer', 2, 'Active'),
      ('EMP-0335', 'Zara', 'Adeyemi', 'Product', 'Midwest', '2023-01-26', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0336', 'Beatriz', 'Cruz', 'Product', 'West Coast', '2022-09-24', 'MGR-047', 'Product Manager', 2, 'Active'),
      ('EMP-0337', 'Brendan', 'Hu', 'Engineering', 'Southwest', '2019-04-12', 'MGR-053', 'Staff Engineer', 4, 'Active'),
      ('EMP-0338', 'Seiji', 'Grant', 'Finance', 'West Coast', '2025-02-17', 'MGR-021', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0339', 'Omar', 'Guo', 'Engineering', 'Southeast', '2020-02-18', 'MGR-038', 'Junior Engineer', 1, 'Active'),
      ('EMP-0340', 'Felix', 'Keita', 'Product', 'Northeast', '2020-08-14', 'MGR-054', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0341', 'Pia', 'Yamamoto', 'Customer Success', 'Midwest', '2019-01-24', 'MGR-048', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0342', 'Tatiana', 'Sharma', 'Marketing', 'Northeast', '2024-06-10', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0343', 'Thandi', 'Xu', 'Finance', 'Southwest', '2020-11-18', 'MGR-039', 'Financial Analyst', 1, 'Active'),
      ('EMP-0344', 'Yusuf', 'Vargas', 'Customer Success', 'Southwest', '2023-01-22', 'MGR-051', 'CS Manager', 2, 'Active'),
      ('EMP-0345', 'Cedric', 'Chen', 'Marketing', 'Northeast', '2017-12-04', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0346', 'Lukas', 'Nishimura', 'Customer Success', 'Southwest', '2024-11-18', 'MGR-051', 'CS Manager', 2, 'Active'),
      ('EMP-0347', 'Ximena', 'Fujita', 'Engineering', 'Southwest', '2018-12-31', 'MGR-029', 'Junior Engineer', 1, 'Active'),
      ('EMP-0348', 'Greta', 'Bhat', 'Operations', 'Midwest', '2024-07-20', 'MGR-011', 'Operations Analyst', 1, 'Active'),
      ('EMP-0349', 'Kenji', 'Zhao', 'Finance', 'Southwest', '2024-09-10', 'MGR-026', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0350', 'Esperanza', 'Santos', 'Operations', 'Northeast', '2018-07-13', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0351', 'Ines', 'García', 'Finance', 'West Coast', '2017-06-21', 'MGR-008', 'Financial Analyst', 1, 'Active'),
      ('EMP-0352', 'Viktor', 'Nair', 'Product', 'Midwest', '2024-03-30', 'MGR-054', 'Product Manager', 2, 'Active'),
      ('EMP-0353', 'Petra', 'Boateng', 'Sales', 'West Coast', '2023-02-27', 'MGR-042', 'Sales Manager', 4, 'Active'),
      ('EMP-0354', 'Svetlana', 'Eriksson', 'Product', 'West Coast', '2020-09-17', 'MGR-047', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0355', 'Petra', 'Wu', 'Operations', 'Southeast', '2024-05-24', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0356', 'Brendan', 'Cissé', 'Sales', 'Southwest', '2019-06-27', 'MGR-059', 'Account Executive', 2, 'Active'),
      ('EMP-0357', 'Felix', 'Aguilar', 'Operations', 'Southeast', '2020-06-05', 'MGR-056', 'Operations Specialist', 2, 'Active'),
      ('EMP-0358', 'Valentina', 'Asante', 'Finance', 'Northeast', '2024-01-11', 'MGR-017', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0359', 'Cormac', 'Ono', 'Operations', 'West Coast', '2017-05-31', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0360', 'Ryan', 'Cruz', 'Customer Success', 'West Coast', '2020-04-06', 'MGR-019', 'CS Director', 4, 'Active'),
      ('EMP-0361', 'Lina', 'Romero', 'Product', 'Northeast', '2018-07-29', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0362', 'Pia', 'Johansson', 'Sales', 'Southeast', '2019-12-19', 'MGR-024', 'Account Executive', 2, 'Active'),
      ('EMP-0363', 'Linh', 'Lund', 'Operations', 'Southwest', '2024-04-10', 'MGR-034', 'Operations Analyst', 1, 'Active'),
      ('EMP-0364', 'Mireille', 'Ndiaye', 'Sales', 'Southeast', '2021-02-05', 'MGR-045', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0365', 'Camila', 'Vega', 'Operations', 'Midwest', '2020-11-14', 'MGR-056', 'Operations Director', 4, 'Active'),
      ('EMP-0366', 'Andrei', 'Matsumoto', 'Engineering', 'West Coast', '2019-05-17', 'MGR-007', 'Senior Engineer', 3, 'Active'),
      ('EMP-0367', 'Takeshi', 'Németh', 'Customer Success', 'Midwest', '2022-05-27', 'MGR-051', 'CS Director', 4, 'Active'),
      ('EMP-0368', 'Sunita', 'O''Brien', 'Sales', 'Southwest', '2023-08-24', 'MGR-016', 'Sales Associate', 1, 'Active'),
      ('EMP-0369', 'Andrei', 'Svoboda', 'Sales', 'West Coast', '2023-09-21', 'MGR-045', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0370', 'Malaika', 'Lund', 'Customer Success', 'Southeast', '2021-08-10', 'MGR-048', 'CS Manager', 2, 'Active'),
      ('EMP-0371', 'Andrei', 'Gutierrez', 'Operations', 'West Coast', '2019-07-31', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0372', 'Dagny', 'Medina', 'Customer Success', 'Northeast', '2018-12-28', 'MGR-046', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0373', 'Gabriel', 'Sharma', 'Operations', 'Northeast', '2023-01-18', 'MGR-003', 'VP of Operations', 5, 'Active'),
      ('EMP-0374', 'Mei', 'Diop', 'Operations', 'Northeast', '2022-05-29', 'MGR-040', 'VP of Operations', 5, 'Active'),
      ('EMP-0375', 'Astrid', 'Wang', 'Marketing', 'West Coast', '2021-08-01', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0376', 'Maria', 'Lukić', 'Product', 'Northeast', '2020-07-17', 'MGR-050', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0377', 'Jabari', 'Guerrero', 'Operations', 'West Coast', '2020-02-03', 'MGR-040', 'Operations Specialist', 2, 'Active'),
      ('EMP-0378', 'Freya', 'Murakami', 'Finance', 'West Coast', '2020-06-10', 'MGR-043', 'Finance Manager', 3, 'Active'),
      ('EMP-0379', 'Gabriel', 'Matsumoto', 'Operations', 'Northeast', '2022-09-14', 'MGR-040', 'Operations Analyst', 1, 'Active'),
      ('EMP-0380', 'Maria', 'Sharma', 'Customer Success', 'Northeast', '2023-09-25', 'MGR-046', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0381', 'Elena', 'Endo', 'Operations', 'West Coast', '2020-03-19', 'MGR-003', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0382', 'Yara', 'Vega', 'Marketing', 'Northeast', '2023-09-22', 'MGR-014', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0383', 'Emeka', 'López', 'Marketing', 'Southeast', '2021-06-07', 'MGR-058', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0384', 'Mohammed', 'Holm', 'Marketing', 'West Coast', '2020-11-26', 'MGR-015', 'VP of Marketing', 5, 'Active'),
      ('EMP-0385', 'Julian', 'Bhat', 'Finance', 'Southwest', '2021-07-26', 'MGR-041', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0386', 'Lakshmi', 'Guo', 'Marketing', 'West Coast', '2023-06-13', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0387', 'Marco', 'Delgado', 'Product', 'Southeast', '2017-04-23', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0388', 'Kofi', 'Matsumoto', 'Customer Success', 'Midwest', '2020-12-17', 'MGR-048', 'CS Manager', 2, 'Active'),
      ('EMP-0389', 'Jia', 'Osei', 'Finance', 'Northeast', '2020-12-19', 'MGR-021', 'Finance Manager', 3, 'Active'),
      ('EMP-0390', 'Hassan', 'Salazar', 'Product', 'Northeast', '2019-09-19', 'MGR-047', 'Product Manager', 2, 'Active'),
      ('EMP-0391', 'Pia', 'Owusu', 'Customer Success', 'Southwest', '2017-11-18', 'MGR-051', 'CS Associate', 1, 'Active'),
      ('EMP-0392', 'Javier', 'Johansson', 'Customer Success', 'Southeast', '2020-07-15', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0393', 'Adam', 'Huang', 'Operations', 'Northeast', '2018-06-10', 'MGR-003', 'Operations Director', 4, 'Active'),
      ('EMP-0394', 'Suresh', 'Ogawa', 'Operations', 'Northeast', '2018-05-09', 'MGR-056', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0395', 'Cormac', 'Mensah', 'Marketing', 'Midwest', '2019-11-30', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0396', 'Jia', 'Kapoor', 'Sales', 'Southeast', '2021-09-13', 'MGR-059', 'Account Executive', 2, 'Active'),
      ('EMP-0397', 'Mateo', 'Weber', 'Sales', 'West Coast', '2018-02-14', 'MGR-059', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0398', 'Samuel', 'Reyes', 'Customer Success', 'Northeast', '2017-02-09', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0399', 'Bao', 'Mayer', 'Product', 'Midwest', '2020-05-13', 'MGR-047', 'Group Product Manager', 4, 'Active'),
      ('EMP-0400', 'Jasmine', 'Touré', 'Customer Success', 'Midwest', '2024-01-24', 'MGR-005', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0401', 'Tarquin', 'Conteh', 'Marketing', 'Southwest', '2020-12-09', 'MGR-014', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0402', 'Annika', 'Haugen', 'Operations', 'Southeast', '2021-04-10', 'MGR-033', 'Operations Director', 4, 'Active'),
      ('EMP-0403', 'Marco', 'Medina', 'Product', 'West Coast', '2017-10-20', 'MGR-002', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0404', 'Chen', 'Sugiyama', 'Product', 'Southeast', '2021-12-28', 'MGR-047', 'Product Manager', 2, 'Active'),
      ('EMP-0405', 'Priya', 'Martínez', 'Product', 'Northeast', '2025-05-05', 'MGR-002', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0406', 'Paloma', 'Holm', 'Engineering', 'Southwest', '2022-11-17', 'MGR-006', 'Staff Engineer', 4, 'Active'),
      ('EMP-0407', 'Linh', 'Koroma', 'Sales', 'Northeast', '2021-12-21', 'MGR-049', 'Sales Manager', 4, 'Active'),
      ('EMP-0408', 'Annika', 'Xu', 'Operations', 'West Coast', '2023-02-25', 'MGR-056', 'VP of Operations', 5, 'Active'),
      ('EMP-0409', 'Obi', 'Ma', 'Finance', 'West Coast', '2020-11-23', 'MGR-039', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0410', 'Jabari', 'Owusu', 'Marketing', 'Southwest', '2018-07-13', 'MGR-015', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0411', 'Amir', 'Kováč', 'Engineering', 'Southeast', '2023-09-12', 'MGR-018', 'Staff Engineer', 4, 'Active'),
      ('EMP-0412', 'Adaeze', 'Sun', 'Sales', 'Northeast', '2024-03-30', 'MGR-035', 'Sales Manager', 4, 'Active'),
      ('EMP-0413', 'Lina', 'Vega', 'Customer Success', 'West Coast', '2024-09-05', 'MGR-027', 'CS Director', 4, 'Active'),
      ('EMP-0414', 'Dante', 'Suzuki', 'Product', 'Southeast', '2020-01-20', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0415', 'Hugo', 'O''Brien', 'Sales', 'Southwest', '2018-05-28', 'MGR-059', 'Account Executive', 2, 'Active'),
      ('EMP-0416', 'Wyatt', 'Touré', 'Marketing', 'Southeast', '2022-08-04', 'MGR-015', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0417', 'Zara', 'Tanaka', 'Marketing', 'Southeast', '2022-04-10', 'MGR-014', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0418', 'Nadia', 'Joshi', 'Operations', 'Southeast', '2017-05-18', 'MGR-031', 'Operations Specialist', 2, 'Active'),
      ('EMP-0419', 'Paloma', 'Jalloh', 'Product', 'Midwest', '2018-10-12', 'MGR-002', 'VP of Product', 5, 'Active'),
      ('EMP-0420', 'Samuel', 'Mendoza', 'Engineering', 'Northeast', '2019-08-25', 'MGR-032', 'Principal Engineer', 5, 'Active'),
      ('EMP-0421', 'Esperanza', 'Sanchez', 'Engineering', 'Southwest', '2024-09-30', 'MGR-036', 'Senior Engineer', 3, 'Active'),
      ('EMP-0422', 'Emeka', 'Salazar', 'Engineering', 'West Coast', '2024-01-05', 'MGR-004', 'Software Engineer', 2, 'Active'),
      ('EMP-0423', 'Tomás', 'Ueda', 'Sales', 'Midwest', '2024-03-25', 'MGR-024', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0424', 'Rohan', 'Zhao', 'Product', 'Northeast', '2017-06-11', 'MGR-050', 'Product Manager', 2, 'Active'),
      ('EMP-0425', 'Helga', 'Flores', 'Finance', 'Midwest', '2022-04-03', 'MGR-026', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0426', 'Natsumi', 'Castillo', 'Finance', 'Midwest', '2024-02-27', 'MGR-041', 'Finance Manager', 3, 'Active'),
      ('EMP-0427', 'Marta', 'Saito', 'Sales', 'Midwest', '2024-05-20', 'MGR-044', 'Sales Manager', 4, 'Active'),
      ('EMP-0428', 'Ayumi', 'Owusu', 'Finance', 'Midwest', '2024-03-10', 'MGR-028', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0429', 'Freya', 'Nakamura', 'Sales', 'Southwest', '2018-02-09', 'MGR-010', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0430', 'Naomi', 'Conteh', 'Engineering', 'Midwest', '2025-01-19', 'MGR-006', 'Software Engineer', 2, 'Active'),
      ('EMP-0431', 'Chioma', 'Keita', 'Customer Success', 'Southwest', '2025-05-04', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0432', 'Oluwaseun', 'Yamamoto', 'Customer Success', 'Midwest', '2019-06-04', 'MGR-048', 'CS Associate', 1, 'Active'),
      ('EMP-0433', 'Elijah', 'Joshi', 'Finance', 'Northeast', '2023-04-06', 'MGR-037', 'Finance Manager', 3, 'Active'),
      ('EMP-0434', 'Hina', 'Ivanov', 'Sales', 'Northeast', '2022-08-30', 'MGR-024', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0435', 'Sean', 'Desai', 'Customer Success', 'Midwest', '2024-02-07', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0436', 'Lukas', 'Lukić', 'Customer Success', 'West Coast', '2019-11-07', 'MGR-027', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0437', 'Hiroshi', 'Rivera', 'Finance', 'Southwest', '2020-05-21', 'MGR-008', 'Finance Manager', 3, 'Active'),
      ('EMP-0438', 'Oumar', 'Hu', 'Finance', 'West Coast', '2023-05-31', 'MGR-020', 'Finance Manager', 3, 'Active'),
      ('EMP-0439', 'Marta', 'Wade', 'Sales', 'Northeast', '2020-05-15', 'MGR-012', 'Account Executive', 2, 'Active'),
      ('EMP-0440', 'Ruth', 'Takahashi', 'Operations', 'West Coast', '2018-01-26', 'MGR-033', 'Operations Director', 4, 'Active'),
      ('EMP-0441', 'Thandiwe', 'Mansaray', 'Customer Success', 'Southeast', '2018-05-09', 'MGR-052', 'CS Manager', 2, 'Active'),
      ('EMP-0442', 'Anya', 'Shimizu', 'Finance', 'Southwest', '2023-05-03', 'MGR-020', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0443', 'Ryan', 'Kondo', 'Customer Success', 'West Coast', '2018-01-04', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0444', 'Alejandro', 'Holm', 'Operations', 'Midwest', '2022-08-18', 'MGR-040', 'Operations Analyst', 1, 'Active'),
      ('EMP-0445', 'Samuel', 'Ueda', 'Operations', 'West Coast', '2023-11-29', 'MGR-031', 'Operations Specialist', 2, 'Active'),
      ('EMP-0446', 'Divya', 'López', 'Engineering', 'Southeast', '2020-11-27', 'MGR-018', 'Software Engineer', 2, 'Active'),
      ('EMP-0447', 'Noor', 'Romero', 'Customer Success', 'Southeast', '2021-12-10', 'MGR-005', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0448', 'Raj', 'Suzuki', 'Product', 'Southwest', '2023-12-19', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0449', 'Sven', 'Shimizu', 'Operations', 'Southeast', '2019-05-07', 'MGR-031', 'Operations Analyst', 1, 'Active'),
      ('EMP-0450', 'Björn', 'Kim', 'Operations', 'West Coast', '2022-11-28', 'MGR-003', 'VP of Operations', 5, 'Active'),
      ('EMP-0451', 'Desmond', 'Sesay', 'Engineering', 'Southeast', '2017-02-04', 'MGR-006', 'Senior Engineer', 3, 'Active'),
      ('EMP-0452', 'Chukwu', 'Morales', 'Engineering', 'Midwest', '2024-04-13', 'MGR-032', 'Staff Engineer', 4, 'Active'),
      ('EMP-0453', 'Brendan', 'Ueda', 'Customer Success', 'West Coast', '2019-02-03', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0454', 'Oluwaseun', 'Joshi', 'Finance', 'Midwest', '2021-05-31', 'MGR-057', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0455', 'Marisol', 'Berg', 'Finance', 'Midwest', '2024-01-08', 'MGR-026', 'Finance Director', 4, 'Active'),
      ('EMP-0456', 'Camila', 'Kobayashi', 'Marketing', 'Southeast', '2017-12-26', 'MGR-058', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0457', 'Hina', 'Koroma', 'Finance', 'Midwest', '2018-06-24', 'MGR-021', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0458', 'Elijah', 'Sato', 'Operations', 'Northeast', '2023-05-03', 'MGR-025', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0459', 'Zara', 'Santos', 'Customer Success', 'Midwest', '2021-08-23', 'MGR-046', 'CS Director', 4, 'Active'),
      ('EMP-0460', 'Hana', 'Flores', 'Engineering', 'West Coast', '2023-10-17', 'MGR-053', 'Senior Engineer', 3, 'Active'),
      ('EMP-0461', 'Chioma', 'Aguilar', 'Sales', 'West Coast', '2022-04-05', 'MGR-059', 'Sales Manager', 4, 'Active'),
      ('EMP-0462', 'Leila', 'Zhang', 'Sales', 'Northeast', '2017-03-03', 'MGR-023', 'Sales Associate', 1, 'Active'),
      ('EMP-0463', 'Nikolai', 'Petrov', 'Sales', 'Southeast', '2022-06-30', 'MGR-059', 'Sales Manager', 4, 'Active'),
      ('EMP-0464', 'Oluwaseun', 'Ly', 'Product', 'Southeast', '2021-06-03', 'MGR-054', 'Group Product Manager', 4, 'Active'),
      ('EMP-0465', 'Oluwaseun', 'Sanchez', 'Finance', 'West Coast', '2025-03-31', 'MGR-008', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0466', 'Marisol', 'Rao', 'Operations', 'Northeast', '2023-11-17', 'MGR-003', 'Operations Specialist', 2, 'Active'),
      ('EMP-0467', 'Mohammed', 'Morita', 'Engineering', 'Northeast', '2024-10-22', 'MGR-038', 'Staff Engineer', 4, 'Active'),
      ('EMP-0468', 'Julian', 'Lin', 'Product', 'Northeast', '2018-01-05', 'MGR-047', 'Group Product Manager', 4, 'Active'),
      ('EMP-0469', 'Lakshmi', 'Sylla', 'Product', 'Midwest', '2024-12-07', 'MGR-050', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0470', 'Sakura', 'Fofana', 'Finance', 'Northeast', '2018-08-16', 'MGR-020', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0471', 'Samir', 'Rao', 'Product', 'Northeast', '2018-06-23', 'MGR-013', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0472', 'Fernanda', 'Sakho', 'Customer Success', 'Southwest', '2022-07-15', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0473', 'Rena', 'Dutta', 'Engineering', 'Northeast', '2020-02-14', 'MGR-053', 'Staff Engineer', 4, 'Active'),
      ('EMP-0474', 'Noor', 'Okafor', 'Sales', 'Southwest', '2023-10-08', 'MGR-023', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0475', 'Freya', 'Zhang', 'Product', 'Midwest', '2024-10-03', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0476', 'Chukwu', 'Okafor', 'Engineering', 'Midwest', '2021-04-02', 'MGR-006', 'Software Engineer', 2, 'Active'),
      ('EMP-0477', 'Oumar', 'Fujita', 'Finance', 'Southeast', '2024-10-21', 'MGR-021', 'Finance Manager', 3, 'Active'),
      ('EMP-0478', 'Thandi', 'López', 'Operations', 'West Coast', '2024-12-05', 'MGR-033', 'VP of Operations', 5, 'Active'),
      ('EMP-0479', 'Iris', 'Nilsson', 'Sales', 'West Coast', '2022-10-30', 'MGR-059', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0480', 'Astrid', 'Hayashi', 'Sales', 'Southwest', '2022-03-20', 'MGR-049', 'Sales Associate', 1, 'Active'),
      ('EMP-0481', 'Sunita', 'Chen', 'Marketing', 'Midwest', '2024-02-25', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0482', 'Sofia', 'Shimizu', 'Marketing', 'West Coast', '2017-01-26', 'MGR-009', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0483', 'Fatima', 'Takahashi', 'Sales', 'Midwest', '2024-07-17', 'MGR-042', 'Sales Manager', 4, 'Active'),
      ('EMP-0484', 'Thandiwe', 'Matsuda', 'Customer Success', 'Southeast', '2017-08-18', 'MGR-052', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0485', 'Divya', 'Fujita', 'Customer Success', 'Midwest', '2018-09-04', 'MGR-027', 'CS Associate', 1, 'Active'),
      ('EMP-0486', 'Andrei', 'Weber', 'Finance', 'Southeast', '2018-04-24', 'MGR-060', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0487', 'Isabella', 'Salazar', 'Sales', 'Midwest', '2020-05-24', 'MGR-022', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0488', 'Yara', 'Sharma', 'Operations', 'West Coast', '2022-05-31', 'MGR-025', 'Operations Analyst', 1, 'Active'),
      ('EMP-0489', 'Annika', 'Kowalski', 'Customer Success', 'Southwest', '2022-10-16', 'MGR-051', 'CS Director', 4, 'Active'),
      ('EMP-0490', 'Karina', 'Boateng', 'Engineering', 'Midwest', '2024-09-15', 'MGR-053', 'Principal Engineer', 5, 'Active'),
      ('EMP-0491', 'Karina', 'Koroma', 'Engineering', 'West Coast', '2024-03-01', 'MGR-018', 'Staff Engineer', 4, 'Active'),
      ('EMP-0492', 'Finn', 'Andersen', 'Marketing', 'Northeast', '2018-04-14', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0493', 'Xiomara', 'Sesay', 'Sales', 'Midwest', '2018-12-03', 'MGR-012', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0494', 'Fatima', 'Lund', 'Product', 'Southwest', '2017-08-09', 'MGR-002', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0495', 'Samir', 'Romero', 'Marketing', 'Midwest', '2019-03-23', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0496', 'Sienna', 'Watanabe', 'Operations', 'Midwest', '2024-12-19', 'MGR-056', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0497', 'Jabari', 'Kapoor', 'Operations', 'Northeast', '2024-06-17', 'MGR-034', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0498', 'Paloma', 'Suzuki', 'Marketing', 'Southeast', '2018-12-01', 'MGR-015', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0499', 'Amara', 'Desai', 'Finance', 'Southwest', '2022-12-23', 'MGR-039', 'Finance Director', 4, 'Active'),
      ('EMP-0500', 'Emeka', 'Menon', 'Operations', 'Southwest', '2024-10-13', 'MGR-040', 'Operations Specialist', 2, 'Active'),
      ('EMP-0501', 'Rashid', 'Takahashi', 'Product', 'Southwest', '2024-12-25', 'MGR-054', 'Group Product Manager', 4, 'Active'),
      ('EMP-0502', 'Tarquin', 'Watanabe', 'Customer Success', 'Southeast', '2021-07-21', 'MGR-005', 'CS Manager', 2, 'Active'),
      ('EMP-0503', 'Jasmine', 'Sharma', 'Sales', 'Northeast', '2024-02-19', 'MGR-010', 'Sales Manager', 4, 'Active'),
      ('EMP-0504', 'Padma', 'Estrada', 'Operations', 'Northeast', '2020-07-20', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0505', 'Esteban', 'López', 'Finance', 'Southwest', '2022-09-22', 'MGR-037', 'Finance Manager', 3, 'Active'),
      ('EMP-0506', 'Anya', 'Smith', 'Product', 'West Coast', '2021-01-11', 'MGR-002', 'Group Product Manager', 4, 'Active'),
      ('EMP-0507', 'Ryan', 'Wu', 'Product', 'Southeast', '2021-11-18', 'MGR-054', 'Product Manager', 2, 'Active'),
      ('EMP-0508', 'Tunde', 'Mendoza', 'Customer Success', 'Southeast', '2024-07-07', 'MGR-019', 'CS Manager', 2, 'Active'),
      ('EMP-0509', 'Cedric', 'Ma', 'Sales', 'Southwest', '2021-08-31', 'MGR-042', 'Sales Associate', 1, 'Active'),
      ('EMP-0510', 'Andre', 'Hu', 'Customer Success', 'Southeast', '2019-07-14', 'MGR-019', 'CS Manager', 2, 'Active'),
      ('EMP-0511', 'Rashid', 'Morita', 'Marketing', 'Southeast', '2023-06-19', 'MGR-015', 'VP of Marketing', 5, 'Active'),
      ('EMP-0512', 'Sven', 'Ono', 'Operations', 'Southwest', '2025-03-15', 'MGR-033', 'Operations Analyst', 1, 'Active'),
      ('EMP-0513', 'Patrick', 'Lund', 'Product', 'Southwest', '2023-01-18', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0514', 'Wei', 'Lund', 'Operations', 'West Coast', '2023-06-09', 'MGR-034', 'VP of Operations', 5, 'Active'),
      ('EMP-0515', 'Winston', 'Moreno', 'Product', 'West Coast', '2024-01-22', 'MGR-050', 'Product Manager', 2, 'Active'),
      ('EMP-0516', 'Iris', 'Müller', 'Marketing', 'Southeast', '2022-09-02', 'MGR-009', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0517', 'Oumar', 'Conteh', 'Engineering', 'Southwest', '2023-08-21', 'MGR-007', 'Senior Engineer', 3, 'Active'),
      ('EMP-0518', 'Rashid', 'Ueda', 'Sales', 'West Coast', '2020-11-05', 'MGR-012', 'Sales Manager', 4, 'Active'),
      ('EMP-0519', 'Sunita', 'Endo', 'Sales', 'Southeast', '2018-11-17', 'MGR-022', 'Sales Manager', 4, 'Active'),
      ('EMP-0520', 'Lakshmi', 'Singh', 'Sales', 'Southeast', '2020-05-19', 'MGR-042', 'Account Executive', 2, 'Active'),
      ('EMP-0521', 'Paloma', 'Castillo', 'Sales', 'West Coast', '2017-02-18', 'MGR-023', 'Sales Manager', 4, 'Active'),
      ('EMP-0522', 'Thandi', 'Johansson', 'Engineering', 'West Coast', '2021-11-04', 'MGR-053', 'Senior Engineer', 3, 'Active'),
      ('EMP-0523', 'Svetlana', 'Conteh', 'Product', 'West Coast', '2024-07-28', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0524', 'Mateo', 'Hansen', 'Finance', 'Southwest', '2017-10-06', 'MGR-008', 'Finance Manager', 3, 'Active'),
      ('EMP-0525', 'Arjun', 'Inoue', 'Sales', 'Southwest', '2018-01-12', 'MGR-010', 'Sales Associate', 1, 'Active'),
      ('EMP-0526', 'Gabriel', 'López', 'Customer Success', 'West Coast', '2024-05-12', 'MGR-052', 'CS Associate', 1, 'Active'),
      ('EMP-0527', 'Enrique', 'Bangura', 'Operations', 'Southwest', '2020-02-07', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0528', 'Oumar', 'Adeyemi', 'Operations', 'Southeast', '2017-09-04', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0529', 'Yara', 'Vogt', 'Operations', 'Northeast', '2018-03-21', 'MGR-025', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0530', 'Catalina', 'Svoboda', 'Engineering', 'Southwest', '2023-05-30', 'MGR-029', 'Junior Engineer', 1, 'Active'),
      ('EMP-0531', 'James', 'Okafor', 'Product', 'Southeast', '2024-11-07', 'MGR-047', 'Product Manager', 2, 'Active'),
      ('EMP-0532', 'Nkechi', 'Aguilar', 'Operations', 'Southeast', '2017-10-15', 'MGR-031', 'Operations Director', 4, 'Active'),
      ('EMP-0533', 'Pia', 'Fofana', 'Product', 'Midwest', '2024-02-03', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0534', 'Dante', 'Li', 'Sales', 'West Coast', '2021-04-23', 'MGR-049', 'Sales Associate', 1, 'Active'),
      ('EMP-0535', 'Pia', 'Ueda', 'Engineering', 'Southeast', '2018-07-28', 'MGR-004', 'Staff Engineer', 4, 'Active'),
      ('EMP-0536', 'Javier', 'Shimizu', 'Operations', 'West Coast', '2022-01-15', 'MGR-003', 'VP of Operations', 5, 'Active'),
      ('EMP-0537', 'Tatiana', 'Andersen', 'Sales', 'West Coast', '2024-08-09', 'MGR-044', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0538', 'Björn', 'Barry', 'Product', 'Southwest', '2023-12-08', 'MGR-002', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0539', 'Viktor', 'Watanabe', 'Operations', 'West Coast', '2023-08-18', 'MGR-011', 'Operations Specialist', 2, 'Active'),
      ('EMP-0540', 'Padma', 'Horváth', 'Engineering', 'Northeast', '2025-04-11', 'MGR-032', 'Software Engineer', 2, 'Active'),
      ('EMP-0541', 'Lukas', 'Chen', 'Finance', 'Northeast', '2018-05-10', 'MGR-026', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0542', 'Andrei', 'Rojas', 'Sales', 'West Coast', '2018-02-14', 'MGR-049', 'Sales Associate', 1, 'Active'),
      ('EMP-0543', 'Maria', 'Patel', 'Sales', 'Southwest', '2023-08-29', 'MGR-023', 'Sales Manager', 4, 'Active'),
      ('EMP-0544', 'Kaia', 'Pillai', 'Operations', 'Southeast', '2018-12-16', 'MGR-003', 'Operations Specialist', 2, 'Active'),
      ('EMP-0545', 'Marisol', 'Mansaray', 'Operations', 'Southwest', '2019-02-26', 'MGR-011', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0546', 'Javier', 'Camara', 'Sales', 'Southeast', '2024-05-24', 'MGR-022', 'Sales Manager', 4, 'Active'),
      ('EMP-0547', 'Paloma', 'Salazar', 'Sales', 'Northeast', '2017-06-26', 'MGR-010', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0548', 'Padma', 'Roth', 'Engineering', 'Southwest', '2023-01-11', 'MGR-007', 'Staff Engineer', 4, 'Active'),
      ('EMP-0549', 'Rashid', 'Iyer', 'Finance', 'West Coast', '2019-03-26', 'MGR-057', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0550', 'Takeshi', 'Mensah', 'Sales', 'Southeast', '2021-03-19', 'MGR-022', 'Sales Manager', 4, 'Active'),
      ('EMP-0551', 'Devi', 'Vogt', 'Operations', 'Northeast', '2018-07-13', 'MGR-056', 'Operations Specialist', 2, 'Active'),
      ('EMP-0552', 'Tomás', 'Nakamura', 'Product', 'West Coast', '2018-07-14', 'MGR-002', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0553', 'Kofi', 'Bangura', 'Finance', 'Northeast', '2024-02-27', 'MGR-043', 'Finance Director', 4, 'Active'),
      ('EMP-0554', 'Nkechi', 'Touré', 'Finance', 'Southeast', '2020-02-18', 'MGR-008', 'Finance Director', 4, 'Active'),
      ('EMP-0555', 'Kofi', 'Lin', 'Sales', 'West Coast', '2021-09-08', 'MGR-010', 'Sales Manager', 4, 'Active'),
      ('EMP-0556', 'Andre', 'Diop', 'Operations', 'Southeast', '2024-10-24', 'MGR-011', 'Operations Director', 4, 'Active'),
      ('EMP-0557', 'Miguel', 'Touré', 'Sales', 'Midwest', '2024-04-06', 'MGR-012', 'Account Executive', 2, 'Active'),
      ('EMP-0558', 'Maxwell', 'Wade', 'Engineering', 'Southeast', '2018-07-22', 'MGR-032', 'Senior Engineer', 3, 'Active'),
      ('EMP-0559', 'James', 'Yamamoto', 'Operations', 'Midwest', '2020-04-29', 'MGR-040', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0560', 'Thandiwe', 'Tanaka', 'Finance', 'Midwest', '2018-03-31', 'MGR-037', 'Finance Director', 4, 'Active'),
      ('EMP-0561', 'Beatriz', 'Hernández', 'Finance', 'Northeast', '2020-10-03', 'MGR-021', 'Financial Analyst', 1, 'Active'),
      ('EMP-0562', 'Amira', 'Cruz', 'Marketing', 'Midwest', '2022-08-25', 'MGR-058', 'Marketing Director', 4, 'Active'),
      ('EMP-0563', 'Suresh', 'Arai', 'Customer Success', 'Southwest', '2022-12-19', 'MGR-051', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0564', 'Tariq', 'Ito', 'Operations', 'Southwest', '2019-01-03', 'MGR-033', 'Operations Analyst', 1, 'Active'),
      ('EMP-0565', 'Zara', 'Salazar', 'Sales', 'Northeast', '2024-01-14', 'MGR-010', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0566', 'Priya', 'Hayashi', 'Sales', 'Southwest', '2019-08-10', 'MGR-044', 'Sales Associate', 1, 'Active'),
      ('EMP-0567', 'Annika', 'Ueda', 'Finance', 'West Coast', '2021-12-29', 'MGR-039', 'Finance Director', 4, 'Active'),
      ('EMP-0568', 'Jabari', 'Matsumoto', 'Operations', 'Midwest', '2017-07-13', 'MGR-025', 'VP of Operations', 5, 'Active'),
      ('EMP-0569', 'Mina', 'Guerrero', 'Marketing', 'Northeast', '2024-12-10', 'MGR-014', 'VP of Marketing', 5, 'Active'),
      ('EMP-0570', 'Tomás', 'Rojas', 'Marketing', 'Midwest', '2023-04-23', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0571', 'Mina', 'Mayer', 'Marketing', 'Southwest', '2021-07-16', 'MGR-058', 'VP of Marketing', 5, 'Active'),
      ('EMP-0572', 'Mireille', 'Camara', 'Marketing', 'Midwest', '2020-04-02', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0573', 'Amir', 'Johansson', 'Sales', 'West Coast', '2017-04-12', 'MGR-035', 'Sales Associate', 1, 'Active'),
      ('EMP-0574', 'Dmitri', 'Ly', 'Product', 'Northeast', '2019-06-29', 'MGR-047', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0575', 'Isabella', 'Guo', 'Operations', 'Northeast', '2023-10-07', 'MGR-003', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0576', 'Hina', 'Murakami', 'Operations', 'Midwest', '2020-11-13', 'MGR-034', 'Operations Analyst', 1, 'Active'),
      ('EMP-0577', 'Catalina', 'Németh', 'Customer Success', 'Southeast', '2025-03-01', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0578', 'Isabella', 'Kowalski', 'Sales', 'Midwest', '2022-11-22', 'MGR-024', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0579', 'Kaia', 'Németh', 'Sales', 'West Coast', '2023-05-16', 'MGR-016', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0580', 'Marisol', 'Wade', 'Marketing', 'Southeast', '2022-03-14', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0581', 'Troy', 'Liu', 'Product', 'Midwest', '2022-07-08', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0582', 'Rena', 'Mendoza', 'Finance', 'Southeast', '2019-11-23', 'MGR-055', 'Finance Manager', 3, 'Active'),
      ('EMP-0583', 'Carlos', 'Svoboda', 'Sales', 'West Coast', '2020-08-02', 'MGR-042', 'Sales Associate', 1, 'Active'),
      ('EMP-0584', 'Chukwu', 'Medina', 'Product', 'Midwest', '2020-04-09', 'MGR-054', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0585', 'Mateo', 'Watanabe', 'Finance', 'Northeast', '2020-07-19', 'MGR-055', 'Finance Manager', 3, 'Active'),
      ('EMP-0586', 'Yuki', 'Mayer', 'Finance', 'Midwest', '2017-02-22', 'MGR-020', 'Finance Director', 4, 'Active'),
      ('EMP-0587', 'Mina', 'Ivanov', 'Sales', 'Northeast', '2019-02-11', 'MGR-044', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0588', 'Lakshmi', 'Gupta', 'Engineering', 'Southeast', '2024-10-01', 'MGR-030', 'Software Engineer', 2, 'Active'),
      ('EMP-0589', 'Jia', 'Takahashi', 'Product', 'Midwest', '2018-05-01', 'MGR-013', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0590', 'Amira', 'Gupta', 'Engineering', 'Southeast', '2018-04-03', 'MGR-006', 'Senior Engineer', 3, 'Active'),
      ('EMP-0591', 'Amara', 'Nakamura', 'Customer Success', 'West Coast', '2022-04-06', 'MGR-005', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0592', 'Yuki', 'Liu', 'Finance', 'Northeast', '2019-03-31', 'MGR-020', 'Finance Manager', 3, 'Active'),
      ('EMP-0593', 'Valentina', 'Ono', 'Marketing', 'Midwest', '2022-08-13', 'MGR-014', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0594', 'Aisha', 'Diop', 'Sales', 'Northeast', '2018-12-05', 'MGR-044', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0595', 'Paloma', 'Kapoor', 'Product', 'West Coast', '2024-07-21', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0596', 'Luciana', 'Matsumoto', 'Operations', 'Southwest', '2020-07-11', 'MGR-011', 'Operations Director', 4, 'Active'),
      ('EMP-0597', 'Elsa', 'Campos', 'Product', 'Southwest', '2022-07-16', 'MGR-002', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0598', 'Catalina', 'Cruz', 'Finance', 'Southeast', '2021-10-19', 'MGR-021', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0599', 'Aisha', 'Barry', 'Product', 'Southwest', '2022-11-11', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0600', 'Diego', 'Reddy', 'Engineering', 'Midwest', '2020-10-19', 'MGR-018', 'Principal Engineer', 5, 'Active'),
      ('EMP-0601', 'Fernanda', 'Huang', 'Customer Success', 'West Coast', '2024-03-22', 'MGR-046', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0602', 'Zara', 'Roth', 'Engineering', 'Southwest', '2022-07-30', 'MGR-018', 'Software Engineer', 2, 'Active'),
      ('EMP-0603', 'Sofia', 'Salazar', 'Product', 'Southwest', '2021-04-17', 'MGR-054', 'VP of Product', 5, 'Active'),
      ('EMP-0604', 'Ingrid', 'Pillai', 'Customer Success', 'Southeast', '2019-04-08', 'MGR-027', 'CS Director', 4, 'Active'),
      ('EMP-0605', 'Javier', 'Sakho', 'Engineering', 'Southwest', '2018-05-03', 'MGR-032', 'Principal Engineer', 5, 'Active'),
      ('EMP-0606', 'Freya', 'Campos', 'Product', 'Midwest', '2018-11-04', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0607', 'Sven', 'Ndiaye', 'Product', 'Southeast', '2024-09-08', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0608', 'Dmitri', 'Bakker', 'Marketing', 'Southeast', '2021-03-28', 'MGR-015', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0609', 'Mei', 'Martínez', 'Customer Success', 'Midwest', '2025-04-28', 'MGR-048', 'CS Manager', 2, 'Active'),
      ('EMP-0610', 'Pia', 'Traoré', 'Marketing', 'Southwest', '2019-10-12', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0611', 'Viktor', 'Boateng', 'Marketing', 'Northeast', '2020-08-28', 'MGR-009', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0612', 'Chen', 'O''Brien', 'Product', 'Southeast', '2020-07-20', 'MGR-050', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0613', 'Svetlana', 'Ramírez', 'Marketing', 'Southeast', '2024-06-26', 'MGR-015', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0614', 'Fernanda', 'Osei', 'Customer Success', 'West Coast', '2019-12-23', 'MGR-005', 'CS Manager', 2, 'Active'),
      ('EMP-0615', 'Mohammed', 'Ono', 'Engineering', 'West Coast', '2017-10-03', 'MGR-053', 'Software Engineer', 2, 'Active'),
      ('EMP-0616', 'Ingrid', 'Moreno', 'Finance', 'Midwest', '2023-01-21', 'MGR-028', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0617', 'Sean', 'Novak', 'Engineering', 'West Coast', '2023-06-21', 'MGR-036', 'Staff Engineer', 4, 'Active'),
      ('EMP-0618', 'Padma', 'Ma', 'Finance', 'Southwest', '2021-02-01', 'MGR-039', 'Finance Manager', 3, 'Active'),
      ('EMP-0619', 'Adaeze', 'Traoré', 'Marketing', 'Southwest', '2021-08-17', 'MGR-015', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0620', 'Tatiana', 'Yang', 'Engineering', 'Northeast', '2019-10-03', 'MGR-029', 'Software Engineer', 2, 'Active'),
      ('EMP-0621', 'Yara', 'Fischer', 'Marketing', 'Northeast', '2020-02-12', 'MGR-014', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0622', 'Priya', 'Tanaka', 'Customer Success', 'Southwest', '2020-05-05', 'MGR-052', 'CS Manager', 2, 'Active'),
      ('EMP-0623', 'Mohammed', 'Sun', 'Customer Success', 'Northeast', '2023-05-28', 'MGR-051', 'CS Manager', 2, 'Active'),
      ('EMP-0624', 'Elijah', 'Inoue', 'Operations', 'Southwest', '2018-05-16', 'MGR-034', 'Operations Specialist', 2, 'Active'),
      ('EMP-0625', 'Andre', 'Touré', 'Sales', 'Southwest', '2020-01-30', 'MGR-042', 'Account Executive', 2, 'Active'),
      ('EMP-0626', 'Sven', 'Wu', 'Finance', 'Southeast', '2019-10-07', 'MGR-026', 'Finance Manager', 3, 'Active'),
      ('EMP-0627', 'Viktor', 'O''Brien', 'Product', 'West Coast', '2025-04-17', 'MGR-002', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0628', 'Chukwu', 'Liu', 'Finance', 'Northeast', '2021-05-11', 'MGR-008', 'Finance Director', 4, 'Active'),
      ('EMP-0629', 'Marisol', 'Sharma', 'Customer Success', 'Northeast', '2018-10-19', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0630', 'Chioma', 'Barry', 'Operations', 'Southeast', '2020-09-24', 'MGR-040', 'VP of Operations', 5, 'Active'),
      ('EMP-0631', 'Dagny', 'Petrov', 'Marketing', 'Southeast', '2023-02-22', 'MGR-015', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0632', 'Aiko', 'Iyer', 'Customer Success', 'Northeast', '2019-03-31', 'MGR-051', 'CS Associate', 1, 'Active'),
      ('EMP-0633', 'Hana', 'Navarro', 'Product', 'Southeast', '2020-08-01', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0634', 'Annika', 'Rivera', 'Sales', 'Southwest', '2019-01-16', 'MGR-035', 'Account Executive', 2, 'Active'),
      ('EMP-0635', 'Tarquin', 'Vogt', 'Product', 'Northeast', '2022-03-10', 'MGR-013', 'VP of Product', 5, 'Active'),
      ('EMP-0636', 'Rena', 'Svoboda', 'Sales', 'Southwest', '2018-11-28', 'MGR-045', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0637', 'Wyatt', 'Andersen', 'Sales', 'Northeast', '2019-12-27', 'MGR-023', 'Account Executive', 2, 'Active'),
      ('EMP-0638', 'Rena', 'Touré', 'Customer Success', 'Midwest', '2019-02-15', 'MGR-046', 'CS Director', 4, 'Active'),
      ('EMP-0639', 'Rashid', 'Saito', 'Operations', 'Northeast', '2024-09-03', 'MGR-056', 'Operations Specialist', 2, 'Active'),
      ('EMP-0640', 'Esperanza', 'Yoshida', 'Product', 'Southeast', '2025-04-04', 'MGR-054', 'Group Product Manager', 4, 'Active'),
      ('EMP-0641', 'Rashid', 'Lund', 'Marketing', 'West Coast', '2023-09-17', 'MGR-009', 'VP of Marketing', 5, 'Active'),
      ('EMP-0642', 'Esperanza', 'Murakami', 'Sales', 'West Coast', '2019-01-05', 'MGR-023', 'Sales Associate', 1, 'Active'),
      ('EMP-0643', 'Hana', 'López', 'Marketing', 'West Coast', '2019-12-03', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0644', 'Valentina', 'Mendoza', 'Operations', 'Midwest', '2019-12-15', 'MGR-033', 'VP of Operations', 5, 'Active'),
      ('EMP-0645', 'Nkechi', 'Kobayashi', 'Finance', 'Southeast', '2018-09-01', 'MGR-008', 'Financial Analyst', 1, 'Active'),
      ('EMP-0646', 'Sienna', 'Ma', 'Engineering', 'Southeast', '2020-12-31', 'MGR-038', 'Junior Engineer', 1, 'Active'),
      ('EMP-0647', 'Zara', 'Liu', 'Marketing', 'Southwest', '2020-03-09', 'MGR-014', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0648', 'Lukas', 'Wade', 'Engineering', 'West Coast', '2019-01-10', 'MGR-032', 'Staff Engineer', 4, 'Active'),
      ('EMP-0649', 'Felix', 'Müller', 'Marketing', 'Southwest', '2023-08-16', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0650', 'Amir', 'Roth', 'Product', 'Midwest', '2017-01-24', 'MGR-047', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0651', 'Helga', 'Gupta', 'Sales', 'Southwest', '2020-03-04', 'MGR-024', 'Sales Manager', 4, 'Active'),
      ('EMP-0652', 'Mohammed', 'Peña', 'Marketing', 'Northeast', '2021-06-22', 'MGR-009', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0653', 'Arjun', 'Owusu', 'Engineering', 'Midwest', '2021-11-06', 'MGR-029', 'Senior Engineer', 3, 'Active'),
      ('EMP-0654', 'Seiji', 'Guo', 'Sales', 'Southeast', '2021-05-09', 'MGR-042', 'Account Executive', 2, 'Active'),
      ('EMP-0655', 'Seiji', 'Romero', 'Sales', 'Southeast', '2018-01-16', 'MGR-010', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0656', 'Celine', 'Braun', 'Finance', 'West Coast', '2022-04-02', 'MGR-037', 'Financial Analyst', 1, 'Active'),
      ('EMP-0657', 'Idris', 'Joshi', 'Finance', 'Southeast', '2017-07-15', 'MGR-041', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0658', 'Sunita', 'Watanabe', 'Operations', 'West Coast', '2020-12-26', 'MGR-033', 'Operations Director', 4, 'Active'),
      ('EMP-0659', 'Daisuke', 'Diallo', 'Customer Success', 'Northeast', '2017-07-05', 'MGR-005', 'CS Director', 4, 'Active'),
      ('EMP-0660', 'Greta', 'Tall', 'Customer Success', 'Midwest', '2019-02-06', 'MGR-019', 'CS Manager', 2, 'Active'),
      ('EMP-0661', 'Hugo', 'Kim', 'Engineering', 'Southeast', '2018-12-05', 'MGR-036', 'Junior Engineer', 1, 'Active'),
      ('EMP-0662', 'Joaquin', 'Ueda', 'Marketing', 'West Coast', '2023-12-02', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0663', 'Kwame', 'Nguyen', 'Sales', 'Southwest', '2024-10-21', 'MGR-022', 'Sales Manager', 4, 'Active'),
      ('EMP-0664', 'Lina', 'Ma', 'Customer Success', 'West Coast', '2020-05-17', 'MGR-052', 'CS Manager', 2, 'Active'),
      ('EMP-0665', 'Celine', 'Iyer', 'Operations', 'Southeast', '2022-01-16', 'MGR-031', 'Operations Analyst', 1, 'Active'),
      ('EMP-0666', 'Nathan', 'Németh', 'Customer Success', 'Southeast', '2023-09-07', 'MGR-051', 'CS Director', 4, 'Active'),
      ('EMP-0667', 'Luciana', 'Lin', 'Product', 'West Coast', '2022-06-22', 'MGR-013', 'VP of Product', 5, 'Active'),
      ('EMP-0668', 'Tariq', 'Kimura', 'Product', 'Southeast', '2018-04-24', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0669', 'Mina', 'Rao', 'Product', 'Northeast', '2021-11-30', 'MGR-013', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0670', 'Sienna', 'Gupta', 'Marketing', 'Southeast', '2024-07-20', 'MGR-015', 'VP of Marketing', 5, 'Active'),
      ('EMP-0671', 'Isabella', 'Menon', 'Sales', 'Northeast', '2023-10-18', 'MGR-042', 'Account Executive', 2, 'Active'),
      ('EMP-0672', 'Rashid', 'Nair', 'Finance', 'Southwest', '2021-01-09', 'MGR-026', 'VP of Finance', 5, 'Active'),
      ('EMP-0673', 'Suresh', 'Nakamura', 'Customer Success', 'Southwest', '2018-04-12', 'MGR-048', 'CS Manager', 2, 'Active'),
      ('EMP-0674', 'Daniel', 'Chen', 'Customer Success', 'West Coast', '2018-09-12', 'MGR-052', 'CS Manager', 2, 'Active'),
      ('EMP-0675', 'Finn', 'Delgado', 'Customer Success', 'Southwest', '2023-11-06', 'MGR-048', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0676', 'Diego', 'Torres', 'Product', 'Southwest', '2021-01-21', 'MGR-013', 'Group Product Manager', 4, 'Active'),
      ('EMP-0677', 'Svetlana', 'Owusu', 'Product', 'Midwest', '2018-07-19', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0678', 'Maria', 'Sanchez', 'Customer Success', 'Southeast', '2022-08-31', 'MGR-019', 'CS Manager', 2, 'Active'),
      ('EMP-0679', 'Patrick', 'Kobayashi', 'Customer Success', 'West Coast', '2019-07-24', 'MGR-019', 'CS Manager', 2, 'Active'),
      ('EMP-0680', 'Bao', 'Mendoza', 'Engineering', 'Southeast', '2017-02-10', 'MGR-038', 'Junior Engineer', 1, 'Active'),
      ('EMP-0681', 'Jasmine', 'Bakker', 'Customer Success', 'Southwest', '2024-03-12', 'MGR-019', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0682', 'Karina', 'Bangura', 'Operations', 'Southeast', '2024-11-10', 'MGR-033', 'Operations Director', 4, 'Active'),
      ('EMP-0683', 'Valentina', 'Diop', 'Finance', 'Northeast', '2022-01-02', 'MGR-055', 'Finance Director', 4, 'Active'),
      ('EMP-0684', 'Tatiana', 'Eriksson', 'Marketing', 'Southwest', '2020-10-02', 'MGR-058', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0685', 'Lukas', 'Sharma', 'Finance', 'West Coast', '2020-10-27', 'MGR-060', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0686', 'Naomi', 'Svoboda', 'Sales', 'Midwest', '2022-09-01', 'MGR-012', 'Sales Manager', 4, 'Active'),
      ('EMP-0687', 'Nadia', 'Rodriguez', 'Customer Success', 'Southwest', '2023-06-03', 'MGR-051', 'CS Manager', 2, 'Active'),
      ('EMP-0688', 'Cormac', 'Maeda', 'Product', 'West Coast', '2019-08-16', 'MGR-047', 'Group Product Manager', 4, 'Active'),
      ('EMP-0689', 'Suki', 'Ivanov', 'Marketing', 'West Coast', '2021-01-19', 'MGR-058', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0690', 'Jasmine', 'Nishimura', 'Sales', 'Southeast', '2017-11-16', 'MGR-024', 'Account Executive', 2, 'Active'),
      ('EMP-0691', 'Esperanza', 'Castillo', 'Finance', 'Southeast', '2021-12-08', 'MGR-057', 'Finance Manager', 3, 'Active'),
      ('EMP-0692', 'Mina', 'Kowalski', 'Finance', 'Northeast', '2022-02-18', 'MGR-020', 'Finance Manager', 3, 'Active'),
      ('EMP-0693', 'Hiroshi', 'Fischer', 'Finance', 'Midwest', '2018-05-02', 'MGR-043', 'VP of Finance', 5, 'Active'),
      ('EMP-0694', 'Oluwaseun', 'Pillai', 'Sales', 'Southwest', '2021-03-14', 'MGR-023', 'Account Executive', 2, 'Active'),
      ('EMP-0695', 'Eric', 'Medina', 'Engineering', 'Midwest', '2019-06-03', 'MGR-007', 'Staff Engineer', 4, 'Active'),
      ('EMP-0696', 'Sofia', 'Chen', 'Operations', 'Southeast', '2023-05-07', 'MGR-056', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0697', 'Malaika', 'Gupta', 'Customer Success', 'Northeast', '2022-03-03', 'MGR-052', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0698', 'Isabella', 'Tall', 'Product', 'West Coast', '2019-08-12', 'MGR-050', 'Product Manager', 2, 'Active'),
      ('EMP-0699', 'Valentina', 'López', 'Customer Success', 'Northeast', '2023-06-01', 'MGR-051', 'CS Director', 4, 'Active'),
      ('EMP-0700', 'Beatriz', 'Wang', 'Sales', 'West Coast', '2017-08-05', 'MGR-045', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0701', 'Hugo', 'Novak', 'Engineering', 'Midwest', '2019-10-02', 'MGR-053', 'Staff Engineer', 4, 'Active'),
      ('EMP-0702', 'Priya', 'Gutierrez', 'Operations', 'Northeast', '2022-12-03', 'MGR-034', 'Operations Specialist', 2, 'Active'),
      ('EMP-0703', 'Sakura', 'Rao', 'Sales', 'Northeast', '2018-01-03', 'MGR-016', 'Account Executive', 2, 'Active'),
      ('EMP-0704', 'Annika', 'Novak', 'Engineering', 'Southwest', '2018-02-09', 'MGR-030', 'Software Engineer', 2, 'Active'),
      ('EMP-0705', 'Gabriel', 'Singh', 'Sales', 'Northeast', '2023-07-29', 'MGR-022', 'Sales Manager', 4, 'Active'),
      ('EMP-0706', 'Jasmine', 'Wu', 'Operations', 'West Coast', '2022-06-07', 'MGR-003', 'Operations Specialist', 2, 'Active'),
      ('EMP-0707', 'Ayumi', 'Grant', 'Product', 'Southwest', '2023-03-23', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0708', 'Suresh', 'Ramírez', 'Customer Success', 'Northeast', '2018-11-20', 'MGR-052', 'CS Manager', 2, 'Active'),
      ('EMP-0709', 'Oluwaseun', 'Smith', 'Customer Success', 'Southeast', '2023-12-18', 'MGR-027', 'VP of Customer Success', 5, 'Active'),
      ('EMP-0710', 'Ruth', 'Sesay', 'Finance', 'Midwest', '2021-04-07', 'MGR-028', 'Finance Director', 4, 'Active'),
      ('EMP-0711', 'Mei', 'Zhang', 'Product', 'West Coast', '2020-05-16', 'MGR-002', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0712', 'Valentina', 'Dahl', 'Sales', 'West Coast', '2020-07-27', 'MGR-049', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0713', 'Kaia', 'Sanchez', 'Product', 'Midwest', '2022-02-27', 'MGR-054', 'Product Manager', 2, 'Active'),
      ('EMP-0714', 'Paloma', 'Patel', 'Engineering', 'Northeast', '2024-10-23', 'MGR-036', 'Software Engineer', 2, 'Active'),
      ('EMP-0715', 'Ingrid', 'Guerrero', 'Engineering', 'Southeast', '2020-12-16', 'MGR-032', 'Senior Engineer', 3, 'Active'),
      ('EMP-0716', 'Wei', 'Liu', 'Operations', 'Midwest', '2021-12-26', 'MGR-003', 'VP of Operations', 5, 'Active'),
      ('EMP-0717', 'Pia', 'Kamara', 'Engineering', 'West Coast', '2025-01-19', 'MGR-018', 'Senior Engineer', 3, 'Active'),
      ('EMP-0718', 'Wyatt', 'Ly', 'Sales', 'Southwest', '2024-02-29', 'MGR-035', 'Account Executive', 2, 'Active'),
      ('EMP-0719', 'Ayumi', 'Kamara', 'Product', 'West Coast', '2023-10-06', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0720', 'Helga', 'Matsumoto', 'Finance', 'Midwest', '2024-08-09', 'MGR-008', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0721', 'James', 'Cissé', 'Product', 'Southwest', '2020-08-16', 'MGR-050', 'Group Product Manager', 4, 'Active'),
      ('EMP-0722', 'Sienna', 'Braun', 'Marketing', 'West Coast', '2025-02-02', 'MGR-014', 'Marketing Director', 4, 'Active'),
      ('EMP-0723', 'Ryan', 'Kamara', 'Marketing', 'Southwest', '2017-04-14', 'MGR-014', 'Marketing Director', 4, 'Active'),
      ('EMP-0724', 'Samuel', 'Torres', 'Marketing', 'Midwest', '2024-01-06', 'MGR-009', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0725', 'Thandiwe', 'Inoue', 'Sales', 'Southwest', '2020-10-27', 'MGR-010', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0726', 'Desmond', 'Rojas', 'Customer Success', 'Southwest', '2023-06-30', 'MGR-005', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0727', 'Tariq', 'Martínez', 'Engineering', 'Southeast', '2023-11-07', 'MGR-032', 'Junior Engineer', 1, 'Active'),
      ('EMP-0728', 'Brigitte', 'Peña', 'Engineering', 'West Coast', '2019-08-13', 'MGR-053', 'Staff Engineer', 4, 'Active'),
      ('EMP-0729', 'Hina', 'Saito', 'Finance', 'Southwest', '2024-07-30', 'MGR-060', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0730', 'Aisha', 'Navarro', 'Product', 'Southwest', '2019-03-05', 'MGR-054', 'Senior Product Manager', 3, 'Active'),
      ('EMP-0731', 'Desmond', 'Iyer', 'Sales', 'Northeast', '2017-06-30', 'MGR-010', 'Sales Associate', 1, 'Active'),
      ('EMP-0732', 'Pia', 'Koroma', 'Finance', 'West Coast', '2018-08-27', 'MGR-039', 'Finance Director', 4, 'Active'),
      ('EMP-0733', 'Bao', 'Grant', 'Product', 'Northeast', '2022-09-09', 'MGR-054', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0734', 'Yara', 'Hernández', 'Marketing', 'Northeast', '2024-10-16', 'MGR-058', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0735', 'Thandiwe', 'Romero', 'Marketing', 'Southeast', '2018-03-06', 'MGR-058', 'Marketing Specialist', 2, 'Active'),
      ('EMP-0736', 'Camila', 'Matsumoto', 'Operations', 'West Coast', '2022-05-24', 'MGR-034', 'Operations Specialist', 2, 'Active'),
      ('EMP-0737', 'Maria', 'Mendoza', 'Engineering', 'Southwest', '2023-03-23', 'MGR-006', 'Software Engineer', 2, 'Active'),
      ('EMP-0738', 'Chukwu', 'Chen', 'Engineering', 'Northeast', '2018-12-15', 'MGR-018', 'Software Engineer', 2, 'Active'),
      ('EMP-0739', 'Freya', 'Eriksson', 'Engineering', 'Northeast', '2018-02-19', 'MGR-004', 'Staff Engineer', 4, 'Active'),
      ('EMP-0740', 'Sven', 'Popov', 'Sales', 'Midwest', '2021-02-23', 'MGR-024', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0741', 'Björn', 'Gupta', 'Customer Success', 'Northeast', '2021-03-30', 'MGR-051', 'CS Manager', 2, 'Active'),
      ('EMP-0742', 'Mei', 'Romero', 'Finance', 'Northeast', '2020-04-19', 'MGR-060', 'Finance Director', 4, 'Active'),
      ('EMP-0743', 'Tomás', 'Haugen', 'Finance', 'Southeast', '2017-11-30', 'MGR-060', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0744', 'Adam', 'Sow', 'Operations', 'West Coast', '2020-08-11', 'MGR-034', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0745', 'Chen', 'Ono', 'Operations', 'West Coast', '2019-04-29', 'MGR-031', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0746', 'Viktor', 'Nishimura', 'Operations', 'West Coast', '2021-03-13', 'MGR-033', 'Operations Specialist', 2, 'Active'),
      ('EMP-0747', 'Bao', 'Nilsson', 'Sales', 'West Coast', '2022-09-30', 'MGR-045', 'Sales Associate', 1, 'Active'),
      ('EMP-0748', 'Fernanda', 'Wu', 'Marketing', 'Southeast', '2021-12-15', 'MGR-014', 'Marketing Coordinator', 1, 'Active'),
      ('EMP-0749', 'Suresh', 'Guo', 'Finance', 'Southwest', '2019-07-22', 'MGR-017', 'Finance Director', 4, 'Active'),
      ('EMP-0750', 'Samuel', 'Fujita', 'Marketing', 'Midwest', '2024-08-31', 'MGR-015', 'Marketing Director', 4, 'Active'),
      ('EMP-0751', 'Mireille', 'Svoboda', 'Engineering', 'Midwest', '2020-11-20', 'MGR-032', 'Software Engineer', 2, 'Active'),
      ('EMP-0752', 'Ravi', 'Sun', 'Sales', 'Northeast', '2019-05-10', 'MGR-042', 'Sales Manager', 4, 'Active'),
      ('EMP-0753', 'Raj', 'Hansen', 'Customer Success', 'Northeast', '2024-10-29', 'MGR-046', 'CS Manager', 2, 'Active'),
      ('EMP-0754', 'Leila', 'Estrada', 'Customer Success', 'Northeast', '2025-04-11', 'MGR-005', 'CS Manager', 2, 'Active'),
      ('EMP-0755', 'Tatiana', 'Guerrero', 'Marketing', 'Midwest', '2023-05-14', 'MGR-009', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0756', 'Helga', 'Sugiyama', 'Finance', 'West Coast', '2021-04-11', 'MGR-021', 'Finance Director', 4, 'Active'),
      ('EMP-0757', 'Amara', 'Fujita', 'Finance', 'Southeast', '2020-06-01', 'MGR-017', 'Finance Manager', 3, 'Active'),
      ('EMP-0758', 'Nkechi', 'Müller', 'Sales', 'Northeast', '2021-04-30', 'MGR-023', 'Sales Associate', 1, 'Active'),
      ('EMP-0759', 'Dmitri', 'Murakami', 'Finance', 'Southwest', '2021-08-10', 'MGR-037', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0760', 'Sofia', 'Jalloh', 'Customer Success', 'Northeast', '2019-04-23', 'MGR-027', 'CS Associate', 1, 'Active'),
      ('EMP-0761', 'Aaliyah', 'Grant', 'Sales', 'West Coast', '2022-02-23', 'MGR-023', 'Sales Manager', 4, 'Active'),
      ('EMP-0762', 'Joaquin', 'Joshi', 'Finance', 'Midwest', '2022-07-04', 'MGR-039', 'VP of Finance', 5, 'Active'),
      ('EMP-0763', 'Julian', 'Ogawa', 'Product', 'Midwest', '2018-12-19', 'MGR-050', 'Product Manager', 2, 'Active'),
      ('EMP-0764', 'Mateo', 'Ndiaye', 'Engineering', 'Southeast', '2017-06-28', 'MGR-018', 'Senior Engineer', 3, 'Active'),
      ('EMP-0765', 'Devi', 'Braun', 'Operations', 'West Coast', '2021-02-19', 'MGR-011', 'Operations Analyst', 1, 'Active'),
      ('EMP-0766', 'Greta', 'Torres', 'Marketing', 'Northeast', '2022-03-09', 'MGR-009', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0767', 'Petra', 'Sun', 'Engineering', 'Southwest', '2024-12-14', 'MGR-007', 'Software Engineer', 2, 'Active'),
      ('EMP-0768', 'Sean', 'Sanchez', 'Product', 'Southeast', '2020-02-18', 'MGR-013', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0769', 'Nadia', 'Mayer', 'Product', 'Southeast', '2024-07-13', 'MGR-002', 'Product Manager', 2, 'Active'),
      ('EMP-0770', 'Hiroshi', 'Mayer', 'Sales', 'Southeast', '2024-02-14', 'MGR-044', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0771', 'Anya', 'Dutta', 'Engineering', 'Southwest', '2019-04-07', 'MGR-018', 'Staff Engineer', 4, 'Active'),
      ('EMP-0772', 'Fatima', 'Nguyen', 'Marketing', 'Northeast', '2017-09-16', 'MGR-014', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0773', 'Andrei', 'Torres', 'Engineering', 'Southeast', '2020-09-01', 'MGR-030', 'Senior Engineer', 3, 'Active'),
      ('EMP-0774', 'Esperanza', 'Cissé', 'Engineering', 'Northeast', '2020-12-31', 'MGR-030', 'Software Engineer', 2, 'Active'),
      ('EMP-0775', 'Lukas', 'Delgado', 'Sales', 'Southwest', '2020-02-15', 'MGR-049', 'Senior Account Executive', 3, 'Active'),
      ('EMP-0776', 'Marisol', 'Dutta', 'Operations', 'Southwest', '2023-05-21', 'MGR-025', 'Operations Director', 4, 'Active'),
      ('EMP-0777', 'Linh', 'Sato', 'Marketing', 'Northeast', '2024-09-17', 'MGR-015', 'Senior Marketing Manager', 3, 'Active'),
      ('EMP-0778', 'Yolanda', 'Kondo', 'Operations', 'West Coast', '2019-08-11', 'MGR-003', 'Senior Operations Manager', 3, 'Active'),
      ('EMP-0779', 'Patrick', 'Saito', 'Engineering', 'Southwest', '2022-08-05', 'MGR-029', 'Junior Engineer', 1, 'Active'),
      ('EMP-0780', 'Rena', 'Iyer', 'Product', 'Midwest', '2020-07-24', 'MGR-002', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0781', 'Liam', 'Matsumoto', 'Customer Success', 'Midwest', '2019-04-24', 'MGR-048', 'CS Manager', 2, 'Active'),
      ('EMP-0782', 'Kofi', 'Ly', 'Customer Success', 'Southeast', '2019-01-22', 'MGR-046', 'Senior CS Manager', 3, 'Active'),
      ('EMP-0783', 'Petra', 'Singh', 'Product', 'Northeast', '2018-05-30', 'MGR-002', 'VP of Product', 5, 'Active'),
      ('EMP-0784', 'Sienna', 'Koroma', 'Sales', 'Northeast', '2018-12-24', 'MGR-045', 'Account Executive', 2, 'Active'),
      ('EMP-0785', 'Yara', 'Sesay', 'Customer Success', 'Southeast', '2021-01-12', 'MGR-046', 'CS Associate', 1, 'Active'),
      ('EMP-0786', 'Nathan', 'Owusu', 'Customer Success', 'Southeast', '2021-04-12', 'MGR-046', 'CS Associate', 1, 'Active'),
      ('EMP-0787', 'Omar', 'Conteh', 'Operations', 'Southeast', '2020-03-06', 'MGR-040', 'Operations Specialist', 2, 'Active'),
      ('EMP-0788', 'Troy', 'Eriksson', 'Sales', 'Northeast', '2022-08-13', 'MGR-059', 'Sales Associate', 1, 'Active'),
      ('EMP-0789', 'Esperanza', 'Sow', 'Operations', 'Southeast', '2023-08-07', 'MGR-011', 'Operations Specialist', 2, 'Active'),
      ('EMP-0790', 'Obi', 'Zhang', 'Sales', 'Southeast', '2025-02-06', 'MGR-024', 'Regional Sales Director', 5, 'Active'),
      ('EMP-0791', 'Dmitri', 'Endo', 'Operations', 'Northeast', '2017-05-22', 'MGR-034', 'Operations Specialist', 2, 'Active'),
      ('EMP-0792', 'Jabari', 'Sugiyama', 'Operations', 'Northeast', '2023-10-03', 'MGR-025', 'Operations Specialist', 2, 'Active'),
      ('EMP-0793', 'Chioma', 'Vega', 'Sales', 'Southeast', '2021-10-15', 'MGR-023', 'Account Executive', 2, 'Active'),
      ('EMP-0794', 'Brigitte', 'Grant', 'Marketing', 'Southeast', '2025-02-28', 'MGR-009', 'Marketing Director', 4, 'Active'),
      ('EMP-0795', 'Amira', 'Sun', 'Product', 'Midwest', '2018-11-21', 'MGR-050', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0796', 'Leo', 'Rao', 'Product', 'Southeast', '2021-03-15', 'MGR-013', 'Product Manager', 2, 'Active'),
      ('EMP-0797', 'Sven', 'Sylla', 'Finance', 'Northeast', '2017-08-30', 'MGR-057', 'Senior Financial Analyst', 2, 'Active'),
      ('EMP-0798', 'Miguel', 'Rojas', 'Product', 'West Coast', '2024-02-20', 'MGR-013', 'Associate Product Manager', 1, 'Active'),
      ('EMP-0799', 'Jia', 'Santos', 'Finance', 'Northeast', '2024-07-18', 'MGR-060', 'Finance Manager', 3, 'Active'),
      ('EMP-0800', 'Yolanda', 'Johansson', 'Engineering', 'Northeast', '2017-01-30', 'MGR-032', 'Senior Engineer', 3, 'Active');
    SET row_count = (SELECT COUNT(*) FROM employees);
    SELECT 'employees: Inserted ' || row_count || ' rows.' AS status;
  ELSE
    SELECT 'employees: Table already has ' || row_count || ' rows. Skipping insert.' AS status;
  END IF;
END;

-- %%
-----------------------------------
-- Create managers table
-----------------------------------
CREATE TABLE IF NOT EXISTS managers (
  manager_id STRING NOT NULL,
  manager_name STRING,
  department STRING,
  region STRING,
  team_size INT,
  start_date DATE,
  end_date DATE,
  performance_rating DOUBLE
);


-- Insert data only if table is empty
BEGIN
  DECLARE row_count INT;
  SET row_count = (SELECT COUNT(*) FROM managers);
  IF row_count = 0 THEN
    INSERT INTO managers VALUES
      ('MGR-001', 'Jordan Rivera', 'Engineering', 'Southwest', 14, '2019-03-10', '2025-07-15', 4.8),
      ('MGR-002', 'Sven Müller', 'Product', 'Midwest', 9, '2018-09-30', NULL, 2.9),
      ('MGR-003', 'Isabella Lin', 'Operations', 'Southwest', 11, '2016-05-02', NULL, 2.4),
      ('MGR-004', 'Dagny Sugiyama', 'Engineering', 'West Coast', 16, '2018-03-25', NULL, 2.9),
      ('MGR-005', 'Valentina Patel', 'Customer Success', 'Northeast', 10, '2020-09-27', NULL, 3.8),
      ('MGR-006', 'Devi Popov', 'Engineering', 'Southwest', 13, '2020-04-05', NULL, 2.6),
      ('MGR-007', 'Ximena Guerrero', 'Engineering', 'Southeast', 18, '2016-11-18', NULL, 2.8),
      ('MGR-008', 'Desmond Mendoza', 'Finance', 'Northeast', 12, '2016-10-11', '2025-04-27', 4.7),
      ('MGR-009', 'Svetlana Vargas', 'Marketing', 'Southeast', 10, '2023-02-16', NULL, 3.4),
      ('MGR-010', 'Seiji Nilsson', 'Sales', 'Midwest', 18, '2023-04-08', NULL, 4),
      ('MGR-011', 'Mina Matsuda', 'Operations', 'Midwest', 11, '2023-03-06', NULL, 4.4),
      ('MGR-012', 'Annika Tanaka', 'Sales', 'Southwest', 9, '2019-07-16', NULL, 3.8),
      ('MGR-013', 'Brendan Yoshida', 'Product', 'Southeast', 18, '2020-06-08', NULL, 4.9),
      ('MGR-014', 'Ximena Kowalski', 'Marketing', 'Northeast', 16, '2018-10-07', NULL, 3.4),
      ('MGR-015', 'Yolanda Peña', 'Marketing', 'Northeast', 9, '2017-07-20', NULL, 4.3),
      ('MGR-016', 'Alejandro Suzuki', 'Sales', 'Northeast', 14, '2020-09-25', NULL, 2),
      ('MGR-017', 'Thandi Inoue', 'Finance', 'Southwest', 16, '2017-04-14', NULL, 4.9),
      ('MGR-018', 'Chen Gutierrez', 'Engineering', 'Midwest', 8, '2020-11-15', NULL, 4.7),
      ('MGR-019', 'Rosa Morita', 'Customer Success', 'Northeast', 18, '2021-09-10', NULL, 3.1),
      ('MGR-020', 'Idris Camara', 'Finance', 'Northeast', 10, '2017-09-18', NULL, 2.5),
      ('MGR-021', 'Thandi Smith', 'Finance', 'Midwest', 12, '2021-06-24', '2025-07-05', 3.2),
      ('MGR-022', 'Lina Tanaka', 'Sales', 'West Coast', 15, '2016-11-18', NULL, 4.2),
      ('MGR-023', 'Hugo Martínez', 'Sales', 'Southeast', 16, '2022-03-01', NULL, 2),
      ('MGR-024', 'Malaika Nishimura', 'Sales', 'West Coast', 14, '2018-04-03', NULL, 4.4),
      ('MGR-025', 'Finn Vega', 'Operations', 'Southwest', 13, '2018-10-12', NULL, 3.5),
      ('MGR-026', 'Priya Grant', 'Finance', 'Northeast', 9, '2022-08-07', NULL, 3.4),
      ('MGR-027', 'Sofia Nakamura', 'Customer Success', 'Midwest', 12, '2016-10-17', NULL, 3.3),
      ('MGR-028', 'Cedric Yoshida', 'Finance', 'Northeast', 11, '2022-05-27', NULL, 3.7),
      ('MGR-029', 'Hassan Watanabe', 'Engineering', 'Southeast', 15, '2019-12-22', NULL, 2.4),
      ('MGR-030', 'Anya Mensah', 'Engineering', 'Southeast', 9, '2019-10-21', NULL, 3.5),
      ('MGR-031', 'Samir Asante', 'Operations', 'Northeast', 9, '2019-02-14', NULL, 3.9),
      ('MGR-032', 'Catalina Holm', 'Engineering', 'Southwest', 8, '2023-04-25', NULL, 4.8),
      ('MGR-033', 'Rashid Torres', 'Operations', 'Southeast', 14, '2021-05-25', NULL, 3.2),
      ('MGR-034', 'Jasmine Torres', 'Operations', 'Southwest', 15, '2020-05-18', NULL, 3.3),
      ('MGR-035', 'Tarquin Ueda', 'Sales', 'Northeast', 8, '2019-04-30', NULL, 4.4),
      ('MGR-036', 'Cormac Ishikawa', 'Engineering', 'Midwest', 15, '2016-08-22', NULL, 2.3),
      ('MGR-037', 'Emeka Tanaka', 'Finance', 'Southwest', 9, '2018-01-31', NULL, 3.5),
      ('MGR-038', 'Rashid Bhat', 'Engineering', 'West Coast', 8, '2018-10-05', NULL, 3),
      ('MGR-039', 'Yolanda Maeda', 'Finance', 'Midwest', 13, '2018-12-04', NULL, 3.1),
      ('MGR-040', 'Lina Castillo', 'Operations', 'Northeast', 13, '2023-03-28', NULL, 4.8),
      ('MGR-041', 'Wei Delgado', 'Finance', 'West Coast', 11, '2017-02-13', NULL, 2.9),
      ('MGR-042', 'Dagny Castillo', 'Sales', 'Midwest', 13, '2016-10-08', NULL, 3.4),
      ('MGR-043', 'Mireille Moreno', 'Finance', 'West Coast', 16, '2016-02-02', NULL, 4.1),
      ('MGR-044', 'Idris Ivanov', 'Sales', 'Midwest', 16, '2017-04-17', NULL, 3.8),
      ('MGR-045', 'Amira Gutierrez', 'Sales', 'Midwest', 8, '2021-09-01', NULL, 3.9),
      ('MGR-046', 'Mohammed Nishimura', 'Customer Success', 'Midwest', 10, '2016-06-29', '2026-01-30', 3.2),
      ('MGR-047', 'Catalina Hu', 'Product', 'Southeast', 10, '2022-04-16', '2025-02-08', 3.1),
      ('MGR-048', 'Mireille Okafor', 'Customer Success', 'Midwest', 14, '2022-07-13', NULL, 3.9),
      ('MGR-049', 'Oluwaseun Zhao', 'Sales', 'Northeast', 16, '2017-02-25', NULL, 3.9),
      ('MGR-050', 'Miguel Saito', 'Product', 'Northeast', 10, '2018-08-27', NULL, 3.6),
      ('MGR-051', 'Thandiwe Traoré', 'Customer Success', 'Northeast', 9, '2018-12-28', NULL, 3.4),
      ('MGR-052', 'Brigitte Okafor', 'Customer Success', 'Southeast', 15, '2018-06-30', NULL, 2.8),
      ('MGR-053', 'Takeshi Cruz', 'Engineering', 'Northeast', 9, '2020-06-20', NULL, 4.4),
      ('MGR-054', 'Valentina Mansaray', 'Product', 'West Coast', 16, '2020-06-25', NULL, 3.4),
      ('MGR-055', 'Jabari Diallo', 'Finance', 'Midwest', 14, '2016-06-05', NULL, 3.6),
      ('MGR-056', 'Esteban Hansen', 'Operations', 'West Coast', 17, '2021-09-25', NULL, 3.6),
      ('MGR-057', 'Adaeze Smith', 'Finance', 'West Coast', 9, '2018-03-18', NULL, 3.7),
      ('MGR-058', 'Felix Tall', 'Marketing', 'Southwest', 18, '2019-05-15', NULL, 3),
      ('MGR-059', 'Natsumi Hu', 'Sales', 'Northeast', 14, '2020-09-18', NULL, 3.8),
      ('MGR-060', 'Omar Romero', 'Finance', 'Midwest', 8, '2020-07-21', NULL, 3.4);
    SET row_count = (SELECT COUNT(*) FROM managers);
    SELECT 'managers: Inserted ' || row_count || ' rows.' AS status;
  ELSE
    SELECT 'managers: Table already has ' || row_count || ' rows. Skipping insert.' AS status;
  END IF;
END;

-- %%
-- Create resignations table
CREATE TABLE IF NOT EXISTS resignations (
  resignation_id STRING NOT NULL,
  employee_id STRING NOT NULL,
  resignation_date DATE,
  last_day DATE,
  reason_code STRING,
  exit_survey_score DOUBLE
);


-- Insert data only if table is empty
BEGIN
  DECLARE row_count INT;
  SET row_count = (SELECT COUNT(*) FROM resignations);
  IF row_count = 0 THEN
    INSERT INTO resignations VALUES
      ('RES-0001', 'EMP-0001', '2025-08-10', '2025-08-29', 'Manager Relationship', 2.1),
      ('RES-0002', 'EMP-0002', '2025-08-12', '2025-09-01', 'Compensation', 4),
      ('RES-0003', 'EMP-0003', '2025-08-12', '2025-09-01', 'Manager Relationship', 2.5),
      ('RES-0004', 'EMP-0004', '2025-08-28', '2025-09-07', 'Personal', 3.5),
      ('RES-0005', 'EMP-0005', '2025-07-20', '2025-08-06', 'Compensation', 1.5),
      ('RES-0006', 'EMP-0006', '2025-08-14', '2025-09-04', 'Compensation', 2.7),
      ('RES-0007', 'EMP-0007', '2025-07-27', '2025-08-14', 'Manager Relationship', 2.4),
      ('RES-0008', 'EMP-0008', '2025-09-02', '2025-09-15', 'Manager Relationship', 1.6),
      ('RES-0009', 'EMP-0009', '2025-08-19', '2025-09-06', 'Manager Relationship', 1.7),
      ('RES-0010', 'EMP-0010', '2025-08-01', '2025-08-11', 'Personal', 3.9),
      ('RES-0011', 'EMP-0011', '2025-07-21', '2025-08-10', 'Manager Relationship', 2.1),
      ('RES-0012', 'EMP-0037', '2025-01-19', '2025-01-30', 'Relocation', 2.2),
      ('RES-0013', 'EMP-0040', '2025-01-16', '2025-02-03', 'Work-Life Balance', 5),
      ('RES-0014', 'EMP-0097', '2025-03-15', '2025-04-09', 'Personal', 3.4),
      ('RES-0015', 'EMP-0068', '2025-02-18', '2025-03-01', 'Work-Life Balance', 3.9),
      ('RES-0016', 'EMP-0091', '2025-02-12', '2025-02-26', 'Manager Relationship', 3.6),
      ('RES-0017', 'EMP-0058', '2025-01-29', '2025-02-09', 'Work-Life Balance', 4.6),
      ('RES-0018', 'EMP-0034', '2025-01-23', '2025-02-17', 'Personal', 2.7),
      ('RES-0019', 'EMP-0113', '2025-01-21', '2025-01-31', 'Relocation', 4.8),
      ('RES-0020', 'EMP-0017', '2025-02-13', '2025-03-08', 'Personal', 4.7),
      ('RES-0021', 'EMP-0122', '2025-02-20', '2025-03-04', 'Relocation', 3.1),
      ('RES-0022', 'EMP-0083', '2025-02-06', '2025-02-25', 'Personal', 3.8),
      ('RES-0023', 'EMP-0114', '2025-02-20', '2025-03-05', 'Career Growth', 4.9),
      ('RES-0024', 'EMP-0041', '2025-03-16', '2025-03-27', 'Manager Relationship', 2.9),
      ('RES-0025', 'EMP-0107', '2025-01-21', '2025-02-18', 'Career Growth', 2.2),
      ('RES-0026', 'EMP-0100', '2025-03-31', '2025-04-25', 'Compensation', 3.6),
      ('RES-0027', 'EMP-0049', '2025-01-26', '2025-02-25', 'Career Growth', 3.7),
      ('RES-0028', 'EMP-0103', '2025-03-15', '2025-03-28', 'Personal', 3.7),
      ('RES-0029', 'EMP-0080', '2025-02-24', '2025-03-11', 'Work-Life Balance', 3.2),
      ('RES-0030', 'EMP-0132', '2025-01-13', '2025-02-03', 'Work-Life Balance', 3.3),
      ('RES-0031', 'EMP-0134', '2025-03-07', '2025-04-06', 'Compensation', 3.5),
      ('RES-0032', 'EMP-0139', '2025-02-25', '2025-03-11', 'Personal', 3),
      ('RES-0033', 'EMP-0021', '2025-01-31', '2025-02-22', 'Compensation', 3.3),
      ('RES-0034', 'EMP-0082', '2025-06-28', '2025-07-27', 'Work-Life Balance', 2.7),
      ('RES-0035', 'EMP-0110', '2025-06-28', '2025-07-10', 'Manager Relationship', 2.5),
      ('RES-0036', 'EMP-0016', '2025-06-23', '2025-07-15', 'Compensation', 2.7),
      ('RES-0037', 'EMP-0024', '2025-04-16', '2025-04-29', 'Career Growth', 2.5),
      ('RES-0038', 'EMP-0015', '2025-06-02', '2025-07-02', 'Personal', 3),
      ('RES-0039', 'EMP-0048', '2025-06-13', '2025-07-11', 'Compensation', 3.2),
      ('RES-0040', 'EMP-0055', '2025-06-28', '2025-07-11', 'Manager Relationship', 3.6),
      ('RES-0041', 'EMP-0065', '2025-06-22', '2025-07-15', 'Compensation', 4.1),
      ('RES-0042', 'EMP-0142', '2025-04-17', '2025-04-30', 'Compensation', 2.8),
      ('RES-0043', 'EMP-0090', '2025-06-08', '2025-06-23', 'Compensation', 1.5),
      ('RES-0044', 'EMP-0023', '2025-06-29', '2025-07-09', 'Compensation', 3.8),
      ('RES-0045', 'EMP-0038', '2025-06-07', '2025-07-02', 'Career Growth', 1.8),
      ('RES-0046', 'EMP-0073', '2025-06-14', '2025-07-11', 'Personal', 3.3),
      ('RES-0047', 'EMP-0125', '2025-04-27', '2025-05-10', 'Career Growth', 2.8),
      ('RES-0048', 'EMP-0121', '2025-06-16', '2025-07-01', 'Career Growth', 2.5),
      ('RES-0049', 'EMP-0054', '2025-04-06', '2025-04-20', 'Relocation', 3.5),
      ('RES-0050', 'EMP-0136', '2025-06-23', '2025-07-08', 'Career Growth', 3.1),
      ('RES-0051', 'EMP-0020', '2025-04-11', '2025-04-24', 'Relocation', 4.7),
      ('RES-0052', 'EMP-0118', '2025-05-17', '2025-06-13', 'Career Growth', 4.5),
      ('RES-0053', 'EMP-0022', '2025-05-02', '2025-05-21', 'Career Growth', 3),
      ('RES-0054', 'EMP-0111', '2025-06-06', '2025-06-25', 'Personal', 2.1),
      ('RES-0055', 'EMP-0131', '2025-06-28', '2025-07-18', 'Relocation', 3.6),
      ('RES-0056', 'EMP-0102', '2025-05-16', '2025-06-14', 'Relocation', 3.3),
      ('RES-0057', 'EMP-0096', '2025-07-06', '2025-07-23', 'Career Growth', 3.6),
      ('RES-0058', 'EMP-0087', '2025-07-19', '2025-08-07', 'Work-Life Balance', 3.3),
      ('RES-0059', 'EMP-0063', '2025-09-09', '2025-09-25', 'Relocation', 3.7),
      ('RES-0060', 'EMP-0140', '2025-08-05', '2025-08-19', 'Personal', 2.2),
      ('RES-0061', 'EMP-0130', '2025-08-03', '2025-08-25', 'Personal', 3.7),
      ('RES-0062', 'EMP-0061', '2025-07-21', '2025-08-12', 'Compensation', 4.5),
      ('RES-0063', 'EMP-0067', '2025-09-27', '2025-10-11', 'Relocation', 2.7),
      ('RES-0064', 'EMP-0062', '2025-07-10', '2025-08-09', 'Personal', 4.6),
      ('RES-0065', 'EMP-0060', '2025-07-25', '2025-08-15', 'Relocation', 3.2),
      ('RES-0066', 'EMP-0120', '2025-09-21', '2025-10-17', 'Personal', 2.7),
      ('RES-0067', 'EMP-0095', '2025-08-25', '2025-09-16', 'Career Growth', 3.5),
      ('RES-0068', 'EMP-0089', '2025-09-16', '2025-10-03', 'Career Growth', 3.5),
      ('RES-0069', 'EMP-0112', '2025-09-09', '2025-10-02', 'Career Growth', 3.5),
      ('RES-0070', 'EMP-0127', '2025-09-20', '2025-10-02', 'Compensation', 2.8),
      ('RES-0071', 'EMP-0117', '2025-07-29', '2025-08-16', 'Career Growth', 3.8),
      ('RES-0072', 'EMP-0133', '2025-08-18', '2025-09-04', 'Compensation', 4.8),
      ('RES-0073', 'EMP-0051', '2025-07-23', '2025-08-18', 'Personal', 4.5),
      ('RES-0074', 'EMP-0105', '2025-08-09', '2025-09-06', 'Manager Relationship', 2.1),
      ('RES-0075', 'EMP-0086', '2025-09-28', '2025-10-26', 'Work-Life Balance', 3.3),
      ('RES-0076', 'EMP-0057', '2025-09-09', '2025-09-27', 'Personal', 3.6),
      ('RES-0077', 'EMP-0094', '2025-08-19', '2025-09-03', 'Compensation', 2.9),
      ('RES-0078', 'EMP-0137', '2025-09-25', '2025-10-22', 'Relocation', 3.9),
      ('RES-0079', 'EMP-0032', '2025-09-14', '2025-09-28', 'Compensation', 2.6),
      ('RES-0080', 'EMP-0030', '2025-09-26', '2025-10-22', 'Personal', 2.9),
      ('RES-0081', 'EMP-0129', '2025-09-11', '2025-09-29', 'Career Growth', 2.8),
      ('RES-0082', 'EMP-0047', '2025-09-20', '2025-10-11', 'Personal', 3.2),
      ('RES-0083', 'EMP-0043', '2025-09-29', '2025-10-23', 'Career Growth', 4.4),
      ('RES-0084', 'EMP-0050', '2025-08-15', '2025-09-08', 'Relocation', 3),
      ('RES-0085', 'EMP-0123', '2025-09-30', '2025-10-17', 'Compensation', 4.1),
      ('RES-0086', 'EMP-0056', '2025-07-12', '2025-07-31', 'Compensation', 3),
      ('RES-0087', 'EMP-0035', '2025-07-11', '2025-07-23', 'Personal', 3.6),
      ('RES-0088', 'EMP-0018', '2025-07-12', '2025-07-27', 'Relocation', 3.8),
      ('RES-0089', 'EMP-0070', '2025-09-02', '2025-09-12', 'Work-Life Balance', 3.6),
      ('RES-0090', 'EMP-0028', '2025-08-24', '2025-09-19', 'Work-Life Balance', 3.9),
      ('RES-0091', 'EMP-0135', '2025-09-26', '2025-10-23', 'Personal', 4),
      ('RES-0092', 'EMP-0126', '2025-11-21', '2025-12-01', 'Personal', 4.5),
      ('RES-0093', 'EMP-0042', '2025-12-31', '2026-01-23', 'Personal', 2.4),
      ('RES-0094', 'EMP-0046', '2025-11-14', '2025-12-01', 'Work-Life Balance', 2.1),
      ('RES-0095', 'EMP-0045', '2025-12-07', '2026-01-05', 'Career Growth', 1.5),
      ('RES-0096', 'EMP-0084', '2025-11-27', '2025-12-12', 'Personal', 4),
      ('RES-0097', 'EMP-0128', '2025-10-29', '2025-11-13', 'Career Growth', 2.5),
      ('RES-0098', 'EMP-0076', '2025-10-18', '2025-11-13', 'Compensation', 4.2),
      ('RES-0099', 'EMP-0029', '2025-10-22', '2025-11-12', 'Work-Life Balance', 3.5),
      ('RES-0100', 'EMP-0072', '2025-11-13', '2025-11-30', 'Manager Relationship', 4.3),
      ('RES-0101', 'EMP-0036', '2025-11-07', '2025-11-26', 'Compensation', 1.8),
      ('RES-0102', 'EMP-0074', '2025-11-03', '2025-11-19', 'Career Growth', 2.6),
      ('RES-0103', 'EMP-0085', '2025-11-09', '2025-12-09', 'Relocation', 2.5),
      ('RES-0104', 'EMP-0141', '2025-10-05', '2025-10-29', 'Work-Life Balance', 3.4),
      ('RES-0105', 'EMP-0053', '2025-10-01', '2025-10-30', 'Compensation', 2.9),
      ('RES-0106', 'EMP-0143', '2025-11-08', '2025-11-29', 'Career Growth', 2.4),
      ('RES-0107', 'EMP-0078', '2025-11-21', '2025-12-12', 'Career Growth', 4.4),
      ('RES-0108', 'EMP-0031', '2025-11-25', '2025-12-20', 'Career Growth', 1.3),
      ('RES-0109', 'EMP-0019', '2025-11-22', '2025-12-05', 'Work-Life Balance', 2.9),
      ('RES-0110', 'EMP-0079', '2025-10-01', '2025-10-15', 'Manager Relationship', 3.2),
      ('RES-0111', 'EMP-0119', '2025-11-17', '2025-12-06', 'Compensation', 4.2),
      ('RES-0112', 'EMP-0115', '2025-10-24', '2025-11-20', 'Manager Relationship', 4),
      ('RES-0113', 'EMP-0088', '2025-11-26', '2025-12-11', 'Career Growth', 3.8),
      ('RES-0114', 'EMP-0081', '2025-11-25', '2025-12-05', 'Compensation', 3.6),
      ('RES-0115', 'EMP-0033', '2025-10-25', '2025-11-13', 'Career Growth', 2.8),
      ('RES-0116', 'EMP-0106', '2025-11-20', '2025-12-13', 'Personal', 3.6),
      ('RES-0117', 'EMP-0039', '2026-01-26', '2026-02-20', 'Work-Life Balance', 2.9),
      ('RES-0118', 'EMP-0138', '2026-02-04', '2026-02-17', 'Compensation', 1.7),
      ('RES-0119', 'EMP-0052', '2026-01-17', '2026-02-06', 'Manager Relationship', 2.7),
      ('RES-0120', 'EMP-0064', '2026-02-21', '2026-03-19', 'Personal', 3.1),
      ('RES-0121', 'EMP-0108', '2026-01-17', '2026-01-30', 'Work-Life Balance', 1.5),
      ('RES-0122', 'EMP-0027', '2026-01-03', '2026-01-17', 'Career Growth', 1.7),
      ('RES-0123', 'EMP-0104', '2026-01-31', '2026-02-11', 'Personal', 3.2),
      ('RES-0124', 'EMP-0124', '2026-02-13', '2026-03-08', 'Work-Life Balance', 3.1),
      ('RES-0125', 'EMP-0099', '2026-02-07', '2026-02-26', 'Compensation', 2.2),
      ('RES-0126', 'EMP-0075', '2026-02-24', '2026-03-13', 'Personal', 3.1),
      ('RES-0127', 'EMP-0069', '2026-02-05', '2026-02-18', 'Work-Life Balance', 2.6),
      ('RES-0128', 'EMP-0059', '2026-03-31', '2026-04-17', 'Personal', 2.3),
      ('RES-0129', 'EMP-0025', '2026-01-14', '2026-02-09', 'Personal', 3.6),
      ('RES-0130', 'EMP-0116', '2026-01-25', '2026-02-22', 'Personal', 3.5),
      ('RES-0131', 'EMP-0093', '2026-02-21', '2026-03-04', 'Compensation', 3.6),
      ('RES-0132', 'EMP-0109', '2026-01-25', '2026-02-08', 'Compensation', 2.9),
      ('RES-0133', 'EMP-0066', '2026-01-07', '2026-01-29', 'Compensation', 2.9),
      ('RES-0134', 'EMP-0077', '2026-02-09', '2026-03-11', 'Work-Life Balance', 3.4),
      ('RES-0135', 'EMP-0092', '2026-01-08', '2026-02-03', 'Compensation', 4.1),
      ('RES-0136', 'EMP-0044', '2026-01-07', '2026-01-26', 'Career Growth', 1.8),
      ('RES-0137', 'EMP-0071', '2026-02-23', '2026-03-12', 'Compensation', 4.8),
      ('RES-0138', 'EMP-0101', '2026-01-07', '2026-01-22', 'Career Growth', 4.6),
      ('RES-0139', 'EMP-0098', '2026-01-28', '2026-02-16', 'Compensation', 3.7),
      ('RES-0140', 'EMP-0026', '2026-03-19', '2026-04-01', 'Compensation', 3.2);
    SET row_count = (SELECT COUNT(*) FROM resignations);
    SELECT 'resignations: Inserted ' || row_count || ' rows.' AS status;
  ELSE
    SELECT 'resignations: Table already has ' || row_count || ' rows. Skipping insert.' AS status;
  END IF;
END;

-- %%
SELECT
  current_catalog() AS `Your Default Catalog`,
  current_schema() AS `Your Default Schema`
